# %% [markdown]
# # Temporary Split Batch 3A
#
# This temporary notebook handles a smaller portion of batch 3 and writes only its split-specific partial outputs until all three coordinated splits are ready.

# %% [markdown]
# ## Drive And Repo Setup
#
# Mount Drive, clone the repo into the runtime, and copy the required CSV inputs into the checkout.
#
# - Reads: Google Drive, GitHub repo, runtime filesystem
# - Writes: `/content/svg-kaggle-comptetition`, Drive output root
# - Rerun-safe: Yes. It reclones the repo and recopies the inputs cleanly.

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path

from google.colab import drive

drive.mount("/content/drive")

GIT_REPO_URL = "https://github.com/Demetri65/svg-kaggle-competition.git"
CHECKOUT_PATH = Path("/content/svg-kaggle-comptetition")
DRIVE_ROOT = Path("/content/drive/MyDrive")
OUTPUT_ROOT = DRIVE_ROOT / "svg-kaggle-comptetition" / "submission_outputs"

if CHECKOUT_PATH.exists():
    shutil.rmtree(CHECKOUT_PATH)
subprocess.check_call(["git", "clone", GIT_REPO_URL, str(CHECKOUT_PATH)])

for required_name in ["test.csv", "train.csv", "sample_submission.csv"]:
    destination = CHECKOUT_PATH / required_name
    if destination.exists():
        continue

    preferred_sources = [
        DRIVE_ROOT / "svg-kaggle-comptetition" / required_name,
        DRIVE_ROOT / "Colab Notebooks" / "svg-kaggle-comptetition" / required_name,
    ]
    copied = False
    for candidate in preferred_sources:
        if candidate.exists():
            shutil.copy2(candidate, destination)
            copied = True
            break
    if not copied:
        for candidate in DRIVE_ROOT.rglob(required_name):
            if candidate.is_file():
                shutil.copy2(candidate, destination)
                copied = True
                break
    if not copied:
        raise FileNotFoundError(
            f"Could not find {required_name} in Google Drive. Copy it into {CHECKOUT_PATH} manually and rerun this cell."
        )

os.environ["SVG_KAGGLE_REPO_ROOT"] = str(CHECKOUT_PATH)
sys.path.insert(0, str(CHECKOUT_PATH))
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

print(f"Repo checkout: {CHECKOUT_PATH}")
print(f"Drive output root: {OUTPUT_ROOT}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Repo checkout: /content/svg-kaggle-comptetition
# Drive output root: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs

# %% [markdown]
# ## Package Check
#
# Install any missing runtime packages required by the shared helper module and this notebook.
#
# - Reads: Current Python environment
# - Writes: Installed runtime packages
# - Rerun-safe: Yes. It only installs missing packages.

# %%
import importlib.util
import subprocess
import sys

REQUIRED_PACKAGES = {
    "pandas": "pandas",
    "numpy": "numpy",
    "torch": "torch",
    "transformers": "transformers",
    "peft": "peft",
    "accelerate": "accelerate",
    "cairosvg": "cairosvg",
    "skimage": "scikit-image",
    "PIL": "pillow",
}

missing_packages = [
    package_name
    for module_name, package_name in REQUIRED_PACKAGES.items()
    if importlib.util.find_spec(module_name) is None
]

if missing_packages:
    subprocess.check_call([sys.executable, "-m", "pip", "install", *missing_packages])
    print(f"Installed missing packages: {missing_packages}")
else:
    print("All required packages are already installed.")
# Out:
# All required packages are already installed.

# %% [markdown]
# ## Load Helpers, Recommendation, And Split Slice
#
# Import the shared helper module, load the analysis recommendation, prepare the coordinated split-run state, and select this notebook's exact row slice.
#
# - Reads: Repo checkout, helper module, analysis recommendation, competition CSV files
# - Writes: Split-run marker and cleared batch 3 artifacts only on first run of this split label
# - Rerun-safe: Yes. It reuses the existing split-run marker for the same run label.

# %%
import os
from pathlib import Path

import pandas as pd
from IPython.display import display

import submission_pipeline as pipeline

pipeline.set_global_seed(1337)
PATHS = pipeline.resolve_pipeline_paths(Path(os.environ["SVG_KAGGLE_REPO_ROOT"]), OUTPUT_ROOT)
CONFIG = pipeline.GenerationConfig(verbose_progress=True)
TEST_DF, SAMPLE_SUBMISSION_DF, TRAIN_DF = pipeline.load_competition_frames(PATHS)

print(f"Repo root: {PATHS.repo_root}")
print(f"Output root: {PATHS.output_root}")

BATCH_ID = 3
PART_NAME = "batch_3a"
ROW_START = 650
ROW_END = 700
EXPECTED_PARTS = ('batch_3_main', 'batch_3a', 'batch_3b')
CHECKPOINT_EVERY = 10
SPLIT_RUN_LABEL = "split_batch_3_temp_20260325_v2"

ANALYSIS_RECOMMENDATION = pipeline.load_analysis_recommendation(PATHS)
GENERATION_MODE = ANALYSIS_RECOMMENDATION.get("recommended_generation_mode", "body_only")
BATCH_DIR = pipeline.batch_output_dir(PATHS, BATCH_ID)
PARTIAL_DIR = pipeline.partial_batch_output_dir(PATHS, BATCH_ID)
SLICE_DF = pipeline.select_row_slice(TEST_DF, ROW_START, ROW_END)
INIT_STATUS = pipeline.prepare_split_batch_outputs(
    BATCH_DIR,
    EXPECTED_PARTS,
    run_label=SPLIT_RUN_LABEL,
)

print(f"Recommended generation mode: {GENERATION_MODE}")
print(f"Split run label: {SPLIT_RUN_LABEL}")
print(f"Slice rows: {ROW_START}:{ROW_END} ({len(SLICE_DF)} rows)")
if INIT_STATUS["did_reset"]:
    print("Initialized split batch 3 outputs and cleared stale batch_3 artifacts.")
else:
    print("Using existing split batch 3 partial state for this run label.")
display(SLICE_DF[["id", "prompt", "row_index"]].head())
# Out:
# Repo root: /content/svg-kaggle-comptetition
# Output root: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs
# Recommended generation mode: full_svg
# Split run label: split_batch_3_temp_20260325_v2
# Slice rows: 650:700 (50 rows)
# Initialized split batch 3 outputs and cleared stale batch_3 artifacts.
#                                  id  \
# 0  a2d1fb8c976851526db46bd0a62df319
# 1  7ab9719066edb519fc70aaeb07eb4e06
# 2  ff14e5ee37528d960a1d1bbb4df6f6af
# 3  87cde794689a999ad40b40ef03f88eba
# 4  eb25bd8aa69ff58fffe2f50db471c4a9
#
#                                               prompt  row_index
# 0  The image depicts a simple black outline of a ...        650
# 1  A rectangular frame with two open brackets at ...        651
# 2  The image contains a black circular logo or ic...        652
# 3  A simple icon featuring a lowercase 'i' inside...        653
# 4  The image shows a dark gray, abstract shape re...        654

# %% [markdown]
# ## Resume From Partial Output
#
# Load this notebook's saved partial results, skip rows that already completed in this split, and show the remaining work.
#
# - Reads: `batch_3/partials/*_results.csv`
# - Writes: Nothing
# - Rerun-safe: Yes. It is how this notebook resumes after interruption.

# %%
PARTIAL_FRAMES, _ = pipeline.load_partial_batch_outputs(BATCH_DIR, [PART_NAME])
PARTIAL_RESULTS_DF = PARTIAL_FRAMES.get(
    PART_NAME,
    pipeline.normalize_results_df(pd.DataFrame(columns=pipeline.RESULT_COLUMNS)),
)
COMPLETED_IDS = set(PARTIAL_RESULTS_DF["id"].tolist())
PENDING_DF = SLICE_DF[~SLICE_DF["id"].isin(COMPLETED_IDS)].copy().reset_index(drop=True)

print(f"Existing completed rows for {PART_NAME}: {len(PARTIAL_RESULTS_DF)}")
print(f"Pending rows for {PART_NAME}: {len(PENDING_DF)}")
if not PENDING_DF.empty:
    display(PENDING_DF[["id", "row_index"]].head(10))
# Out:
# Existing completed rows for batch_3a: 0
# Pending rows for batch_3a: 50
#                                  id  row_index
# 0  a2d1fb8c976851526db46bd0a62df319        650
# 1  7ab9719066edb519fc70aaeb07eb4e06        651
# 2  ff14e5ee37528d960a1d1bbb4df6f6af        652
# 3  87cde794689a999ad40b40ef03f88eba        653
# 4  eb25bd8aa69ff58fffe2f50db471c4a9        654
# 5  72eb0386899d377cdfcf670007ebfad4        655
# 6  929aa50770012fcc29ea7619e1979620        656
# 7  f7999d677294f41a6a77f628b2369578        657
# 8  4c8f301dc3b7a2b9427069599408694a        658
# 9  f6a0318b5669d8be1abf0fb0a67b3b3b        659

# %% [markdown]
# ## Load Model
#
# Load the base model plus the LoRA adapter into the current Colab GPU runtime for first-pass generation.
#
# - Reads: Base model on Hugging Face, LoRA adapter from repo
# - Writes: In-memory model state only
# - Rerun-safe: No. It is safe to rerun, but it reloads the model and costs time.

# %%
RUNTIME = pipeline.load_lora_runtime(PATHS.adapter_dir)
print(f"Loaded runtime on: {RUNTIME.runtime_device}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# Loaded runtime on: cuda

# %% [markdown]
# ## Deterministic First Pass With Partial Checkpoints
#
# Run one deterministic generation attempt per pending row in this split and checkpoint the split-specific partial CSVs every 10 rows.
#
# - Reads: Selected split rows, model runtime, existing partial outputs
# - Writes: `batch_3/partials/*` files for this split only
# - Rerun-safe: Yes. It resumes from this split's saved partial results.

# %%
records = PARTIAL_RESULTS_DF.to_dict(orient="records")
total_pending = len(PENDING_DF)

if total_pending == 0:
    print(f"{PART_NAME} is already complete. Rewriting the current partial artifacts for consistency.")
else:
    for local_index, row in enumerate(PENDING_DF.to_dict(orient="records"), start=1):
        row_id = row["id"]
        prompt = row["prompt"]
        row_index = int(row["row_index"])
        started_at = pipeline.time.perf_counter()
        try:
            prepared = pipeline.infer_svg_candidate(
                prompt,
                RUNTIME,
                generation_mode=GENERATION_MODE,
                config=CONFIG,
                allow_sampled_repair=False,
                progress_label=f"{PART_NAME} {local_index}/{total_pending}",
                row_id=row_id,
            )
            runtime_seconds = pipeline.time.perf_counter() - started_at
            record = pipeline.build_success_record(
                row_id,
                prompt,
                prepared,
                batch_id=str(BATCH_ID),
                row_index=row_index,
                generation_mode=GENERATION_MODE,
                first_pass_success=True,
                runtime_seconds=runtime_seconds,
            )
        except pipeline.RowInferenceError as exc:
            runtime_seconds = pipeline.time.perf_counter() - started_at
            record = pipeline.build_failed_record(
                row_id,
                prompt,
                exc,
                batch_id=str(BATCH_ID),
                row_index=row_index,
                generation_mode=GENERATION_MODE,
                first_pass_success=False,
                runtime_seconds=runtime_seconds,
            )
        records.append(record)
        if local_index % CHECKPOINT_EVERY == 0 or local_index == total_pending:
            PARTIAL_RESULTS_DF = pipeline.normalize_results_df(pd.DataFrame(records))
            PARTIAL_RESULTS_DF = PARTIAL_RESULTS_DF.sort_values("row_index").drop_duplicates(subset=["id"], keep="last")
            pipeline.save_partial_batch_outputs(PARTIAL_RESULTS_DF, BATCH_DIR, PART_NAME)
            print(
                f"Checkpointed {PART_NAME}: {len(PARTIAL_RESULTS_DF)}/{len(SLICE_DF)} rows saved to {PARTIAL_DIR}"
            )
        pipeline.release_runtime_memory()

PARTIAL_RESULTS_DF = pipeline.normalize_results_df(pd.DataFrame(records))
PARTIAL_RESULTS_DF = PARTIAL_RESULTS_DF.sort_values("row_index").drop_duplicates(subset=["id"], keep="last")
pipeline.save_partial_batch_outputs(PARTIAL_RESULTS_DF, BATCH_DIR, PART_NAME)
print(f"Wrote partial batch artifacts to: {PARTIAL_DIR}")
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [batch_3a 1/50] row a2d1fb8c976851526db46bd0a62df319: attempt 1/1 (deterministic)
# [batch_3a 1/50] row a2d1fb8c976851526db46bd0a62df319: success on attempt 1/1
# [batch_3a 2/50] row 7ab9719066edb519fc70aaeb07eb4e06: attempt 1/1 (deterministic)
# [batch_3a 2/50] row 7ab9719066edb519fc70aaeb07eb4e06: success on attempt 1/1
# [batch_3a 3/50] row ff14e5ee37528d960a1d1bbb4df6f6af: attempt 1/1 (deterministic)
# [batch_3a 3/50] row ff14e5ee37528d960a1d1bbb4df6f6af: success on attempt 1/1
# [batch_3a 4/50] row 87cde794689a999ad40b40ef03f88eba: attempt 1/1 (deterministic)
# [batch_3a 4/50] row 87cde794689a999ad40b40ef03f88eba: success on attempt 1/1
# [batch_3a 5/50] row eb25bd8aa69ff58fffe2f50db471c4a9: attempt 1/1 (deterministic)
# [batch_3a 5/50] row eb25bd8aa69ff58fffe2f50db471c4a9: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_3a 6/50] row 72eb0386899d377cdfcf670007ebfad4: attempt 1/1 (deterministic)
# [batch_3a 6/50] row 72eb0386899d377cdfcf670007ebfad4: attempt 1/1 failed: unclosed token: line 15, column 0
# [batch_3a 7/50] row 929aa50770012fcc29ea7619e1979620: attempt 1/1 (deterministic)
# [batch_3a 7/50] row 929aa50770012fcc29ea7619e1979620: success on attempt 1/1
# [batch_3a 8/50] row f7999d677294f41a6a77f628b2369578: attempt 1/1 (deterministic)
# [batch_3a 8/50] row f7999d677294f41a6a77f628b2369578: success on attempt 1/1
# [batch_3a 9/50] row 4c8f301dc3b7a2b9427069599408694a: attempt 1/1 (deterministic)
# [batch_3a 9/50] row 4c8f301dc3b7a2b9427069599408694a: success on attempt 1/1
# [batch_3a 10/50] row f6a0318b5669d8be1abf0fb0a67b3b3b: attempt 1/1 (deterministic)
# [batch_3a 10/50] row f6a0318b5669d8be1abf0fb0a67b3b3b: attempt 1/1 failed: unclosed token: line 22, column 0
# Checkpointed batch_3a: 10/50 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3a 11/50] row 112ba24ae9e0c6f096b9128625f8832c: attempt 1/1 (deterministic)
# [batch_3a 11/50] row 112ba24ae9e0c6f096b9128625f8832c: success on attempt 1/1
# [batch_3a 12/50] row b42bf4c9f5cff809206c1566a65665f6: attempt 1/1 (deterministic)
# [batch_3a 12/50] row b42bf4c9f5cff809206c1566a65665f6: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_3a 13/50] row 0a36304dec03e1ea2fcd956c4bb7d3a1: attempt 1/1 (deterministic)
# [batch_3a 13/50] row 0a36304dec03e1ea2fcd956c4bb7d3a1: attempt 1/1 failed: unclosed token: line 3, column 2
# [batch_3a 14/50] row fc0c62d5010d40dbdc422b9877477348: attempt 1/1 (deterministic)
# [batch_3a 14/50] row fc0c62d5010d40dbdc422b9877477348: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3a 15/50] row e5217d6123baf58c5d7ef460fe54cd7e: attempt 1/1 (deterministic)
# [batch_3a 15/50] row e5217d6123baf58c5d7ef460fe54cd7e: success on attempt 1/1
# [batch_3a 16/50] row bb003bdd403f4a9bad8b1c3b138f4060: attempt 1/1 (deterministic)
# [batch_3a 16/50] row bb003bdd403f4a9bad8b1c3b138f4060: success on attempt 1/1
# [batch_3a 17/50] row 2aa7a54fbec708d1adaa9f64f3da1336: attempt 1/1 (deterministic)
# [batch_3a 17/50] row 2aa7a54fbec708d1adaa9f64f3da1336: success on attempt 1/1
# [batch_3a 18/50] row f3a0e52f983b046e6f352e38d7089225: attempt 1/1 (deterministic)
# [batch_3a 18/50] row f3a0e52f983b046e6f352e38d7089225: success on attempt 1/1
# [batch_3a 19/50] row 93fcb2f3193c0a05e3e025c37b99ca8f: attempt 1/1 (deterministic)
# [batch_3a 19/50] row 93fcb2f3193c0a05e3e025c37b99ca8f: success on attempt 1/1
# [batch_3a 20/50] row 01632c497e0bafb8ff07907f753a0fa8: attempt 1/1 (deterministic)
# [batch_3a 20/50] row 01632c497e0bafb8ff07907f753a0fa8: attempt 1/1 failed: unclosed token: line 6, column 0
# Checkpointed batch_3a: 20/50 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3a 21/50] row a1546bb46e3d70ff4ebbb688ece1535f: attempt 1/1 (deterministic)
# [batch_3a 21/50] row a1546bb46e3d70ff4ebbb688ece1535f: attempt 1/1 failed: unclosed token: line 14, column 0
# [batch_3a 22/50] row c0a634bc156f907ad148fff33e08a797: attempt 1/1 (deterministic)
# [batch_3a 22/50] row c0a634bc156f907ad148fff33e08a797: success on attempt 1/1
# [batch_3a 23/50] row 9720d368bcaebe97328d60764b349438: attempt 1/1 (deterministic)
# [batch_3a 23/50] row 9720d368bcaebe97328d60764b349438: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3a 24/50] row 3cd203f594485bcf83054c3bebea8100: attempt 1/1 (deterministic)
# [batch_3a 24/50] row 3cd203f594485bcf83054c3bebea8100: attempt 1/1 failed: unclosed token: line 12, column 2
# [batch_3a 25/50] row 00f708cd3f4a7792afcfb4bc6dcb4017: attempt 1/1 (deterministic)
# [batch_3a 25/50] row 00f708cd3f4a7792afcfb4bc6dcb4017: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_3a 26/50] row 4af3c9ce4fd62efbbf0160a76f037b8d: attempt 1/1 (deterministic)
# [batch_3a 26/50] row 4af3c9ce4fd62efbbf0160a76f037b8d: attempt 1/1 failed: unclosed token: line 18, column 4
# [batch_3a 27/50] row 63b3422cb2fe74e70f8e15f723077655: attempt 1/1 (deterministic)
# [batch_3a 27/50] row 63b3422cb2fe74e70f8e15f723077655: success on attempt 1/1
# [batch_3a 28/50] row 9ee3b1227a90cc9040d89e482e25e68a: attempt 1/1 (deterministic)
# [batch_3a 28/50] row 9ee3b1227a90cc9040d89e482e25e68a: success on attempt 1/1
# [batch_3a 29/50] row 34031d8d633b61cb8e6c5adf5ca66906: attempt 1/1 (deterministic)
# [batch_3a 29/50] row 34031d8d633b61cb8e6c5adf5ca66906: attempt 1/1 failed: unclosed token: line 27, column 0
# [batch_3a 30/50] row c7b3eca840b6f51565368e521d493bf7: attempt 1/1 (deterministic)
# [batch_3a 30/50] row c7b3eca840b6f51565368e521d493bf7: success on attempt 1/1
# Checkpointed batch_3a: 30/50 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3a 31/50] row 8ff07cf9f7a1ac4cf1b990630c754913: attempt 1/1 (deterministic)
# [batch_3a 31/50] row 8ff07cf9f7a1ac4cf1b990630c754913: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3a 32/50] row ceb70ea6-74e0-4754-adbc-328208cd8ea3: attempt 1/1 (deterministic)
# [batch_3a 32/50] row ceb70ea6-74e0-4754-adbc-328208cd8ea3: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3a 33/50] row 0e2acc081df1ca0ea866498eb9da99ba: attempt 1/1 (deterministic)
# [batch_3a 33/50] row 0e2acc081df1ca0ea866498eb9da99ba: success on attempt 1/1
# [batch_3a 34/50] row 9bc27fa8e926dec612e192735d63911e: attempt 1/1 (deterministic)
# [batch_3a 34/50] row 9bc27fa8e926dec612e192735d63911e: success on attempt 1/1
# [batch_3a 35/50] row 2c381c4126788a6b95c9150dc3a8a3d7: attempt 1/1 (deterministic)
# [batch_3a 35/50] row 2c381c4126788a6b95c9150dc3a8a3d7: attempt 1/1 failed: unclosed token: line 21, column 0
# [batch_3a 36/50] row a039891794356a93f0b690fc9bdc1a54: attempt 1/1 (deterministic)
# [batch_3a 36/50] row a039891794356a93f0b690fc9bdc1a54: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3a 37/50] row 2de7509b-b4b1-44c9-b134-e79d09773c1a: attempt 1/1 (deterministic)
# [batch_3a 37/50] row 2de7509b-b4b1-44c9-b134-e79d09773c1a: success on attempt 1/1
# [batch_3a 38/50] row 31ad93a7cf6591716bbc0ce785f8bb71: attempt 1/1 (deterministic)
# [batch_3a 38/50] row 31ad93a7cf6591716bbc0ce785f8bb71: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3a 39/50] row 08bb21af456700fada1ac15ec4d32754: attempt 1/1 (deterministic)
# [batch_3a 39/50] row 08bb21af456700fada1ac15ec4d32754: attempt 1/1 failed: unclosed token: line 16, column 4
# [batch_3a 40/50] row 45edfe755f4b2466bbf0d84ea7d15401: attempt 1/1 (deterministic)
# [batch_3a 40/50] row 45edfe755f4b2466bbf0d84ea7d15401: attempt 1/1 failed: unclosed token: line 13, column 4
# Checkpointed batch_3a: 40/50 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3a 41/50] row 7b8fc50363222eaf0d9371d86bb448e7: attempt 1/1 (deterministic)
# [batch_3a 41/50] row 7b8fc50363222eaf0d9371d86bb448e7: success on attempt 1/1
# [batch_3a 42/50] row a9805813b67720210604c1200c2da2b6: attempt 1/1 (deterministic)
# [batch_3a 42/50] row a9805813b67720210604c1200c2da2b6: attempt 1/1 failed: unclosed token: line 15, column 4
# [batch_3a 43/50] row d3d3a5bc95f33a9ea00a407f3a8ee393: attempt 1/1 (deterministic)
# [batch_3a 43/50] row d3d3a5bc95f33a9ea00a407f3a8ee393: success on attempt 1/1
# [batch_3a 44/50] row 22e173a9-bc71-4d0d-84cf-1142060333ce: attempt 1/1 (deterministic)
# [batch_3a 44/50] row 22e173a9-bc71-4d0d-84cf-1142060333ce: attempt 1/1 failed: unclosed token: line 13, column 0
# [batch_3a 45/50] row dc5100694058a72a945a134e15530f0b: attempt 1/1 (deterministic)
# [batch_3a 45/50] row dc5100694058a72a945a134e15530f0b: success on attempt 1/1
# [batch_3a 46/50] row 72d63427fdc2f627b08d5dfaa6a9918e: attempt 1/1 (deterministic)
# [batch_3a 46/50] row 72d63427fdc2f627b08d5dfaa6a9918e: success on attempt 1/1
# [batch_3a 47/50] row 488042cf6eaa01e7845139e79a38e9fe: attempt 1/1 (deterministic)
# [batch_3a 47/50] row 488042cf6eaa01e7845139e79a38e9fe: success on attempt 1/1
# [batch_3a 48/50] row f9e624c0e186b0e0f75887c3e2131df1: attempt 1/1 (deterministic)
# [batch_3a 48/50] row f9e624c0e186b0e0f75887c3e2131df1: success on attempt 1/1
# [batch_3a 49/50] row 8a7cd1257fb803546c12a12cc321b485: attempt 1/1 (deterministic)
# [batch_3a 49/50] row 8a7cd1257fb803546c12a12cc321b485: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3a 50/50] row af7d4afb-4071-40e3-bcfe-2a5587e2dfe3: attempt 1/1 (deterministic)
# [batch_3a 50/50] row af7d4afb-4071-40e3-bcfe-2a5587e2dfe3: attempt 1/1 failed: no element found: line 19, column 51
# Checkpointed batch_3a: 50/50 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# Wrote partial batch artifacts to: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials

# %% [markdown]
# ## Split Summary
#
# Show the current success and failure totals for this split of batch 3.
#
# - Reads: In-memory partial results
# - Writes: Nothing
# - Rerun-safe: Yes. Read-only display cell.

# %%
display(pipeline.summarize_batch_results(PARTIAL_RESULTS_DF))
FAILED_DF = PARTIAL_RESULTS_DF[~PARTIAL_RESULTS_DF["first_pass_success"]].copy()
if FAILED_DF.empty:
    print("No failed rows in this split.")
else:
    display(FAILED_DF[["id", "row_index", "generation_mode", "gate_error"]].head(20))

# %% [markdown]
# ## Finalize Canonical Batch 3 Outputs
#
# If all three split notebooks have finished, combine the partial outputs into the normal `batch_3/*.csv` files expected by the merge notebook. Otherwise print which split is still missing.
#
# - Reads: `batch_3/partials/*`
# - Writes: Canonical `batch_3/*.csv` only when all three splits are present
# - Rerun-safe: Yes. It rewrites the canonical batch 3 files if all splits are ready.

# %%
FINALIZE_STATUS = pipeline.finalize_split_batch_outputs(BATCH_DIR, expected_row_count=250)
if FINALIZE_STATUS["ready"]:
    print("Canonical batch_3 files are now finalized.")
    print(
        f"Rows: {FINALIZE_STATUS['rows']} | row range: {FINALIZE_STATUS['first_row_index']}:{FINALIZE_STATUS['last_row_index']}"
    )
else:
    print("Waiting for the other split notebooks before writing canonical batch_3 files.")
    print(f"Missing partials: {FINALIZE_STATUS['missing_parts']}")
    print(f"Currently saved rows across available partials: {FINALIZE_STATUS['rows']}")
display(pipeline.artifact_status_table(PATHS, batch_count=4))
