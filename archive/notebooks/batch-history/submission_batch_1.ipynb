# %% [markdown]
# # First-Pass Batch 1
#
# This notebook handles the deterministic first pass for batch 1 of 4. It does not retry failed rows.

# %% [markdown]
# ## Drive And Repo Setup
#
# Mount Drive, clone the repo into the runtime, and copy the required CSV inputs into the checkout.
#
# - Reads: Google Drive, GitHub repo, runtime filesystem
# - Writes: `/content/svg-kaggle-comptetition`, Drive output root
# - Rerun-safe: Yes. It reclones the repo and recopies the inputs cleanly.

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path

from google.colab import drive

drive.mount("/content/drive")

GIT_REPO_URL = "https://github.com/Demetri65/svg-kaggle-competition-.git"
CHECKOUT_PATH = Path("/content/svg-kaggle-comptetition")
DRIVE_ROOT = Path("/content/drive/MyDrive")
OUTPUT_ROOT = DRIVE_ROOT / "svg-kaggle-comptetition" / "submission_outputs"

if CHECKOUT_PATH.exists():
    shutil.rmtree(CHECKOUT_PATH)
subprocess.check_call(["git", "clone", GIT_REPO_URL, str(CHECKOUT_PATH)])

for required_name in ["test.csv", "train.csv", "sample_submission.csv"]:
    destination = CHECKOUT_PATH / required_name
    if destination.exists():
        continue

    preferred_sources = [
        DRIVE_ROOT / "svg-kaggle-comptetition" / required_name,
        DRIVE_ROOT / "Colab Notebooks" / "svg-kaggle-comptetition" / required_name,
    ]
    copied = False
    for candidate in preferred_sources:
        if candidate.exists():
            shutil.copy2(candidate, destination)
            copied = True
            break
    if not copied:
        for candidate in DRIVE_ROOT.rglob(required_name):
            if candidate.is_file():
                shutil.copy2(candidate, destination)
                copied = True
                break
    if not copied:
        raise FileNotFoundError(
            f"Could not find {required_name} in Google Drive. Copy it into {CHECKOUT_PATH} manually and rerun this cell."
        )

os.environ["SVG_KAGGLE_REPO_ROOT"] = str(CHECKOUT_PATH)
sys.path.insert(0, str(CHECKOUT_PATH))
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

print(f"Repo checkout: {CHECKOUT_PATH}")
print(f"Drive output root: {OUTPUT_ROOT}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Repo checkout: /content/svg-kaggle-comptetition
# Drive output root: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs

# %% [markdown]
# ## Package Check
#
# Install any missing runtime packages required by the shared helper module and this notebook.
#
# - Reads: Current Python environment
# - Writes: Installed runtime packages
# - Rerun-safe: Yes. It only installs missing packages.

# %%
import importlib.util
import subprocess
import sys

REQUIRED_PACKAGES = {
    "pandas": "pandas",
    "numpy": "numpy",
    "torch": "torch",
    "transformers": "transformers",
    "peft": "peft",
    "accelerate": "accelerate",
    "cairosvg": "cairosvg",
    "skimage": "scikit-image",
    "PIL": "pillow",
}

missing_packages = [
    package_name
    for module_name, package_name in REQUIRED_PACKAGES.items()
    if importlib.util.find_spec(module_name) is None
]

if missing_packages:
    subprocess.check_call([sys.executable, "-m", "pip", "install", *missing_packages])
    print(f"Installed missing packages: {missing_packages}")
else:
    print("All required packages are already installed.")
# Out:
# All required packages are already installed.

# %% [markdown]
# ## Load Helpers, Recommendation, And Batch Slice
#
# Import the shared helper module, load the analysis recommendation, and select this notebook's fixed quarter of `test.csv`.
#
# - Reads: Repo checkout, helper module, analysis recommendation, competition CSV files
# - Writes: In-memory batch slice only
# - Rerun-safe: Yes. It is deterministic because the batch boundaries are fixed.

# %%
import json
import os
from pathlib import Path

import pandas as pd
from IPython.display import SVG, Markdown, display

import submission_pipeline as pipeline

pipeline.set_global_seed(1337)
PATHS = pipeline.resolve_pipeline_paths(Path(os.environ["SVG_KAGGLE_REPO_ROOT"]), OUTPUT_ROOT)
CONFIG = pipeline.GenerationConfig(verbose_progress=True)
TEST_DF, SAMPLE_SUBMISSION_DF, TRAIN_DF = pipeline.load_competition_frames(PATHS)

print(f"Repo root: {PATHS.repo_root}")
print(f"Output root: {PATHS.output_root}")

BATCH_ID = 1
ANALYSIS_RECOMMENDATION = pipeline.load_analysis_recommendation(PATHS)
GENERATION_MODE = ANALYSIS_RECOMMENDATION.get("recommended_generation_mode", "body_only")
BATCH_DF = pipeline.select_batch_df(TEST_DF, batch_id=BATCH_ID, batch_count=4)
BATCH_DIR = pipeline.batch_output_dir(PATHS, BATCH_ID)
print(f"Recommended generation mode: {GENERATION_MODE}")
print(f"Batch rows: {len(BATCH_DF)}")
display(BATCH_DF[["id", "prompt", "row_index"]].head())
# Out:
# Repo root: /content/svg-kaggle-comptetition
# Output root: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs
# Recommended generation mode: full_svg
# Batch rows: 250
#                                      id  \
# 0  fa1d8fa7-080f-4269-a9cf-a17562c9a0ca
# 1      6eede943219547c22ac56085027d33cc
# 2      ea045c7a247166f061ce504d9b7ccaab
# 3      8fe82f3af89e487b31236ca829c3f071
# 4      600464e4d92c75338462271a09b3f176
#
#                                               prompt  row_index
# 0  firewood stack cut logs wood with leaf illustr...          0
# 1  The image shows five horizontal lines of varyi...          1
# 2  A stylized icon depicting a curved arrow withi...          2
# 3  The image contains black geometric shapes agai...          3
# 4  The image shows a single dark gray triangle po...          4

# %% [markdown]
# ## Load Model
#
# Load the base model plus the LoRA adapter into the current Colab GPU runtime for first-pass generation.
#
# - Reads: Base model on Hugging Face, LoRA adapter from repo
# - Writes: In-memory model state only
# - Rerun-safe: No. It is safe to rerun, but it reloads the model and costs time.

# %%
RUNTIME = pipeline.load_lora_runtime(PATHS.adapter_dir)
print(f"Loaded runtime on: {RUNTIME.runtime_device}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# Loaded runtime on: cuda

# %% [markdown]
# ## Deterministic First Pass
#
# Run one deterministic generation attempt per row in this batch and save the success/failure artifacts for the merge notebook.
#
# - Reads: Selected batch rows, model runtime
# - Writes: Batch output CSV artifacts under this batch directory
# - Rerun-safe: Yes. It recomputes and overwrites this batch's artifacts.

# %%
FIRST_PASS_RESULTS_DF = pipeline.run_first_pass_batch(
    BATCH_DF,
    RUNTIME,
    batch_id=BATCH_ID,
    generation_mode=GENERATION_MODE,
    config=CONFIG,
)
pipeline.save_batch_outputs(FIRST_PASS_RESULTS_DF, BATCH_DIR)
print(f"Wrote batch artifacts to: {BATCH_DIR}")
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [batch_1 1/250] row fa1d8fa7-080f-4269-a9cf-a17562c9a0ca: attempt 1/1 (deterministic)
# [batch_1 1/250] row fa1d8fa7-080f-4269-a9cf-a17562c9a0ca: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 2/250] row 6eede943219547c22ac56085027d33cc: attempt 1/1 (deterministic)
# [batch_1 2/250] row 6eede943219547c22ac56085027d33cc: success on attempt 1/1
# [batch_1 3/250] row ea045c7a247166f061ce504d9b7ccaab: attempt 1/1 (deterministic)
# [batch_1 3/250] row ea045c7a247166f061ce504d9b7ccaab: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_1 4/250] row 8fe82f3af89e487b31236ca829c3f071: attempt 1/1 (deterministic)
# [batch_1 4/250] row 8fe82f3af89e487b31236ca829c3f071: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 5/250] row 600464e4d92c75338462271a09b3f176: attempt 1/1 (deterministic)
# [batch_1 5/250] row 600464e4d92c75338462271a09b3f176: success on attempt 1/1
# [batch_1 6/250] row 9e831fb6831745f4d15156b7a95e4f92: attempt 1/1 (deterministic)
# [batch_1 6/250] row 9e831fb6831745f4d15156b7a95e4f92: success on attempt 1/1
# [batch_1 7/250] row 8cbefcd53fd5dfa2cbe1b374356ed709: attempt 1/1 (deterministic)
# [batch_1 7/250] row 8cbefcd53fd5dfa2cbe1b374356ed709: attempt 1/1 failed: unclosed token: line 18, column 4
# [batch_1 8/250] row 625181a2-600d-4db5-83c6-1a34676eb0dc: attempt 1/1 (deterministic)
# [batch_1 8/250] row 625181a2-600d-4db5-83c6-1a34676eb0dc: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 9/250] row 8ba1bd7c-211c-43b0-a4aa-0e6e33c92486: attempt 1/1 (deterministic)
# [batch_1 9/250] row 8ba1bd7c-211c-43b0-a4aa-0e6e33c92486: success on attempt 1/1
# [batch_1 10/250] row 4e56e508270eb0d02291927638d3c685: attempt 1/1 (deterministic)
# [batch_1 10/250] row 4e56e508270eb0d02291927638d3c685: success on attempt 1/1
# [batch_1 11/250] row bef2864d9a862b7436c73435346f1c64: attempt 1/1 (deterministic)
# [batch_1 11/250] row bef2864d9a862b7436c73435346f1c64: success on attempt 1/1
# [batch_1 12/250] row 7f11068772653f283977d9c2f5612a02: attempt 1/1 (deterministic)
# [batch_1 12/250] row 7f11068772653f283977d9c2f5612a02: success on attempt 1/1
# [batch_1 13/250] row cc1df4dd3f0cc361daa667ee0f05eaf7: attempt 1/1 (deterministic)
# [batch_1 13/250] row cc1df4dd3f0cc361daa667ee0f05eaf7: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 14/250] row 8821c406-676c-4fdf-b18f-fe01c00d793f: attempt 1/1 (deterministic)
# [batch_1 14/250] row 8821c406-676c-4fdf-b18f-fe01c00d793f: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 15/250] row 8390a1ddd68fc7de495d11dffab32031: attempt 1/1 (deterministic)
# [batch_1 15/250] row 8390a1ddd68fc7de495d11dffab32031: attempt 1/1 failed: unclosed token: line 8, column 4
# [batch_1 16/250] row 48fba8b033c732c00f1a288dfc34aedc: attempt 1/1 (deterministic)
# [batch_1 16/250] row 48fba8b033c732c00f1a288dfc34aedc: attempt 1/1 failed: unclosed token: line 7, column 0
# [batch_1 17/250] row 1d800968d7d3aa76b9e097cee61fbe60: attempt 1/1 (deterministic)
# [batch_1 17/250] row 1d800968d7d3aa76b9e097cee61fbe60: success on attempt 1/1
# [batch_1 18/250] row 5f4a048069086cff1d5f8d424af1b8ca: attempt 1/1 (deterministic)
# [batch_1 18/250] row 5f4a048069086cff1d5f8d424af1b8ca: attempt 1/1 failed: unclosed token: line 18, column 0
# [batch_1 19/250] row 363e052b0457c60892eab6c887dd5b27: attempt 1/1 (deterministic)
# [batch_1 19/250] row 363e052b0457c60892eab6c887dd5b27: attempt 1/1 failed: unclosed token: line 17, column 0
# [batch_1 20/250] row d942c8be4045344396e6a113f7c58a3f: attempt 1/1 (deterministic)
# [batch_1 20/250] row d942c8be4045344396e6a113f7c58a3f: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 21/250] row 5486017c6c4d153449d07c7c4f7afbd4: attempt 1/1 (deterministic)
# [batch_1 21/250] row 5486017c6c4d153449d07c7c4f7afbd4: success on attempt 1/1
# [batch_1 22/250] row 7e63b44725fd31b7ee98d8ba88fe29cd: attempt 1/1 (deterministic)
# [batch_1 22/250] row 7e63b44725fd31b7ee98d8ba88fe29cd: attempt 1/1 failed: unclosed token: line 7, column 0
# [batch_1 23/250] row 75ea7d1de57013d3d210046f6cec14d5: attempt 1/1 (deterministic)
# [batch_1 23/250] row 75ea7d1de57013d3d210046f6cec14d5: attempt 1/1 failed: unclosed token: line 3, column 2
# [batch_1 24/250] row 9bda86e2078baf4d4fa15be8de3bcdce: attempt 1/1 (deterministic)
# [batch_1 24/250] row 9bda86e2078baf4d4fa15be8de3bcdce: success on attempt 1/1
# [batch_1 25/250] row 5847d7d98926031f8b9ca1eb61fa7163: attempt 1/1 (deterministic)
# [batch_1 25/250] row 5847d7d98926031f8b9ca1eb61fa7163: success on attempt 1/1
# [batch_1 26/250] row c97c8f66ce177e81c529de16b5bd4118: attempt 1/1 (deterministic)
# [batch_1 26/250] row c97c8f66ce177e81c529de16b5bd4118: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 27/250] row e41ccb9c836340147df2ccb127e8dde6: attempt 1/1 (deterministic)
# [batch_1 27/250] row e41ccb9c836340147df2ccb127e8dde6: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_1 28/250] row 1bb91e93-817e-484d-859c-428ec68c30f9: attempt 1/1 (deterministic)
# [batch_1 28/250] row 1bb91e93-817e-484d-859c-428ec68c30f9: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 29/250] row 643a84fa96883ea934fdf60cd6b58513: attempt 1/1 (deterministic)
# [batch_1 29/250] row 643a84fa96883ea934fdf60cd6b58513: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_1 30/250] row 7116d593ba10694dbf864f192ff2f07b: attempt 1/1 (deterministic)
# [batch_1 30/250] row 7116d593ba10694dbf864f192ff2f07b: success on attempt 1/1
# [batch_1 31/250] row d14ffebbc58e451c3d713e66e59414e0: attempt 1/1 (deterministic)
# [batch_1 31/250] row d14ffebbc58e451c3d713e66e59414e0: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_1 32/250] row 42ec3240e21ab822adca80d09707c527: attempt 1/1 (deterministic)
# [batch_1 32/250] row 42ec3240e21ab822adca80d09707c527: attempt 1/1 failed: unclosed token: line 23, column 4
# [batch_1 33/250] row fb7d61688fa296dea40d7e579db49428: attempt 1/1 (deterministic)
# [batch_1 33/250] row fb7d61688fa296dea40d7e579db49428: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_1 34/250] row 2dc79da3-62ee-49ab-815d-ebcd832cfd2d: attempt 1/1 (deterministic)
# [batch_1 34/250] row 2dc79da3-62ee-49ab-815d-ebcd832cfd2d: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 35/250] row 1d716bd624982a0e450cbdd9abbc21f6: attempt 1/1 (deterministic)
# [batch_1 35/250] row 1d716bd624982a0e450cbdd9abbc21f6: success on attempt 1/1
# [batch_1 36/250] row c323393eac394f19afec9f714b63976d: attempt 1/1 (deterministic)
# [batch_1 36/250] row c323393eac394f19afec9f714b63976d: success on attempt 1/1
# [batch_1 37/250] row 25ac054b53cc1e9443ba87fbb4f3f25d: attempt 1/1 (deterministic)
# [batch_1 37/250] row 25ac054b53cc1e9443ba87fbb4f3f25d: success on attempt 1/1
# [batch_1 38/250] row 8aeed0decb8802edd77fde5e026eb915: attempt 1/1 (deterministic)
# [batch_1 38/250] row 8aeed0decb8802edd77fde5e026eb915: success on attempt 1/1
# [batch_1 39/250] row 81ef4bd0b6d6d5e1980b8e39646d5097: attempt 1/1 (deterministic)
# [batch_1 39/250] row 81ef4bd0b6d6d5e1980b8e39646d5097: success on attempt 1/1
# [batch_1 40/250] row 4a77266da26727f9ae4858d0a368d168: attempt 1/1 (deterministic)
# [batch_1 40/250] row 4a77266da26727f9ae4858d0a368d168: success on attempt 1/1
# [batch_1 41/250] row e3eb16f93299028540e0ca713c279086: attempt 1/1 (deterministic)
# [batch_1 41/250] row e3eb16f93299028540e0ca713c279086: success on attempt 1/1
# [batch_1 42/250] row 8d4aea82-e57e-4019-aff5-c8383c34c2a3: attempt 1/1 (deterministic)
# [batch_1 42/250] row 8d4aea82-e57e-4019-aff5-c8383c34c2a3: success on attempt 1/1
# [batch_1 43/250] row 42774b275712fad4243e86e2805aadc6: attempt 1/1 (deterministic)
# [batch_1 43/250] row 42774b275712fad4243e86e2805aadc6: attempt 1/1 failed: unclosed token: line 4, column 0
# [batch_1 44/250] row 46985c942079349b8c4d5fcc20999368: attempt 1/1 (deterministic)
# [batch_1 44/250] row 46985c942079349b8c4d5fcc20999368: success on attempt 1/1
# [batch_1 45/250] row e3e0fff5ead535daf599d302dd645b45: attempt 1/1 (deterministic)
# [batch_1 45/250] row e3e0fff5ead535daf599d302dd645b45: success on attempt 1/1
# [batch_1 46/250] row 912205c69e8d840c623389740a95c61c: attempt 1/1 (deterministic)
# [batch_1 46/250] row 912205c69e8d840c623389740a95c61c: success on attempt 1/1
# [batch_1 47/250] row 73d9382bff01f823b41e1b5956f067d9: attempt 1/1 (deterministic)
# [batch_1 47/250] row 73d9382bff01f823b41e1b5956f067d9: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_1 48/250] row 53265889-a906-470a-8717-f3af3c5e5ccd: attempt 1/1 (deterministic)
# [batch_1 48/250] row 53265889-a906-470a-8717-f3af3c5e5ccd: attempt 1/1 failed: unclosed token: line 7, column 0
# [batch_1 49/250] row b1ca02cfeedcd872a55c70ce6b3ff09c: attempt 1/1 (deterministic)
# [batch_1 49/250] row b1ca02cfeedcd872a55c70ce6b3ff09c: attempt 1/1 failed: unclosed token: line 4, column 4
# [batch_1 50/250] row thesantatitan_deepseek-svg-dataset_0004683: attempt 1/1 (deterministic)
# [batch_1 50/250] row thesantatitan_deepseek-svg-dataset_0004683: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_1 51/250] row thesantatitan_deepseek-svg-dataset_0003059: attempt 1/1 (deterministic)
# [batch_1 51/250] row thesantatitan_deepseek-svg-dataset_0003059: success on attempt 1/1
# [batch_1 52/250] row 2ee5815d274c932d7595db413c0d45a8: attempt 1/1 (deterministic)
# [batch_1 52/250] row 2ee5815d274c932d7595db413c0d45a8: attempt 1/1 failed: unclosed token: line 15, column 4
# [batch_1 53/250] row 22c9af1ee5c39d0f2c1cfced7b303b31: attempt 1/1 (deterministic)
# [batch_1 53/250] row 22c9af1ee5c39d0f2c1cfced7b303b31: success on attempt 1/1
# [batch_1 54/250] row 6ffc093dac031f57dedbff4c54ad6b53: attempt 1/1 (deterministic)
# [batch_1 54/250] row 6ffc093dac031f57dedbff4c54ad6b53: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 55/250] row 3307888a6e369e7b8fe8f97b1d5ca059: attempt 1/1 (deterministic)
# [batch_1 55/250] row 3307888a6e369e7b8fe8f97b1d5ca059: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 56/250] row thesantatitan_deepseek-svg-dataset_0003803: attempt 1/1 (deterministic)
# [batch_1 56/250] row thesantatitan_deepseek-svg-dataset_0003803: success on attempt 1/1
# [batch_1 57/250] row thesantatitan_deepseek-svg-dataset_0001862: attempt 1/1 (deterministic)
# [batch_1 57/250] row thesantatitan_deepseek-svg-dataset_0001862: success on attempt 1/1
# [batch_1 58/250] row d3662fd819d68f1d3ea300f7ffbafaf1: attempt 1/1 (deterministic)
# [batch_1 58/250] row d3662fd819d68f1d3ea300f7ffbafaf1: success on attempt 1/1
# [batch_1 59/250] row 805e13c9-09d2-4828-a754-1939092246f4: attempt 1/1 (deterministic)
# [batch_1 59/250] row 805e13c9-09d2-4828-a754-1939092246f4: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 60/250] row f317b1db71a938871c811c8e3a64ff78: attempt 1/1 (deterministic)
# [batch_1 60/250] row f317b1db71a938871c811c8e3a64ff78: success on attempt 1/1
# [batch_1 61/250] row de3d096a9919e2d36bfab7d98f12471b: attempt 1/1 (deterministic)
# [batch_1 61/250] row de3d096a9919e2d36bfab7d98f12471b: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 62/250] row 6a23eaf9af94f1dc2c6757965b09958b: attempt 1/1 (deterministic)
# [batch_1 62/250] row 6a23eaf9af94f1dc2c6757965b09958b: success on attempt 1/1
# [batch_1 63/250] row f82a1d17293a309f41c745a2dd9e3057: attempt 1/1 (deterministic)
# [batch_1 63/250] row f82a1d17293a309f41c745a2dd9e3057: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_1 64/250] row 36395e670d119b48df4895776d5b74c2: attempt 1/1 (deterministic)
# [batch_1 64/250] row 36395e670d119b48df4895776d5b74c2: attempt 1/1 failed: unclosed token: line 19, column 4
# [batch_1 65/250] row 0feb0f573c27675b0d3a4d9a314f8127: attempt 1/1 (deterministic)
# [batch_1 65/250] row 0feb0f573c27675b0d3a4d9a314f8127: success on attempt 1/1
# [batch_1 66/250] row 580d7d5cdf416645f13d6d9e3aa2590b: attempt 1/1 (deterministic)
# [batch_1 66/250] row 580d7d5cdf416645f13d6d9e3aa2590b: success on attempt 1/1
# [batch_1 67/250] row fa6ccf7e-9549-47c5-8c05-0b96ec5d56f3: attempt 1/1 (deterministic)
# [batch_1 67/250] row fa6ccf7e-9549-47c5-8c05-0b96ec5d56f3: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_1 68/250] row a0e1e594-d8ab-43e1-a395-eeb8db7132a5: attempt 1/1 (deterministic)
# [batch_1 68/250] row a0e1e594-d8ab-43e1-a395-eeb8db7132a5: success on attempt 1/1
# [batch_1 69/250] row c8d9f86a253c3316308f642ebf1df890: attempt 1/1 (deterministic)
# [batch_1 69/250] row c8d9f86a253c3316308f642ebf1df890: success on attempt 1/1
# [batch_1 70/250] row 6533809323284ce30427cde779fff269: attempt 1/1 (deterministic)
# [batch_1 70/250] row 6533809323284ce30427cde779fff269: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 71/250] row db5e492cdd2ef3eff0a1a5798a2e1e03: attempt 1/1 (deterministic)
# [batch_1 71/250] row db5e492cdd2ef3eff0a1a5798a2e1e03: attempt 1/1 failed: unclosed token: line 14, column 4
# [batch_1 72/250] row 18626b764590055f2aae6292fd38df50: attempt 1/1 (deterministic)
# [batch_1 72/250] row 18626b764590055f2aae6292fd38df50: success on attempt 1/1
# [batch_1 73/250] row af5c92c5dd805ba882bf2cf71f1c0da5: attempt 1/1 (deterministic)
# [batch_1 73/250] row af5c92c5dd805ba882bf2cf71f1c0da5: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 74/250] row 6514c1d3e873cde2d0b364aa72b94b03: attempt 1/1 (deterministic)
# [batch_1 74/250] row 6514c1d3e873cde2d0b364aa72b94b03: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 75/250] row 85a815b47e2f89ffeb68de032151f56d: attempt 1/1 (deterministic)
# [batch_1 75/250] row 85a815b47e2f89ffeb68de032151f56d: success on attempt 1/1
# [batch_1 76/250] row 8f92d1229080b7ce7b1fcec21cb213db: attempt 1/1 (deterministic)
# [batch_1 76/250] row 8f92d1229080b7ce7b1fcec21cb213db: success on attempt 1/1
# [batch_1 77/250] row 1bfff390-28ce-4d73-85d4-0c58113fdd88: attempt 1/1 (deterministic)
# [batch_1 77/250] row 1bfff390-28ce-4d73-85d4-0c58113fdd88: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 78/250] row 7768eaa8d8a3f4de8d722af327e6e4fa: attempt 1/1 (deterministic)
# [batch_1 78/250] row 7768eaa8d8a3f4de8d722af327e6e4fa: success on attempt 1/1
# [batch_1 79/250] row 959e0c49460d7355330faa5fc6966fa6: attempt 1/1 (deterministic)
# [batch_1 79/250] row 959e0c49460d7355330faa5fc6966fa6: success on attempt 1/1
# [batch_1 80/250] row 86eb9093f8e49aba9fee562bd0701ed4: attempt 1/1 (deterministic)
# [batch_1 80/250] row 86eb9093f8e49aba9fee562bd0701ed4: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_1 81/250] row e9ffd3297260257322b15ba6510e836e: attempt 1/1 (deterministic)
# [batch_1 81/250] row e9ffd3297260257322b15ba6510e836e: success on attempt 1/1
# [batch_1 82/250] row 0fddcd7d7cc5f4e47d3593536e7f797e: attempt 1/1 (deterministic)
# [batch_1 82/250] row 0fddcd7d7cc5f4e47d3593536e7f797e: success on attempt 1/1
# [batch_1 83/250] row 58851b06-b2b9-4a7e-96f4-c057ecfcb03e: attempt 1/1 (deterministic)
# [batch_1 83/250] row 58851b06-b2b9-4a7e-96f4-c057ecfcb03e: success on attempt 1/1
# [batch_1 84/250] row afc35e09-e0b3-4005-85a6-5b9ea92ffc44: attempt 1/1 (deterministic)
# [batch_1 84/250] row afc35e09-e0b3-4005-85a6-5b9ea92ffc44: success on attempt 1/1
# [batch_1 85/250] row dd69f2cfb431fdf4ced08f7255dd6970: attempt 1/1 (deterministic)
# [batch_1 85/250] row dd69f2cfb431fdf4ced08f7255dd6970: success on attempt 1/1
# [batch_1 86/250] row 6f4c365ad0d7bba6930c3f3633213f66: attempt 1/1 (deterministic)
# [batch_1 86/250] row 6f4c365ad0d7bba6930c3f3633213f66: success on attempt 1/1
# [batch_1 87/250] row 43538b024f1f60fe918a5bf3940aea9f: attempt 1/1 (deterministic)
# [batch_1 87/250] row 43538b024f1f60fe918a5bf3940aea9f: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_1 88/250] row df01f46bd358f107b4919b94efb0b365: attempt 1/1 (deterministic)
# [batch_1 88/250] row df01f46bd358f107b4919b94efb0b365: attempt 1/1 failed: unclosed token: line 18, column 0
# [batch_1 89/250] row 58b9421f28c24d526023e8b1b2493325: attempt 1/1 (deterministic)
# [batch_1 89/250] row 58b9421f28c24d526023e8b1b2493325: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_1 90/250] row 4a968506f2c7f3da659a1d8cdc568ddd: attempt 1/1 (deterministic)
# [batch_1 90/250] row 4a968506f2c7f3da659a1d8cdc568ddd: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_1 91/250] row 832a8032c3da6573c5530a5f6537486a: attempt 1/1 (deterministic)
# [batch_1 91/250] row 832a8032c3da6573c5530a5f6537486a: success on attempt 1/1
# [batch_1 92/250] row 9e331a32e09fbc708dea49b88027cd6e: attempt 1/1 (deterministic)
# [batch_1 92/250] row 9e331a32e09fbc708dea49b88027cd6e: success on attempt 1/1
# [batch_1 93/250] row 3ab946716c079e386eae3c608eb3e510: attempt 1/1 (deterministic)
# [batch_1 93/250] row 3ab946716c079e386eae3c608eb3e510: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_1 94/250] row 1b80bd25-ccb4-4041-9895-142e59610944: attempt 1/1 (deterministic)
# [batch_1 94/250] row 1b80bd25-ccb4-4041-9895-142e59610944: success on attempt 1/1
# [batch_1 95/250] row 89aef77e14a596edcf6a61dc687e18f2: attempt 1/1 (deterministic)
# [batch_1 95/250] row 89aef77e14a596edcf6a61dc687e18f2: success on attempt 1/1
# [batch_1 96/250] row 2efc5bf83782701ffe988db621c4bef9: attempt 1/1 (deterministic)
# [batch_1 96/250] row 2efc5bf83782701ffe988db621c4bef9: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_1 97/250] row 69c33b61d96656ff61ed82d455d9142b: attempt 1/1 (deterministic)
# [batch_1 97/250] row 69c33b61d96656ff61ed82d455d9142b: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 98/250] row 3c0fc1a44e3b6a8aaae3f7daacfccc90: attempt 1/1 (deterministic)
# [batch_1 98/250] row 3c0fc1a44e3b6a8aaae3f7daacfccc90: success on attempt 1/1
# [batch_1 99/250] row 41326c8540b89371b2ac41cd1ce06b32: attempt 1/1 (deterministic)
# [batch_1 99/250] row 41326c8540b89371b2ac41cd1ce06b32: success on attempt 1/1
# [batch_1 100/250] row thesantatitan_deepseek-svg-dataset_0003427: attempt 1/1 (deterministic)
# [batch_1 100/250] row thesantatitan_deepseek-svg-dataset_0003427: success on attempt 1/1
# [batch_1 101/250] row 7fc400bb5e93c44d6b63d0fdc6e0ff14: attempt 1/1 (deterministic)
# [batch_1 101/250] row 7fc400bb5e93c44d6b63d0fdc6e0ff14: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 102/250] row 9e72c6dd78d3115435efdd77656d9cf7: attempt 1/1 (deterministic)
# [batch_1 102/250] row 9e72c6dd78d3115435efdd77656d9cf7: attempt 1/1 failed: unclosed token: line 3, column 2
# [batch_1 103/250] row 2083ff4e29756f813951e64909f79e87: attempt 1/1 (deterministic)
# [batch_1 103/250] row 2083ff4e29756f813951e64909f79e87: success on attempt 1/1
# [batch_1 104/250] row a3f7d55f98b9f4650982837716e45558: attempt 1/1 (deterministic)
# [batch_1 104/250] row a3f7d55f98b9f4650982837716e45558: success on attempt 1/1
# [batch_1 105/250] row 51638adddbb17dd52b7a860d091afea2: attempt 1/1 (deterministic)
# [batch_1 105/250] row 51638adddbb17dd52b7a860d091afea2: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 106/250] row 8edb2eb8e91319b38e0861e57637f9be: attempt 1/1 (deterministic)
# [batch_1 106/250] row 8edb2eb8e91319b38e0861e57637f9be: success on attempt 1/1
# [batch_1 107/250] row 868eb1cfe38c855f29c42910408a503f: attempt 1/1 (deterministic)
# [batch_1 107/250] row 868eb1cfe38c855f29c42910408a503f: attempt 1/1 failed: unclosed token: line 13, column 4
# [batch_1 108/250] row 11a27a3b6cf29b26cfb4e9705a0f2b91: attempt 1/1 (deterministic)
# [batch_1 108/250] row 11a27a3b6cf29b26cfb4e9705a0f2b91: success on attempt 1/1
# [batch_1 109/250] row e1f2704ae308f86cfd5a65dce745e37a: attempt 1/1 (deterministic)
# [batch_1 109/250] row e1f2704ae308f86cfd5a65dce745e37a: success on attempt 1/1
# [batch_1 110/250] row 963bb1df7ab893b87b41941827c22f17: attempt 1/1 (deterministic)
# [batch_1 110/250] row 963bb1df7ab893b87b41941827c22f17: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 111/250] row 4b5eeb0941380dab5e4b7c21a36902b0: attempt 1/1 (deterministic)
# [batch_1 111/250] row 4b5eeb0941380dab5e4b7c21a36902b0: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_1 112/250] row eba7feb3013e23adb23aa8432b5c6e40: attempt 1/1 (deterministic)
# [batch_1 112/250] row eba7feb3013e23adb23aa8432b5c6e40: success on attempt 1/1
# [batch_1 113/250] row 4e355e35dc8edb95b514e3487a9e13f4: attempt 1/1 (deterministic)
# [batch_1 113/250] row 4e355e35dc8edb95b514e3487a9e13f4: attempt 1/1 failed: unclosed token: line 7, column 0
# [batch_1 114/250] row b3e6d797f017ecf5c69db1bc13ea6505: attempt 1/1 (deterministic)
# [batch_1 114/250] row b3e6d797f017ecf5c69db1bc13ea6505: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 115/250] row b7b04b9f8a1071aba9fe8401fad79678: attempt 1/1 (deterministic)
# [batch_1 115/250] row b7b04b9f8a1071aba9fe8401fad79678: attempt 1/1 failed: unclosed token: line 13, column 0
# [batch_1 116/250] row f8442c8dd7a2c3d1ae8c7c1f2ea9a253: attempt 1/1 (deterministic)
# [batch_1 116/250] row f8442c8dd7a2c3d1ae8c7c1f2ea9a253: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 117/250] row 59ba28b82776364e6d5c9b82b1ca33b4: attempt 1/1 (deterministic)
# [batch_1 117/250] row 59ba28b82776364e6d5c9b82b1ca33b4: success on attempt 1/1
# [batch_1 118/250] row 91348c0b0c69183ca7a5ce0c14d33d4c: attempt 1/1 (deterministic)
# [batch_1 118/250] row 91348c0b0c69183ca7a5ce0c14d33d4c: success on attempt 1/1
# [batch_1 119/250] row thesantatitan_deepseek-svg-dataset_0002981: attempt 1/1 (deterministic)
# [batch_1 119/250] row thesantatitan_deepseek-svg-dataset_0002981: success on attempt 1/1
# [batch_1 120/250] row 501d22e95eb0f1a021b4cbd657a09f60: attempt 1/1 (deterministic)
# [batch_1 120/250] row 501d22e95eb0f1a021b4cbd657a09f60: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 121/250] row f22a95ed-6e0b-40b4-bab4-03d1813e32ce: attempt 1/1 (deterministic)
# [batch_1 121/250] row f22a95ed-6e0b-40b4-bab4-03d1813e32ce: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_1 122/250] row a90ccfad4269a659725a078c9c3385e0: attempt 1/1 (deterministic)
# [batch_1 122/250] row a90ccfad4269a659725a078c9c3385e0: success on attempt 1/1
# [batch_1 123/250] row cca98eb919e4d42b9402b9a15ab7a27f: attempt 1/1 (deterministic)
# [batch_1 123/250] row cca98eb919e4d42b9402b9a15ab7a27f: success on attempt 1/1
# [batch_1 124/250] row 9c714437b101a275aa57869f2fe83aa5: attempt 1/1 (deterministic)
# [batch_1 124/250] row 9c714437b101a275aa57869f2fe83aa5: success on attempt 1/1
# [batch_1 125/250] row thesantatitan_deepseek-svg-dataset_0002054: attempt 1/1 (deterministic)
# [batch_1 125/250] row thesantatitan_deepseek-svg-dataset_0002054: success on attempt 1/1
# [batch_1 126/250] row c1ed0cae3affe5b41eafffb724da4eff: attempt 1/1 (deterministic)
# [batch_1 126/250] row c1ed0cae3affe5b41eafffb724da4eff: success on attempt 1/1
# [batch_1 127/250] row c954181c0f7068dfa557d5fa204a9ab3: attempt 1/1 (deterministic)
# [batch_1 127/250] row c954181c0f7068dfa557d5fa204a9ab3: success on attempt 1/1
# [batch_1 128/250] row ef0950dbc0cfd0a6b9e64593180580ee: attempt 1/1 (deterministic)
# [batch_1 128/250] row ef0950dbc0cfd0a6b9e64593180580ee: success on attempt 1/1
# [batch_1 129/250] row 99dd6d71-6ed3-4053-be6f-8fe2586fd599: attempt 1/1 (deterministic)
# [batch_1 129/250] row 99dd6d71-6ed3-4053-be6f-8fe2586fd599: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 130/250] row 55d6d473c725fbb1de811c9d2afdaa8c: attempt 1/1 (deterministic)
# [batch_1 130/250] row 55d6d473c725fbb1de811c9d2afdaa8c: success on attempt 1/1
# [batch_1 131/250] row d1357835-8e25-45f8-80ed-5c93caafd8ff: attempt 1/1 (deterministic)
# [batch_1 131/250] row d1357835-8e25-45f8-80ed-5c93caafd8ff: attempt 1/1 failed: unclosed token: line 12, column 0
# [batch_1 132/250] row c4faf634-3023-4cec-b1d1-9e27c09ec28a: attempt 1/1 (deterministic)
# [batch_1 132/250] row c4faf634-3023-4cec-b1d1-9e27c09ec28a: success on attempt 1/1
# [batch_1 133/250] row 23fd0372-c4df-42f1-b3ba-d5b26911afd7: attempt 1/1 (deterministic)
# [batch_1 133/250] row 23fd0372-c4df-42f1-b3ba-d5b26911afd7: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 134/250] row d3e7f6cc778c47961ce4efeb7829f5f0: attempt 1/1 (deterministic)
# [batch_1 134/250] row d3e7f6cc778c47961ce4efeb7829f5f0: success on attempt 1/1
# [batch_1 135/250] row thesantatitan_deepseek-svg-dataset_0002855: attempt 1/1 (deterministic)
# [batch_1 135/250] row thesantatitan_deepseek-svg-dataset_0002855: success on attempt 1/1
# [batch_1 136/250] row 10f4ee45-455b-4a12-af4c-4ad671cc88cc: attempt 1/1 (deterministic)
# [batch_1 136/250] row 10f4ee45-455b-4a12-af4c-4ad671cc88cc: attempt 1/1 failed: unclosed token: line 20, column 4
# [batch_1 137/250] row 9d9983d2944a72fc057c2c1e38520157: attempt 1/1 (deterministic)
# [batch_1 137/250] row 9d9983d2944a72fc057c2c1e38520157: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 138/250] row ae8f7c626b4d5dcc1e9f3ba1ec56d8db: attempt 1/1 (deterministic)
# [batch_1 138/250] row ae8f7c626b4d5dcc1e9f3ba1ec56d8db: success on attempt 1/1
# [batch_1 139/250] row 8a256a06888539b2276f0728b298bcf6: attempt 1/1 (deterministic)
# [batch_1 139/250] row 8a256a06888539b2276f0728b298bcf6: success on attempt 1/1
# [batch_1 140/250] row f1483a452ca6724ef63ee11ca94fb4b9: attempt 1/1 (deterministic)
# [batch_1 140/250] row f1483a452ca6724ef63ee11ca94fb4b9: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 141/250] row 4f373ffabc552ec0ac5d7f039c79e730: attempt 1/1 (deterministic)
# [batch_1 141/250] row 4f373ffabc552ec0ac5d7f039c79e730: success on attempt 1/1
# [batch_1 142/250] row a76889ab492cb7974e73d5a0b1b02d01: attempt 1/1 (deterministic)
# [batch_1 142/250] row a76889ab492cb7974e73d5a0b1b02d01: success on attempt 1/1
# [batch_1 143/250] row 2a5ed734fc8b884fb29017f2b145469e: attempt 1/1 (deterministic)
# [batch_1 143/250] row 2a5ed734fc8b884fb29017f2b145469e: success on attempt 1/1
# [batch_1 144/250] row ad66f0cb81724c93dce3bce7fb6ee477: attempt 1/1 (deterministic)
# [batch_1 144/250] row ad66f0cb81724c93dce3bce7fb6ee477: success on attempt 1/1
# [batch_1 145/250] row 2396f2ab4dfe7860463ad9438b3e2608: attempt 1/1 (deterministic)
# [batch_1 145/250] row 2396f2ab4dfe7860463ad9438b3e2608: success on attempt 1/1
# [batch_1 146/250] row f141210c97daf31a237c6c01ff221ccb: attempt 1/1 (deterministic)
# [batch_1 146/250] row f141210c97daf31a237c6c01ff221ccb: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_1 147/250] row a9b948dca66819446ca60ed183b64f56: attempt 1/1 (deterministic)
# [batch_1 147/250] row a9b948dca66819446ca60ed183b64f56: success on attempt 1/1
# [batch_1 148/250] row 0185f3975d6a39f29003339669d98720: attempt 1/1 (deterministic)
# [batch_1 148/250] row 0185f3975d6a39f29003339669d98720: success on attempt 1/1
# [batch_1 149/250] row 976cb41e081a20f3c6b97d026a3b36b6: attempt 1/1 (deterministic)
# [batch_1 149/250] row 976cb41e081a20f3c6b97d026a3b36b6: success on attempt 1/1
# [batch_1 150/250] row e77199c27ef910306b1b05c3071d5f02: attempt 1/1 (deterministic)
# [batch_1 150/250] row e77199c27ef910306b1b05c3071d5f02: attempt 1/1 failed: unclosed token: line 15, column 4
# [batch_1 151/250] row c106940a5f0dab81ce47beb97b6583bf: attempt 1/1 (deterministic)
# [batch_1 151/250] row c106940a5f0dab81ce47beb97b6583bf: success on attempt 1/1
# [batch_1 152/250] row 4d0a2eb6-e631-4382-9bb8-6257a35e3c35: attempt 1/1 (deterministic)
# [batch_1 152/250] row 4d0a2eb6-e631-4382-9bb8-6257a35e3c35: attempt 1/1 failed: unclosed token: line 22, column 0
# [batch_1 153/250] row 4c2ca501bd739340de1d7090e731bb01: attempt 1/1 (deterministic)
# [batch_1 153/250] row 4c2ca501bd739340de1d7090e731bb01: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_1 154/250] row 576645d5e68be36d97b63de0f127d453: attempt 1/1 (deterministic)
# [batch_1 154/250] row 576645d5e68be36d97b63de0f127d453: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 155/250] row 8c53af1feb8b2428b55a56b03c7f7183: attempt 1/1 (deterministic)
# [batch_1 155/250] row 8c53af1feb8b2428b55a56b03c7f7183: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 156/250] row 976ce5a45126d71ebbe4ff71467d4cd6: attempt 1/1 (deterministic)
# [batch_1 156/250] row 976ce5a45126d71ebbe4ff71467d4cd6: success on attempt 1/1
# [batch_1 157/250] row 366b603a3643088ac81d98569bd3e962: attempt 1/1 (deterministic)
# [batch_1 157/250] row 366b603a3643088ac81d98569bd3e962: success on attempt 1/1
# [batch_1 158/250] row f042a3f29c965a1ea50f22002bbd25e0: attempt 1/1 (deterministic)
# [batch_1 158/250] row f042a3f29c965a1ea50f22002bbd25e0: attempt 1/1 failed: unclosed token: line 4, column 0
# [batch_1 159/250] row 487dd547-7ba2-41cf-b5aa-08691b4e0d0b: attempt 1/1 (deterministic)
# [batch_1 159/250] row 487dd547-7ba2-41cf-b5aa-08691b4e0d0b: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 160/250] row ea23c50eb991f46f812108d7f2b88e95: attempt 1/1 (deterministic)
# [batch_1 160/250] row ea23c50eb991f46f812108d7f2b88e95: success on attempt 1/1
# [batch_1 161/250] row dc2053c8-2c1f-4d5b-be7a-d1edb51b4d9d: attempt 1/1 (deterministic)
# [batch_1 161/250] row dc2053c8-2c1f-4d5b-be7a-d1edb51b4d9d: attempt 1/1 failed: unclosed token: line 11, column 4
# [batch_1 162/250] row 208d3a204869313c75a2188821e965b1: attempt 1/1 (deterministic)
# [batch_1 162/250] row 208d3a204869313c75a2188821e965b1: success on attempt 1/1
# [batch_1 163/250] row 522dbb719a7af9320fbd1e283f4de091: attempt 1/1 (deterministic)
# [batch_1 163/250] row 522dbb719a7af9320fbd1e283f4de091: success on attempt 1/1
# [batch_1 164/250] row 853ecc8c-4b22-49b1-b401-8fab84804e88: attempt 1/1 (deterministic)
# [batch_1 164/250] row 853ecc8c-4b22-49b1-b401-8fab84804e88: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 165/250] row e0db5eacebc21e859253d0b383a1ed96: attempt 1/1 (deterministic)
# [batch_1 165/250] row e0db5eacebc21e859253d0b383a1ed96: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 166/250] row c485dd74cf5e9bb13491c0d54589939a: attempt 1/1 (deterministic)
# [batch_1 166/250] row c485dd74cf5e9bb13491c0d54589939a: success on attempt 1/1
# [batch_1 167/250] row c91871a6-5f92-4f84-ac8a-758d5adcbf50: attempt 1/1 (deterministic)
# [batch_1 167/250] row c91871a6-5f92-4f84-ac8a-758d5adcbf50: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 168/250] row 5460b288-68cd-47b4-a7f0-3dcc7af46e22: attempt 1/1 (deterministic)
# [batch_1 168/250] row 5460b288-68cd-47b4-a7f0-3dcc7af46e22: success on attempt 1/1
# [batch_1 169/250] row 20c327c57674a8cbc5960bf89e75aada: attempt 1/1 (deterministic)
# [batch_1 169/250] row 20c327c57674a8cbc5960bf89e75aada: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 170/250] row 26accc1d0eae3cf5a282fe8bc9f24ae6: attempt 1/1 (deterministic)
# [batch_1 170/250] row 26accc1d0eae3cf5a282fe8bc9f24ae6: success on attempt 1/1
# [batch_1 171/250] row 73708003-fcac-40e5-ab72-56cf146bd6ea: attempt 1/1 (deterministic)
# [batch_1 171/250] row 73708003-fcac-40e5-ab72-56cf146bd6ea: success on attempt 1/1
# [batch_1 172/250] row b031866f9839e47867bdf04be7c70179: attempt 1/1 (deterministic)
# [batch_1 172/250] row b031866f9839e47867bdf04be7c70179: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 173/250] row 2027e68d0f0f12743d8b1b3e0bf7327d: attempt 1/1 (deterministic)
# [batch_1 173/250] row 2027e68d0f0f12743d8b1b3e0bf7327d: success on attempt 1/1
# [batch_1 174/250] row 29aeeb99-5145-4c28-9fca-7a691e2fcbba: attempt 1/1 (deterministic)
# [batch_1 174/250] row 29aeeb99-5145-4c28-9fca-7a691e2fcbba: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 175/250] row cd10d9e2a00497818b7bc88db9265125: attempt 1/1 (deterministic)
# [batch_1 175/250] row cd10d9e2a00497818b7bc88db9265125: success on attempt 1/1
# [batch_1 176/250] row 90efed7b71ba491724756bbcbfc46734: attempt 1/1 (deterministic)
# [batch_1 176/250] row 90efed7b71ba491724756bbcbfc46734: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 177/250] row a94d05f0e0eb85e06839b5c1c5523a74: attempt 1/1 (deterministic)
# [batch_1 177/250] row a94d05f0e0eb85e06839b5c1c5523a74: attempt 1/1 failed: unclosed token: line 9, column 4
# [batch_1 178/250] row fa16ad7ec9e08db1119b96f54d67f1c8: attempt 1/1 (deterministic)
# [batch_1 178/250] row fa16ad7ec9e08db1119b96f54d67f1c8: success on attempt 1/1
# [batch_1 179/250] row a92453bd82b74a72badf504d9fb77bbd: attempt 1/1 (deterministic)
# [batch_1 179/250] row a92453bd82b74a72badf504d9fb77bbd: success on attempt 1/1
# [batch_1 180/250] row 75cbc991cd88a5b0b0351a1e6d743a1d: attempt 1/1 (deterministic)
# [batch_1 180/250] row 75cbc991cd88a5b0b0351a1e6d743a1d: success on attempt 1/1
# [batch_1 181/250] row e0fb222844234c7fde7149aa7a2c49e2: attempt 1/1 (deterministic)
# [batch_1 181/250] row e0fb222844234c7fde7149aa7a2c49e2: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 182/250] row 687d6990a090b56714dc2d45160f2770: attempt 1/1 (deterministic)
# [batch_1 182/250] row 687d6990a090b56714dc2d45160f2770: success on attempt 1/1
# [batch_1 183/250] row cdfa7edfdde22df95c4872e946865b8f: attempt 1/1 (deterministic)
# [batch_1 183/250] row cdfa7edfdde22df95c4872e946865b8f: attempt 1/1 failed: unclosed token: line 8, column 4
# [batch_1 184/250] row a77d3986e254202d345d504cf50c1593: attempt 1/1 (deterministic)
# [batch_1 184/250] row a77d3986e254202d345d504cf50c1593: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 185/250] row 639cdf9c5a3f7bb32fe2c924f9ed43c8: attempt 1/1 (deterministic)
# [batch_1 185/250] row 639cdf9c5a3f7bb32fe2c924f9ed43c8: success on attempt 1/1
# [batch_1 186/250] row thesantatitan_deepseek-svg-dataset_0004039: attempt 1/1 (deterministic)
# [batch_1 186/250] row thesantatitan_deepseek-svg-dataset_0004039: success on attempt 1/1
# [batch_1 187/250] row bb49941826f148b8df0fc8ccffc8ed31: attempt 1/1 (deterministic)
# [batch_1 187/250] row bb49941826f148b8df0fc8ccffc8ed31: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_1 188/250] row ea729a2f4580947d41485f3775bd5707: attempt 1/1 (deterministic)
# [batch_1 188/250] row ea729a2f4580947d41485f3775bd5707: attempt 1/1 failed: unclosed token: line 4, column 4
# [batch_1 189/250] row e33ef0e67b141c3ca4c25fd009081b9f: attempt 1/1 (deterministic)
# [batch_1 189/250] row e33ef0e67b141c3ca4c25fd009081b9f: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_1 190/250] row 39ae60955e6b585fc27304e970ce565e: attempt 1/1 (deterministic)
# [batch_1 190/250] row 39ae60955e6b585fc27304e970ce565e: success on attempt 1/1
# [batch_1 191/250] row 6afe00f782bd17861b66844966a4f5b7: attempt 1/1 (deterministic)
# [batch_1 191/250] row 6afe00f782bd17861b66844966a4f5b7: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_1 192/250] row ca98032e0ec54cff276b43ce2c8bcc96: attempt 1/1 (deterministic)
# [batch_1 192/250] row ca98032e0ec54cff276b43ce2c8bcc96: attempt 1/1 failed: unclosed token: line 14, column 4
# [batch_1 193/250] row f08f803eca6e2ccf56623f2b88111307: attempt 1/1 (deterministic)
# [batch_1 193/250] row f08f803eca6e2ccf56623f2b88111307: attempt 1/1 failed: unclosed token: line 12, column 0
# [batch_1 194/250] row a53ec4a5f72d175bcab07aa5d4ca0825: attempt 1/1 (deterministic)
# [batch_1 194/250] row a53ec4a5f72d175bcab07aa5d4ca0825: success on attempt 1/1
# [batch_1 195/250] row 01b96b3b48ebec80ad1c1fd978143edf: attempt 1/1 (deterministic)
# [batch_1 195/250] row 01b96b3b48ebec80ad1c1fd978143edf: success on attempt 1/1
# [batch_1 196/250] row a95fdba762ea7be4d915dd4d03f5b2f4: attempt 1/1 (deterministic)
# [batch_1 196/250] row a95fdba762ea7be4d915dd4d03f5b2f4: success on attempt 1/1
# [batch_1 197/250] row 86c7a83cb9e81bdf455a99e659137ef2: attempt 1/1 (deterministic)
# [batch_1 197/250] row 86c7a83cb9e81bdf455a99e659137ef2: success on attempt 1/1
# [batch_1 198/250] row b41d7e3e022e43081f5192ee07f4d4f7: attempt 1/1 (deterministic)
# [batch_1 198/250] row b41d7e3e022e43081f5192ee07f4d4f7: success on attempt 1/1
# [batch_1 199/250] row fa36047dea04e51d93fb31470871d5e9: attempt 1/1 (deterministic)
# [batch_1 199/250] row fa36047dea04e51d93fb31470871d5e9: success on attempt 1/1
# [batch_1 200/250] row 368f07a008f8a3e39b1497d2de618441: attempt 1/1 (deterministic)
# [batch_1 200/250] row 368f07a008f8a3e39b1497d2de618441: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 201/250] row c40d4f88519b6bb02fe8fca55bab9fa3: attempt 1/1 (deterministic)
# [batch_1 201/250] row c40d4f88519b6bb02fe8fca55bab9fa3: success on attempt 1/1
# [batch_1 202/250] row ae0d69831dfeb9bb21e44699e9483e11: attempt 1/1 (deterministic)
# [batch_1 202/250] row ae0d69831dfeb9bb21e44699e9483e11: success on attempt 1/1
# [batch_1 203/250] row 5bc26faa106b61de6c697d8389b2494c: attempt 1/1 (deterministic)
# [batch_1 203/250] row 5bc26faa106b61de6c697d8389b2494c: success on attempt 1/1
# [batch_1 204/250] row thesantatitan_deepseek-svg-dataset_0003317: attempt 1/1 (deterministic)
# [batch_1 204/250] row thesantatitan_deepseek-svg-dataset_0003317: success on attempt 1/1
# [batch_1 205/250] row 5a89b390d26eb0c79fa762f9bb6e0ea2: attempt 1/1 (deterministic)
# [batch_1 205/250] row 5a89b390d26eb0c79fa762f9bb6e0ea2: success on attempt 1/1
# [batch_1 206/250] row 1bdce14177d6c7d19c56eb84d7d8de03: attempt 1/1 (deterministic)
# [batch_1 206/250] row 1bdce14177d6c7d19c56eb84d7d8de03: attempt 1/1 failed: unclosed token: line 7, column 0
# [batch_1 207/250] row 869fc1019e4860633ff8ce833e1f44ef: attempt 1/1 (deterministic)
# [batch_1 207/250] row 869fc1019e4860633ff8ce833e1f44ef: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 208/250] row e4dfae5a4b965b6aa85f8653c7cfb9e4: attempt 1/1 (deterministic)
# [batch_1 208/250] row e4dfae5a4b965b6aa85f8653c7cfb9e4: success on attempt 1/1
# [batch_1 209/250] row 4e2cb420fbaff506b56aff612a1ea247: attempt 1/1 (deterministic)
# [batch_1 209/250] row 4e2cb420fbaff506b56aff612a1ea247: success on attempt 1/1
# [batch_1 210/250] row bb6a320a-f1b2-4bf9-aa51-67e34dcbd214: attempt 1/1 (deterministic)
# [batch_1 210/250] row bb6a320a-f1b2-4bf9-aa51-67e34dcbd214: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 211/250] row 15ec41d43f41853fab819a5c5844b8ac: attempt 1/1 (deterministic)
# [batch_1 211/250] row 15ec41d43f41853fab819a5c5844b8ac: success on attempt 1/1
# [batch_1 212/250] row 4bab6c8a-3ef9-4e83-913c-42967c7e50d0: attempt 1/1 (deterministic)
# [batch_1 212/250] row 4bab6c8a-3ef9-4e83-913c-42967c7e50d0: success on attempt 1/1
# [batch_1 213/250] row cbfcd190d8a34707569179ac050afc08: attempt 1/1 (deterministic)
# [batch_1 213/250] row cbfcd190d8a34707569179ac050afc08: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 214/250] row f842bfcb04d3fbddcdf9f2a18e6fd61e: attempt 1/1 (deterministic)
# [batch_1 214/250] row f842bfcb04d3fbddcdf9f2a18e6fd61e: success on attempt 1/1
# [batch_1 215/250] row 2959a4147b65342b54cc5537cad9104a: attempt 1/1 (deterministic)
# [batch_1 215/250] row 2959a4147b65342b54cc5537cad9104a: success on attempt 1/1
# [batch_1 216/250] row 795d07ed95526c906b164488ac16409e: attempt 1/1 (deterministic)
# [batch_1 216/250] row 795d07ed95526c906b164488ac16409e: success on attempt 1/1
# [batch_1 217/250] row 796221887d9b5a55ed27a7b445ca93da: attempt 1/1 (deterministic)
# [batch_1 217/250] row 796221887d9b5a55ed27a7b445ca93da: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 218/250] row f012d7256a7942d77f2f733d47b3c609: attempt 1/1 (deterministic)
# [batch_1 218/250] row f012d7256a7942d77f2f733d47b3c609: attempt 1/1 failed: unclosed token: line 15, column 4
# [batch_1 219/250] row dea8c91b333fef2d0cad705d4556cbb0: attempt 1/1 (deterministic)
# [batch_1 219/250] row dea8c91b333fef2d0cad705d4556cbb0: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 220/250] row decc4c13cc2aa6760c8870b9a04d6a42: attempt 1/1 (deterministic)
# [batch_1 220/250] row decc4c13cc2aa6760c8870b9a04d6a42: success on attempt 1/1
# [batch_1 221/250] row 3f480073f77d15df0d59993b573832c7: attempt 1/1 (deterministic)
# [batch_1 221/250] row 3f480073f77d15df0d59993b573832c7: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 222/250] row e347d66285704a472274748785b2ce9d: attempt 1/1 (deterministic)
# [batch_1 222/250] row e347d66285704a472274748785b2ce9d: success on attempt 1/1
# [batch_1 223/250] row f56f5527-6b18-40ba-be43-310c034c0450: attempt 1/1 (deterministic)
# [batch_1 223/250] row f56f5527-6b18-40ba-be43-310c034c0450: success on attempt 1/1
# [batch_1 224/250] row 73f19b688a39c0cdf6157fb4e2c4537e: attempt 1/1 (deterministic)
# [batch_1 224/250] row 73f19b688a39c0cdf6157fb4e2c4537e: success on attempt 1/1
# [batch_1 225/250] row 3cf1e548ac96efa8a849c2e30c09c2c9: attempt 1/1 (deterministic)
# [batch_1 225/250] row 3cf1e548ac96efa8a849c2e30c09c2c9: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 226/250] row d584789a90321b0e5b02f5b57b783d22: attempt 1/1 (deterministic)
# [batch_1 226/250] row d584789a90321b0e5b02f5b57b783d22: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 227/250] row 4a2c2e6b0d883c43b80d1b8c00c9d143: attempt 1/1 (deterministic)
# [batch_1 227/250] row 4a2c2e6b0d883c43b80d1b8c00c9d143: success on attempt 1/1
# [batch_1 228/250] row 7b09ab57cfb607da982fb06b6ba08ccb: attempt 1/1 (deterministic)
# [batch_1 228/250] row 7b09ab57cfb607da982fb06b6ba08ccb: attempt 1/1 failed: unclosed token: line 22, column 0
# [batch_1 229/250] row 3c1afdf835e6b629d14ee7c0e78760e0: attempt 1/1 (deterministic)
# [batch_1 229/250] row 3c1afdf835e6b629d14ee7c0e78760e0: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 230/250] row 6bc68236fcd5a5301ae4c596734549c9: attempt 1/1 (deterministic)
# [batch_1 230/250] row 6bc68236fcd5a5301ae4c596734549c9: attempt 1/1 failed: unclosed token: line 3, column 2
# [batch_1 231/250] row b3dcd64a4e0748e091af2990909be3aa: attempt 1/1 (deterministic)
# [batch_1 231/250] row b3dcd64a4e0748e091af2990909be3aa: success on attempt 1/1
# [batch_1 232/250] row thesantatitan_deepseek-svg-dataset_0000533: attempt 1/1 (deterministic)
# [batch_1 232/250] row thesantatitan_deepseek-svg-dataset_0000533: success on attempt 1/1
# [batch_1 233/250] row 3ac2c9ed08f0f1b85f95bfba0e84da08: attempt 1/1 (deterministic)
# [batch_1 233/250] row 3ac2c9ed08f0f1b85f95bfba0e84da08: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 234/250] row a0df842d-d482-4917-94f0-25b885c1c3ec: attempt 1/1 (deterministic)
# [batch_1 234/250] row a0df842d-d482-4917-94f0-25b885c1c3ec: success on attempt 1/1
# [batch_1 235/250] row 9a9563a6-a25f-4d01-8bc7-8da0cf5f5e45: attempt 1/1 (deterministic)
# [batch_1 235/250] row 9a9563a6-a25f-4d01-8bc7-8da0cf5f5e45: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 236/250] row b17139fd16d7ace872ea8110329ecf21: attempt 1/1 (deterministic)
# [batch_1 236/250] row b17139fd16d7ace872ea8110329ecf21: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 237/250] row 0de7149e99b56fde10e47d1c29a032ba: attempt 1/1 (deterministic)
# [batch_1 237/250] row 0de7149e99b56fde10e47d1c29a032ba: success on attempt 1/1
# [batch_1 238/250] row 84225196-e3a2-4789-873c-6009be8dd608: attempt 1/1 (deterministic)
# [batch_1 238/250] row 84225196-e3a2-4789-873c-6009be8dd608: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_1 239/250] row d966537c-46ae-4e34-8347-b0b273743187: attempt 1/1 (deterministic)
# [batch_1 239/250] row d966537c-46ae-4e34-8347-b0b273743187: success on attempt 1/1
# [batch_1 240/250] row 5a17ad6464e07133da8992dd3c52488b: attempt 1/1 (deterministic)
# [batch_1 240/250] row 5a17ad6464e07133da8992dd3c52488b: success on attempt 1/1
# [batch_1 241/250] row 9255034c-9ca4-49a3-969f-aa56573be0b2: attempt 1/1 (deterministic)
# [batch_1 241/250] row 9255034c-9ca4-49a3-969f-aa56573be0b2: success on attempt 1/1
# [batch_1 242/250] row 22d04b3be8c872703266802c919a57b2: attempt 1/1 (deterministic)
# [batch_1 242/250] row 22d04b3be8c872703266802c919a57b2: success on attempt 1/1
# [batch_1 243/250] row 566f44c1afbe084f8665c31b1396728d: attempt 1/1 (deterministic)
# [batch_1 243/250] row 566f44c1afbe084f8665c31b1396728d: attempt 1/1 failed: unclosed token: line 22, column 0
# [batch_1 244/250] row 1ffcf29fc54313c8b4e75e9072b651c8: attempt 1/1 (deterministic)
# [batch_1 244/250] row 1ffcf29fc54313c8b4e75e9072b651c8: attempt 1/1 failed: unclosed token: line 21, column 2
# [batch_1 245/250] row 11b43007370a4744a79048f67b5c90a4: attempt 1/1 (deterministic)
# [batch_1 245/250] row 11b43007370a4744a79048f67b5c90a4: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 246/250] row a18b36b0fa714d7f34575a027d1bc693: attempt 1/1 (deterministic)
# [batch_1 246/250] row a18b36b0fa714d7f34575a027d1bc693: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_1 247/250] row 37e8022f-243f-40f8-89f7-c5c056083469: attempt 1/1 (deterministic)
# [batch_1 247/250] row 37e8022f-243f-40f8-89f7-c5c056083469: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_1 248/250] row thesantatitan_deepseek-svg-dataset_0001179: attempt 1/1 (deterministic)
# [batch_1 248/250] row thesantatitan_deepseek-svg-dataset_0001179: success on attempt 1/1
# [batch_1 249/250] row fd8b4b17bf2a56a32144b1e3fd080dc4: attempt 1/1 (deterministic)
# [batch_1 249/250] row fd8b4b17bf2a56a32144b1e3fd080dc4: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_1 250/250] row a9f87cd9445715e6b87fbe34c18a0fcf: attempt 1/1 (deterministic)
# [batch_1 250/250] row a9f87cd9445715e6b87fbe34c18a0fcf: attempt 1/1 failed: unclosed token: line 6, column 0
# Wrote batch artifacts to: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_1

# %% [markdown]
# ## Batch Summary
#
# Show the first-pass success/failure totals and inspect a few failed rows with their gate errors.
#
# - Reads: Batch result artifacts in memory
# - Writes: Nothing
# - Rerun-safe: Yes. Read-only display cell.

# %%
display(pipeline.summarize_batch_results(FIRST_PASS_RESULTS_DF))
FAILED_DF = FIRST_PASS_RESULTS_DF[~FIRST_PASS_RESULTS_DF["first_pass_success"]].copy()
if FAILED_DF.empty:
    print("No failed rows in this batch.")
else:
    display(FAILED_DF[["id", "row_index", "generation_mode", "gate_error"]].head(20))
