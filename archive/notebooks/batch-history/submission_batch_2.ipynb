# %% [markdown]
# # First-Pass Batch 2
#
# This notebook handles the deterministic first pass for batch 2 of 4. It does not retry failed rows.

# %% [markdown]
# ## Drive And Repo Setup
#
# Mount Drive, clone the repo into the runtime, and copy the required CSV inputs into the checkout.
#
# - Reads: Google Drive, GitHub repo, runtime filesystem
# - Writes: `/content/svg-kaggle-comptetition`, Drive output root
# - Rerun-safe: Yes. It reclones the repo and recopies the inputs cleanly.

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path

from google.colab import drive

drive.mount("/content/drive")

GIT_REPO_URL = "https://github.com/Demetri65/svg-kaggle-competition-.git"
CHECKOUT_PATH = Path("/content/svg-kaggle-comptetition")
DRIVE_ROOT = Path("/content/drive/MyDrive")
OUTPUT_ROOT = DRIVE_ROOT / "svg-kaggle-comptetition" / "submission_outputs"

if CHECKOUT_PATH.exists():
    shutil.rmtree(CHECKOUT_PATH)
subprocess.check_call(["git", "clone", GIT_REPO_URL, str(CHECKOUT_PATH)])

for required_name in ["test.csv", "train.csv", "sample_submission.csv"]:
    destination = CHECKOUT_PATH / required_name
    if destination.exists():
        continue

    preferred_sources = [
        DRIVE_ROOT / "svg-kaggle-comptetition" / required_name,
        DRIVE_ROOT / "Colab Notebooks" / "svg-kaggle-comptetition" / required_name,
    ]
    copied = False
    for candidate in preferred_sources:
        if candidate.exists():
            shutil.copy2(candidate, destination)
            copied = True
            break
    if not copied:
        for candidate in DRIVE_ROOT.rglob(required_name):
            if candidate.is_file():
                shutil.copy2(candidate, destination)
                copied = True
                break
    if not copied:
        raise FileNotFoundError(
            f"Could not find {required_name} in Google Drive. Copy it into {CHECKOUT_PATH} manually and rerun this cell."
        )

os.environ["SVG_KAGGLE_REPO_ROOT"] = str(CHECKOUT_PATH)
sys.path.insert(0, str(CHECKOUT_PATH))
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

print(f"Repo checkout: {CHECKOUT_PATH}")
print(f"Drive output root: {OUTPUT_ROOT}")
# Out:
# Mounted at /content/drive
# Repo checkout: /content/svg-kaggle-comptetition
# Drive output root: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs

# %% [markdown]
# ## Package Check
#
# Install any missing runtime packages required by the shared helper module and this notebook.
#
# - Reads: Current Python environment
# - Writes: Installed runtime packages
# - Rerun-safe: Yes. It only installs missing packages.

# %%
import importlib.util
import subprocess
import sys

REQUIRED_PACKAGES = {
    "pandas": "pandas",
    "numpy": "numpy",
    "torch": "torch",
    "transformers": "transformers",
    "peft": "peft",
    "accelerate": "accelerate",
    "cairosvg": "cairosvg",
    "skimage": "scikit-image",
    "PIL": "pillow",
}

missing_packages = [
    package_name
    for module_name, package_name in REQUIRED_PACKAGES.items()
    if importlib.util.find_spec(module_name) is None
]

if missing_packages:
    subprocess.check_call([sys.executable, "-m", "pip", "install", *missing_packages])
    print(f"Installed missing packages: {missing_packages}")
else:
    print("All required packages are already installed.")
# Out:
# Installed missing packages: ['cairosvg']

# %% [markdown]
# ## Load Helpers, Recommendation, And Batch Slice
#
# Import the shared helper module, load the analysis recommendation, and select this notebook's fixed quarter of `test.csv`.
#
# - Reads: Repo checkout, helper module, analysis recommendation, competition CSV files
# - Writes: In-memory batch slice only
# - Rerun-safe: Yes. It is deterministic because the batch boundaries are fixed.

# %%
import json
import os
from pathlib import Path

import pandas as pd
from IPython.display import SVG, Markdown, display

import submission_pipeline as pipeline

pipeline.set_global_seed(1337)
PATHS = pipeline.resolve_pipeline_paths(Path(os.environ["SVG_KAGGLE_REPO_ROOT"]), OUTPUT_ROOT)
CONFIG = pipeline.GenerationConfig(verbose_progress=True)
TEST_DF, SAMPLE_SUBMISSION_DF, TRAIN_DF = pipeline.load_competition_frames(PATHS)

print(f"Repo root: {PATHS.repo_root}")
print(f"Output root: {PATHS.output_root}")

BATCH_ID = 2
ANALYSIS_RECOMMENDATION = pipeline.load_analysis_recommendation(PATHS)
GENERATION_MODE = ANALYSIS_RECOMMENDATION.get("recommended_generation_mode", "body_only")
BATCH_DF = pipeline.select_batch_df(TEST_DF, batch_id=BATCH_ID, batch_count=4)
BATCH_DIR = pipeline.batch_output_dir(PATHS, BATCH_ID)
print(f"Recommended generation mode: {GENERATION_MODE}")
print(f"Batch rows: {len(BATCH_DF)}")
display(BATCH_DF[["id", "prompt", "row_index"]].head())
# Out:
# Repo root: /content/svg-kaggle-comptetition
# Output root: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs
# Recommended generation mode: full_svg
# Batch rows: 250
#                                  id  \
# 0  34c190727cce6d1ea6d41e76ec560860
# 1  d5831d22106a0c672f06cc95e6fc3184
# 2  a4022c2822c93ed88e60f70ec8f877cb
# 3  eac44be984595232d314038a2de321ab
# 4  db53c8c82b81efca578d46ffb9ddf1ff
#
#                                               prompt  row_index
# 0  A simple line drawing of a camera with black l...        250
# 1  The image features a black outline of a rectan...        251
# 2  The image shows a pink folder icon with a blue...        252
# 3  The image features a blue magnifying glass wit...        253
# 4  A black circular outline contains a white face...        254

# %% [markdown]
# ## Load Model
#
# Load the base model plus the LoRA adapter into the current Colab GPU runtime for first-pass generation.
#
# - Reads: Base model on Hugging Face, LoRA adapter from repo
# - Writes: In-memory model state only
# - Rerun-safe: No. It is safe to rerun, but it reloads the model and costs time.

# %%
RUNTIME = pipeline.load_lora_runtime(PATHS.adapter_dir)
print(f"Loaded runtime on: {RUNTIME.runtime_device}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Loaded runtime on: cuda

# %% [markdown]
# ## Deterministic First Pass
#
# Run one deterministic generation attempt per row in this batch and save the success/failure artifacts for the merge notebook.
#
# - Reads: Selected batch rows, model runtime
# - Writes: Batch output CSV artifacts under this batch directory
# - Rerun-safe: Yes. It recomputes and overwrites this batch's artifacts.

# %%
FIRST_PASS_RESULTS_DF = pipeline.run_first_pass_batch(
    BATCH_DF,
    RUNTIME,
    batch_id=BATCH_ID,
    generation_mode=GENERATION_MODE,
    config=CONFIG,
)
pipeline.save_batch_outputs(FIRST_PASS_RESULTS_DF, BATCH_DIR)
print(f"Wrote batch artifacts to: {BATCH_DIR}")
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [batch_2 1/250] row 34c190727cce6d1ea6d41e76ec560860: attempt 1/1 (deterministic)
# [batch_2 1/250] row 34c190727cce6d1ea6d41e76ec560860: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_2 2/250] row d5831d22106a0c672f06cc95e6fc3184: attempt 1/1 (deterministic)
# [batch_2 2/250] row d5831d22106a0c672f06cc95e6fc3184: success on attempt 1/1
# [batch_2 3/250] row a4022c2822c93ed88e60f70ec8f877cb: attempt 1/1 (deterministic)
# [batch_2 3/250] row a4022c2822c93ed88e60f70ec8f877cb: success on attempt 1/1
# [batch_2 4/250] row eac44be984595232d314038a2de321ab: attempt 1/1 (deterministic)
# [batch_2 4/250] row eac44be984595232d314038a2de321ab: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 5/250] row db53c8c82b81efca578d46ffb9ddf1ff: attempt 1/1 (deterministic)
# [batch_2 5/250] row db53c8c82b81efca578d46ffb9ddf1ff: success on attempt 1/1
# [batch_2 6/250] row 605476208ee5690024db67bb3db70285: attempt 1/1 (deterministic)
# [batch_2 6/250] row 605476208ee5690024db67bb3db70285: success on attempt 1/1
# [batch_2 7/250] row b4f79e0b2f72c1e7b9f8c4956be5a1f6: attempt 1/1 (deterministic)
# [batch_2 7/250] row b4f79e0b2f72c1e7b9f8c4956be5a1f6: success on attempt 1/1
# [batch_2 8/250] row a198f33e-3ec4-4932-8a5e-8266f5ef9ee1: attempt 1/1 (deterministic)
# [batch_2 8/250] row a198f33e-3ec4-4932-8a5e-8266f5ef9ee1: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_2 9/250] row thesantatitan_deepseek-svg-dataset_0002990: attempt 1/1 (deterministic)
# [batch_2 9/250] row thesantatitan_deepseek-svg-dataset_0002990: success on attempt 1/1
# [batch_2 10/250] row 4683d181d4956eae836923f39c1a8246: attempt 1/1 (deterministic)
# [batch_2 10/250] row 4683d181d4956eae836923f39c1a8246: success on attempt 1/1
# [batch_2 11/250] row 0139c8b5480769aed9b19064eacfa406: attempt 1/1 (deterministic)
# [batch_2 11/250] row 0139c8b5480769aed9b19064eacfa406: success on attempt 1/1
# [batch_2 12/250] row ce8ac939a28821660b25d8e82a4e040c: attempt 1/1 (deterministic)
# [batch_2 12/250] row ce8ac939a28821660b25d8e82a4e040c: success on attempt 1/1
# [batch_2 13/250] row b185f9e6f195059e509da7cdd413babb: attempt 1/1 (deterministic)
# [batch_2 13/250] row b185f9e6f195059e509da7cdd413babb: success on attempt 1/1
# [batch_2 14/250] row abaca1bd-1bb3-4dec-9316-76cd5bbcb07e: attempt 1/1 (deterministic)
# [batch_2 14/250] row abaca1bd-1bb3-4dec-9316-76cd5bbcb07e: attempt 1/1 failed: unclosed token: line 14, column 0
# [batch_2 15/250] row 973b240f0cb9d52940206c72b8acef67: attempt 1/1 (deterministic)
# [batch_2 15/250] row 973b240f0cb9d52940206c72b8acef67: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_2 16/250] row 616da53d0b6c10cb4b9658b6cf8f04c1: attempt 1/1 (deterministic)
# [batch_2 16/250] row 616da53d0b6c10cb4b9658b6cf8f04c1: success on attempt 1/1
# [batch_2 17/250] row 2ecac2a7259aa42b1f34ae1ca7a84304: attempt 1/1 (deterministic)
# [batch_2 17/250] row 2ecac2a7259aa42b1f34ae1ca7a84304: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_2 18/250] row 9a0c9dc7-ff3e-45df-9040-01ea6572ab3c: attempt 1/1 (deterministic)
# [batch_2 18/250] row 9a0c9dc7-ff3e-45df-9040-01ea6572ab3c: attempt 1/1 failed: unclosed token: line 7, column 0
# [batch_2 19/250] row 8c32b0cc5f5d6cc5237154f5aefdad3a: attempt 1/1 (deterministic)
# [batch_2 19/250] row 8c32b0cc5f5d6cc5237154f5aefdad3a: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 20/250] row e9e06f483926aa9173f47efdff47bdfd: attempt 1/1 (deterministic)
# [batch_2 20/250] row e9e06f483926aa9173f47efdff47bdfd: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_2 21/250] row be0626beefd28e1e0dac6a99dfbc4654: attempt 1/1 (deterministic)
# [batch_2 21/250] row be0626beefd28e1e0dac6a99dfbc4654: success on attempt 1/1
# [batch_2 22/250] row ddeb75ae62bcf0b9d4020fed43425249: attempt 1/1 (deterministic)
# [batch_2 22/250] row ddeb75ae62bcf0b9d4020fed43425249: attempt 1/1 failed: unclosed token: line 4, column 4
# [batch_2 23/250] row 33712ead-2ffa-41ac-8b3c-450418e64526: attempt 1/1 (deterministic)
# [batch_2 23/250] row 33712ead-2ffa-41ac-8b3c-450418e64526: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_2 24/250] row f589c2b36017997b6cf8fec88a1b0210: attempt 1/1 (deterministic)
# [batch_2 24/250] row f589c2b36017997b6cf8fec88a1b0210: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 25/250] row c321f45ec36cd318121742cf86b4bbe3: attempt 1/1 (deterministic)
# [batch_2 25/250] row c321f45ec36cd318121742cf86b4bbe3: attempt 1/1 failed: unclosed token: line 19, column 4
# [batch_2 26/250] row 3c4fae8973f3201cc56bf021d6c28a05: attempt 1/1 (deterministic)
# [batch_2 26/250] row 3c4fae8973f3201cc56bf021d6c28a05: success on attempt 1/1
# [batch_2 27/250] row c8ecb42b67d98b80728ae0800580c7f5: attempt 1/1 (deterministic)
# [batch_2 27/250] row c8ecb42b67d98b80728ae0800580c7f5: attempt 1/1 failed: unclosed token: line 17, column 4
# [batch_2 28/250] row 6eca3b2c4fa89b8a75aae63e1e99d965: attempt 1/1 (deterministic)
# [batch_2 28/250] row 6eca3b2c4fa89b8a75aae63e1e99d965: attempt 1/1 failed: unclosed token: line 24, column 2
# [batch_2 29/250] row 4a4873e4c365c59b08392cb0a3e4a5a2: attempt 1/1 (deterministic)
# [batch_2 29/250] row 4a4873e4c365c59b08392cb0a3e4a5a2: success on attempt 1/1
# [batch_2 30/250] row 403dd46dcbadef8e7a82aabda5c0d5ce: attempt 1/1 (deterministic)
# [batch_2 30/250] row 403dd46dcbadef8e7a82aabda5c0d5ce: success on attempt 1/1
# [batch_2 31/250] row 14e2bada9947c9771638f4c8de86a362: attempt 1/1 (deterministic)
# [batch_2 31/250] row 14e2bada9947c9771638f4c8de86a362: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 32/250] row 2e7630a66e4c461b4ba8832fb2c9eb05: attempt 1/1 (deterministic)
# [batch_2 32/250] row 2e7630a66e4c461b4ba8832fb2c9eb05: attempt 1/1 failed: unclosed token: line 4, column 0
# [batch_2 33/250] row 037dde66e5c63733fa3d155d56e83a2e: attempt 1/1 (deterministic)
# [batch_2 33/250] row 037dde66e5c63733fa3d155d56e83a2e: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_2 34/250] row ebdf859d921b2cfdcb73d16f47016fcb: attempt 1/1 (deterministic)
# [batch_2 34/250] row ebdf859d921b2cfdcb73d16f47016fcb: attempt 1/1 failed: unclosed token: line 7, column 0
# [batch_2 35/250] row ac4acd9150326a0101068a3d40828e80: attempt 1/1 (deterministic)
# [batch_2 35/250] row ac4acd9150326a0101068a3d40828e80: success on attempt 1/1
# [batch_2 36/250] row 555907014c744d478184abd3c533833c: attempt 1/1 (deterministic)
# [batch_2 36/250] row 555907014c744d478184abd3c533833c: success on attempt 1/1
# [batch_2 37/250] row 810635cb0eb01e92368295951f7829bf: attempt 1/1 (deterministic)
# [batch_2 37/250] row 810635cb0eb01e92368295951f7829bf: success on attempt 1/1
# [batch_2 38/250] row b3d2b3de67376420e0ce0999630c1b06: attempt 1/1 (deterministic)
# [batch_2 38/250] row b3d2b3de67376420e0ce0999630c1b06: success on attempt 1/1
# [batch_2 39/250] row 3c45ef17a1f899dcd6bc21f857abedb6: attempt 1/1 (deterministic)
# [batch_2 39/250] row 3c45ef17a1f899dcd6bc21f857abedb6: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 40/250] row 3755d5181136c358d28f77501efc697b: attempt 1/1 (deterministic)
# [batch_2 40/250] row 3755d5181136c358d28f77501efc697b: success on attempt 1/1
# [batch_2 41/250] row 622391934b16f56fc5432d4257fe5f6b: attempt 1/1 (deterministic)
# [batch_2 41/250] row 622391934b16f56fc5432d4257fe5f6b: success on attempt 1/1
# [batch_2 42/250] row 774b94e6b5203b32b92364d81d1c0cc6: attempt 1/1 (deterministic)
# [batch_2 42/250] row 774b94e6b5203b32b92364d81d1c0cc6: success on attempt 1/1
# [batch_2 43/250] row 0fffa7b61a4c17c2e20b1f46eda9b7b6: attempt 1/1 (deterministic)
# [batch_2 43/250] row 0fffa7b61a4c17c2e20b1f46eda9b7b6: success on attempt 1/1
# [batch_2 44/250] row 5006c58a2f008edfd4bfe6139810547d: attempt 1/1 (deterministic)
# [batch_2 44/250] row 5006c58a2f008edfd4bfe6139810547d: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_2 45/250] row fa49d1a6aab69014a23585aef9b4c490: attempt 1/1 (deterministic)
# [batch_2 45/250] row fa49d1a6aab69014a23585aef9b4c490: attempt 1/1 failed: unclosed token: line 17, column 0
# [batch_2 46/250] row 02f8d0703df269ab1f6b2b721f61eb40: attempt 1/1 (deterministic)
# [batch_2 46/250] row 02f8d0703df269ab1f6b2b721f61eb40: success on attempt 1/1
# [batch_2 47/250] row 2ef2753d777c31bf5331ef7691a51c03: attempt 1/1 (deterministic)
# [batch_2 47/250] row 2ef2753d777c31bf5331ef7691a51c03: success on attempt 1/1
# [batch_2 48/250] row e9d61a4aae58d3751999c104886c311f: attempt 1/1 (deterministic)
# [batch_2 48/250] row e9d61a4aae58d3751999c104886c311f: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_2 49/250] row da41b54baffda55195a4903087a9c0a5: attempt 1/1 (deterministic)
# [batch_2 49/250] row da41b54baffda55195a4903087a9c0a5: attempt 1/1 failed: unclosed token: line 4, column 4
# [batch_2 50/250] row f4db9007ce8675094d29cbf5cbed692a: attempt 1/1 (deterministic)
# [batch_2 50/250] row f4db9007ce8675094d29cbf5cbed692a: success on attempt 1/1
# [batch_2 51/250] row 374605817a610078144d145016357fd1: attempt 1/1 (deterministic)
# [batch_2 51/250] row 374605817a610078144d145016357fd1: success on attempt 1/1
# [batch_2 52/250] row 3fddc9a0-5fcf-48ea-908d-8c87851d6407: attempt 1/1 (deterministic)
# [batch_2 52/250] row 3fddc9a0-5fcf-48ea-908d-8c87851d6407: success on attempt 1/1
# [batch_2 53/250] row b40657d55b72089f8017320972579a23: attempt 1/1 (deterministic)
# [batch_2 53/250] row b40657d55b72089f8017320972579a23: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_2 54/250] row d5fecb02676b57a58c8ecba2188f15c3: attempt 1/1 (deterministic)
# [batch_2 54/250] row d5fecb02676b57a58c8ecba2188f15c3: success on attempt 1/1
# [batch_2 55/250] row ffe0160c-355c-4abc-917a-9f8aa2df5f0e: attempt 1/1 (deterministic)
# [batch_2 55/250] row ffe0160c-355c-4abc-917a-9f8aa2df5f0e: success on attempt 1/1
# [batch_2 56/250] row dec247574ae1fceb82580da0c2636b78: attempt 1/1 (deterministic)
# [batch_2 56/250] row dec247574ae1fceb82580da0c2636b78: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_2 57/250] row 1bf0a4fd8b529954a7c4b755f5592e39: attempt 1/1 (deterministic)
# [batch_2 57/250] row 1bf0a4fd8b529954a7c4b755f5592e39: attempt 1/1 failed: unclosed token: line 4, column 0
# [batch_2 58/250] row 71229e9fb7139eaf508760275eacdeb2: attempt 1/1 (deterministic)
# [batch_2 58/250] row 71229e9fb7139eaf508760275eacdeb2: success on attempt 1/1
# [batch_2 59/250] row a1a9ed9f8e8ba3a5f7a3c3bba3052769: attempt 1/1 (deterministic)
# [batch_2 59/250] row a1a9ed9f8e8ba3a5f7a3c3bba3052769: success on attempt 1/1
# [batch_2 60/250] row 5cbc0b2b-a5b2-4f77-97bd-ba8c6d4ec74c: attempt 1/1 (deterministic)
# [batch_2 60/250] row 5cbc0b2b-a5b2-4f77-97bd-ba8c6d4ec74c: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 61/250] row ff1d3c30bedd80ff49645734fb3f0579: attempt 1/1 (deterministic)
# [batch_2 61/250] row ff1d3c30bedd80ff49645734fb3f0579: success on attempt 1/1
# [batch_2 62/250] row c4890de3e15f42c2f51407fdbee9c65b: attempt 1/1 (deterministic)
# [batch_2 62/250] row c4890de3e15f42c2f51407fdbee9c65b: success on attempt 1/1
# [batch_2 63/250] row b3bc18737e09298638058fc0e73edfe6: attempt 1/1 (deterministic)
# [batch_2 63/250] row b3bc18737e09298638058fc0e73edfe6: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_2 64/250] row b58139c55d43e791697567363c8a4460: attempt 1/1 (deterministic)
# [batch_2 64/250] row b58139c55d43e791697567363c8a4460: success on attempt 1/1
# [batch_2 65/250] row 1b91a87ceb02be159be9c622186fccb6: attempt 1/1 (deterministic)
# [batch_2 65/250] row 1b91a87ceb02be159be9c622186fccb6: success on attempt 1/1
# [batch_2 66/250] row 533830e799427ac90462e7bd2b8ccd83: attempt 1/1 (deterministic)
# [batch_2 66/250] row 533830e799427ac90462e7bd2b8ccd83: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 67/250] row 5d3523ac267ea453f2dee29b27742600: attempt 1/1 (deterministic)
# [batch_2 67/250] row 5d3523ac267ea453f2dee29b27742600: success on attempt 1/1
# [batch_2 68/250] row 6581c6cfae44dfbd3ebf4c2ff86fb790: attempt 1/1 (deterministic)
# [batch_2 68/250] row 6581c6cfae44dfbd3ebf4c2ff86fb790: success on attempt 1/1
# [batch_2 69/250] row ea93e12ab3ba63800e57b92baacf3b89: attempt 1/1 (deterministic)
# [batch_2 69/250] row ea93e12ab3ba63800e57b92baacf3b89: attempt 1/1 failed: unclosed token: line 10, column 4
# [batch_2 70/250] row ecc57ddb50404c8ca7b0ab8755108c12: attempt 1/1 (deterministic)
# [batch_2 70/250] row ecc57ddb50404c8ca7b0ab8755108c12: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 71/250] row 7aee9393-5a81-45ec-8865-e5f1ca18cbae: attempt 1/1 (deterministic)
# [batch_2 71/250] row 7aee9393-5a81-45ec-8865-e5f1ca18cbae: success on attempt 1/1
# [batch_2 72/250] row 423c3b02fb71e0cdeba220b5e5ceeb72: attempt 1/1 (deterministic)
# [batch_2 72/250] row 423c3b02fb71e0cdeba220b5e5ceeb72: attempt 1/1 failed: unclosed token: line 27, column 0
# [batch_2 73/250] row ed3be894-4384-47ff-9e48-9e38d4943630: attempt 1/1 (deterministic)
# [batch_2 73/250] row ed3be894-4384-47ff-9e48-9e38d4943630: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_2 74/250] row 0c87d84034ba5da6a50123b4dc98289b: attempt 1/1 (deterministic)
# [batch_2 74/250] row 0c87d84034ba5da6a50123b4dc98289b: success on attempt 1/1
# [batch_2 75/250] row 428732138d7c2b3af31515432bb3facc: attempt 1/1 (deterministic)
# [batch_2 75/250] row 428732138d7c2b3af31515432bb3facc: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 76/250] row bc765aee-0c85-4e1b-8e79-ca876ffc8c57: attempt 1/1 (deterministic)
# [batch_2 76/250] row bc765aee-0c85-4e1b-8e79-ca876ffc8c57: attempt 1/1 failed: unclosed token: line 27, column 2
# [batch_2 77/250] row 2b0ce303-8182-4b7f-90f1-379a2a350c41: attempt 1/1 (deterministic)
# [batch_2 77/250] row 2b0ce303-8182-4b7f-90f1-379a2a350c41: success on attempt 1/1
# [batch_2 78/250] row 132c4b91b99af7734d0a1d8a796c8990: attempt 1/1 (deterministic)
# [batch_2 78/250] row 132c4b91b99af7734d0a1d8a796c8990: attempt 1/1 failed: unclosed token: line 24, column 0
# [batch_2 79/250] row bb7dc129-a948-494c-960e-8a6728b3bac0: attempt 1/1 (deterministic)
# [batch_2 79/250] row bb7dc129-a948-494c-960e-8a6728b3bac0: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 80/250] row 14d9bf25fcbd9c1b7ef43d6c3ddfe5eb: attempt 1/1 (deterministic)
# [batch_2 80/250] row 14d9bf25fcbd9c1b7ef43d6c3ddfe5eb: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 81/250] row thesantatitan_deepseek-svg-dataset_0004735: attempt 1/1 (deterministic)
# [batch_2 81/250] row thesantatitan_deepseek-svg-dataset_0004735: success on attempt 1/1
# [batch_2 82/250] row 9080bb03-1946-4d44-9f51-b7c1a6120940: attempt 1/1 (deterministic)
# [batch_2 82/250] row 9080bb03-1946-4d44-9f51-b7c1a6120940: success on attempt 1/1
# [batch_2 83/250] row 649540a8fd20684a9d4bda3b637a0f03: attempt 1/1 (deterministic)
# [batch_2 83/250] row 649540a8fd20684a9d4bda3b637a0f03: success on attempt 1/1
# [batch_2 84/250] row 38f0152a-a6e2-4e37-9095-34e8000ed74d: attempt 1/1 (deterministic)
# [batch_2 84/250] row 38f0152a-a6e2-4e37-9095-34e8000ed74d: success on attempt 1/1
# [batch_2 85/250] row 7dd1b6b7383bc19f38cb73a81dce5f14: attempt 1/1 (deterministic)
# [batch_2 85/250] row 7dd1b6b7383bc19f38cb73a81dce5f14: success on attempt 1/1
# [batch_2 86/250] row thesantatitan_deepseek-svg-dataset_0002188: attempt 1/1 (deterministic)
# [batch_2 86/250] row thesantatitan_deepseek-svg-dataset_0002188: success on attempt 1/1
# [batch_2 87/250] row 2edfc92eb5e00ba4e6d1f3d6d55bf7db: attempt 1/1 (deterministic)
# [batch_2 87/250] row 2edfc92eb5e00ba4e6d1f3d6d55bf7db: success on attempt 1/1
# [batch_2 88/250] row f496d4356a37d545c2903fa36e493284: attempt 1/1 (deterministic)
# [batch_2 88/250] row f496d4356a37d545c2903fa36e493284: attempt 1/1 failed: unclosed token: line 17, column 0
# [batch_2 89/250] row 38b176737aaa3d129ece7d30211388ca: attempt 1/1 (deterministic)
# [batch_2 89/250] row 38b176737aaa3d129ece7d30211388ca: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_2 90/250] row thesantatitan_deepseek-svg-dataset_0002535: attempt 1/1 (deterministic)
# [batch_2 90/250] row thesantatitan_deepseek-svg-dataset_0002535: success on attempt 1/1
# [batch_2 91/250] row 8f6a8b2945e5f442f4aeaa8b3345b350: attempt 1/1 (deterministic)
# [batch_2 91/250] row 8f6a8b2945e5f442f4aeaa8b3345b350: success on attempt 1/1
# [batch_2 92/250] row b7915534de58d3a9d1ba0129d36a52cd: attempt 1/1 (deterministic)
# [batch_2 92/250] row b7915534de58d3a9d1ba0129d36a52cd: success on attempt 1/1
# [batch_2 93/250] row 10054d5e97923c31d3f090a7be76cfec: attempt 1/1 (deterministic)
# [batch_2 93/250] row 10054d5e97923c31d3f090a7be76cfec: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 94/250] row 060d74da90afa9b3f8f14237c83d1970: attempt 1/1 (deterministic)
# [batch_2 94/250] row 060d74da90afa9b3f8f14237c83d1970: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 95/250] row d33e9257f3f4d1374dcda52d920d65d1: attempt 1/1 (deterministic)
# [batch_2 95/250] row d33e9257f3f4d1374dcda52d920d65d1: success on attempt 1/1
# [batch_2 96/250] row 28c00a3a8e0e7c38d848fdb6a90a0933: attempt 1/1 (deterministic)
# [batch_2 96/250] row 28c00a3a8e0e7c38d848fdb6a90a0933: success on attempt 1/1
# [batch_2 97/250] row 694eec9473b383b64843412844164b9a: attempt 1/1 (deterministic)
# [batch_2 97/250] row 694eec9473b383b64843412844164b9a: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_2 98/250] row 07388aecbe3020febb41744d568c32e5: attempt 1/1 (deterministic)
# [batch_2 98/250] row 07388aecbe3020febb41744d568c32e5: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_2 99/250] row c8de301d35c53d0e72df6ae56edde621: attempt 1/1 (deterministic)
# [batch_2 99/250] row c8de301d35c53d0e72df6ae56edde621: success on attempt 1/1
# [batch_2 100/250] row efa84cbc19adddf53f8fded9de39185c: attempt 1/1 (deterministic)
# [batch_2 100/250] row efa84cbc19adddf53f8fded9de39185c: success on attempt 1/1
# [batch_2 101/250] row 4ceb2de56b8a4a667bab0cbe761d1dbc: attempt 1/1 (deterministic)
# [batch_2 101/250] row 4ceb2de56b8a4a667bab0cbe761d1dbc: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_2 102/250] row 08622d6ae1ffc2c7945fb76c5ee21b2c: attempt 1/1 (deterministic)
# [batch_2 102/250] row 08622d6ae1ffc2c7945fb76c5ee21b2c: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 103/250] row fc6850e28ca47e7c4620a0a810b0a33f: attempt 1/1 (deterministic)
# [batch_2 103/250] row fc6850e28ca47e7c4620a0a810b0a33f: attempt 1/1 failed: unclosed token: line 18, column 0
# [batch_2 104/250] row 4ffbff366fc8a0973cfe6f31d034bbff: attempt 1/1 (deterministic)
# [batch_2 104/250] row 4ffbff366fc8a0973cfe6f31d034bbff: success on attempt 1/1
# [batch_2 105/250] row 49484c41779a745a90c961b0ed141a99: attempt 1/1 (deterministic)
# [batch_2 105/250] row 49484c41779a745a90c961b0ed141a99: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_2 106/250] row 305ead77-a8ba-4258-9a52-388ab6b33bfd: attempt 1/1 (deterministic)
# [batch_2 106/250] row 305ead77-a8ba-4258-9a52-388ab6b33bfd: success on attempt 1/1
# [batch_2 107/250] row 0b846be714c0cb5d1d68af1ad1c5b4cf: attempt 1/1 (deterministic)
# [batch_2 107/250] row 0b846be714c0cb5d1d68af1ad1c5b4cf: success on attempt 1/1
# [batch_2 108/250] row 0444cb0e-f24d-49ea-b958-61c50002b7f8: attempt 1/1 (deterministic)
# [batch_2 108/250] row 0444cb0e-f24d-49ea-b958-61c50002b7f8: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_2 109/250] row 8dd45f18ee9d2a7d1e7b16fce184e99b: attempt 1/1 (deterministic)
# [batch_2 109/250] row 8dd45f18ee9d2a7d1e7b16fce184e99b: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_2 110/250] row 97807803c0b98a7c0204b3d651b01215: attempt 1/1 (deterministic)
# [batch_2 110/250] row 97807803c0b98a7c0204b3d651b01215: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_2 111/250] row 8af3927f4b61dd96b13296860a9d079d: attempt 1/1 (deterministic)
# [batch_2 111/250] row 8af3927f4b61dd96b13296860a9d079d: success on attempt 1/1
# [batch_2 112/250] row ee959eba320678966980b5266489ed0f: attempt 1/1 (deterministic)
# [batch_2 112/250] row ee959eba320678966980b5266489ed0f: success on attempt 1/1
# [batch_2 113/250] row 749dbb938050d35c5fcdf4f9d378d8a3: attempt 1/1 (deterministic)
# [batch_2 113/250] row 749dbb938050d35c5fcdf4f9d378d8a3: success on attempt 1/1
# [batch_2 114/250] row 12ef9d71b62d5ed7808cbde91910a258: attempt 1/1 (deterministic)
# [batch_2 114/250] row 12ef9d71b62d5ed7808cbde91910a258: success on attempt 1/1
# [batch_2 115/250] row 712fb5ad9547a2a859eed9fc42f1cf8d: attempt 1/1 (deterministic)
# [batch_2 115/250] row 712fb5ad9547a2a859eed9fc42f1cf8d: success on attempt 1/1
# [batch_2 116/250] row cee975d169c6ff0d78bb5572b404ccf6: attempt 1/1 (deterministic)
# [batch_2 116/250] row cee975d169c6ff0d78bb5572b404ccf6: success on attempt 1/1
# [batch_2 117/250] row d907bc994c744afd038f7bdd8e1b6cc1: attempt 1/1 (deterministic)
# [batch_2 117/250] row d907bc994c744afd038f7bdd8e1b6cc1: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 118/250] row b4b86740ca1f1b94f64e12a31805941a: attempt 1/1 (deterministic)
# [batch_2 118/250] row b4b86740ca1f1b94f64e12a31805941a: success on attempt 1/1
# [batch_2 119/250] row a4505046b1476f0c056dd2a5f2d50e5f: attempt 1/1 (deterministic)
# [batch_2 119/250] row a4505046b1476f0c056dd2a5f2d50e5f: success on attempt 1/1
# [batch_2 120/250] row d6d1dee2a2fde7b349762e48c63b6c07: attempt 1/1 (deterministic)
# [batch_2 120/250] row d6d1dee2a2fde7b349762e48c63b6c07: success on attempt 1/1
# [batch_2 121/250] row thesantatitan_deepseek-svg-dataset_0000669: attempt 1/1 (deterministic)
# [batch_2 121/250] row thesantatitan_deepseek-svg-dataset_0000669: success on attempt 1/1
# [batch_2 122/250] row 8b9186dca63a14a1480c50ae3001b884: attempt 1/1 (deterministic)
# [batch_2 122/250] row 8b9186dca63a14a1480c50ae3001b884: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_2 123/250] row 0d023a70ccb244ddb37957856d357020: attempt 1/1 (deterministic)
# [batch_2 123/250] row 0d023a70ccb244ddb37957856d357020: success on attempt 1/1
# [batch_2 124/250] row 5d08388622a8416c9f124edb303655ab: attempt 1/1 (deterministic)
# [batch_2 124/250] row 5d08388622a8416c9f124edb303655ab: attempt 1/1 failed: unclosed token: line 10, column 0
# [batch_2 125/250] row 77d1b3e5aafa26213a17a50e348a2a14: attempt 1/1 (deterministic)
# [batch_2 125/250] row 77d1b3e5aafa26213a17a50e348a2a14: success on attempt 1/1
# [batch_2 126/250] row 480304d1813794757ea03b689a26e3c6: attempt 1/1 (deterministic)
# [batch_2 126/250] row 480304d1813794757ea03b689a26e3c6: success on attempt 1/1
# [batch_2 127/250] row 3c89ac21-2c9c-4285-993e-bb2ed4f4132d: attempt 1/1 (deterministic)
# [batch_2 127/250] row 3c89ac21-2c9c-4285-993e-bb2ed4f4132d: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_2 128/250] row 211ac579-e807-43a9-89a3-f8126433ed69: attempt 1/1 (deterministic)
# [batch_2 128/250] row 211ac579-e807-43a9-89a3-f8126433ed69: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_2 129/250] row 60372742fd10015e9215dca9917f651b: attempt 1/1 (deterministic)
# [batch_2 129/250] row 60372742fd10015e9215dca9917f651b: success on attempt 1/1
# [batch_2 130/250] row b75b5b813208c3575eae23e7f8441c9c: attempt 1/1 (deterministic)
# [batch_2 130/250] row b75b5b813208c3575eae23e7f8441c9c: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_2 131/250] row 21710155389cd47c795b518a3b0b8de5: attempt 1/1 (deterministic)
# [batch_2 131/250] row 21710155389cd47c795b518a3b0b8de5: success on attempt 1/1
# [batch_2 132/250] row d7b5a8761701fde714108908b207ffc9: attempt 1/1 (deterministic)
# [batch_2 132/250] row d7b5a8761701fde714108908b207ffc9: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_2 133/250] row 402dd1d6c8a1a3c341dc453dead18b97: attempt 1/1 (deterministic)
# [batch_2 133/250] row 402dd1d6c8a1a3c341dc453dead18b97: attempt 1/1 failed: unclosed token: line 10, column 0
# [batch_2 134/250] row e8aee3776894d20b70727aa265e3c8b6: attempt 1/1 (deterministic)
# [batch_2 134/250] row e8aee3776894d20b70727aa265e3c8b6: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 135/250] row b068c6bc0dab328b6027ccd02d03b174: attempt 1/1 (deterministic)
# [batch_2 135/250] row b068c6bc0dab328b6027ccd02d03b174: success on attempt 1/1
# [batch_2 136/250] row d960f5de-3ab1-41a3-8db1-853e895889ec: attempt 1/1 (deterministic)
# [batch_2 136/250] row d960f5de-3ab1-41a3-8db1-853e895889ec: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 137/250] row 22df98911f5c5a5eabc508e739730daf: attempt 1/1 (deterministic)
# [batch_2 137/250] row 22df98911f5c5a5eabc508e739730daf: success on attempt 1/1
# [batch_2 138/250] row 9ca610ffc3aa94ee90b8fad40f39f2ce: attempt 1/1 (deterministic)
# [batch_2 138/250] row 9ca610ffc3aa94ee90b8fad40f39f2ce: success on attempt 1/1
# [batch_2 139/250] row 6cafe414afbff1122a96ac8f0a9ce893: attempt 1/1 (deterministic)
# [batch_2 139/250] row 6cafe414afbff1122a96ac8f0a9ce893: success on attempt 1/1
# [batch_2 140/250] row 8e1fadf0ca78b939adfb003d4e011a0e: attempt 1/1 (deterministic)
# [batch_2 140/250] row 8e1fadf0ca78b939adfb003d4e011a0e: attempt 1/1 failed: unclosed token: line 10, column 0
# [batch_2 141/250] row ab976da55b074a76089bd31cf654dc11: attempt 1/1 (deterministic)
# [batch_2 141/250] row ab976da55b074a76089bd31cf654dc11: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_2 142/250] row 7d41f40dc025829b6c2c3f9370aa91ab: attempt 1/1 (deterministic)
# [batch_2 142/250] row 7d41f40dc025829b6c2c3f9370aa91ab: success on attempt 1/1
# [batch_2 143/250] row ec89d045d7ac2c5bba7e3a7b7f2ecfe3: attempt 1/1 (deterministic)
# [batch_2 143/250] row ec89d045d7ac2c5bba7e3a7b7f2ecfe3: success on attempt 1/1
# [batch_2 144/250] row 68e2e535-32c9-48fd-a9f6-9c4b2c411e58: attempt 1/1 (deterministic)
# [batch_2 144/250] row 68e2e535-32c9-48fd-a9f6-9c4b2c411e58: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 145/250] row 8c7c71f2fa98547406cb8e566921b0f0: attempt 1/1 (deterministic)
# [batch_2 145/250] row 8c7c71f2fa98547406cb8e566921b0f0: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 146/250] row 61b523b078eb8c534f9f61b1a98b3c59: attempt 1/1 (deterministic)
# [batch_2 146/250] row 61b523b078eb8c534f9f61b1a98b3c59: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_2 147/250] row 25ed85dba28ae2d20a0d38f681d5a613: attempt 1/1 (deterministic)
# [batch_2 147/250] row 25ed85dba28ae2d20a0d38f681d5a613: attempt 1/1 failed: unclosed token: line 8, column 2
# [batch_2 148/250] row 2e096cabf70630aa429df802aadee781: attempt 1/1 (deterministic)
# [batch_2 148/250] row 2e096cabf70630aa429df802aadee781: success on attempt 1/1
# [batch_2 149/250] row 233eefc40f52085d4f6005f113561a01: attempt 1/1 (deterministic)
# [batch_2 149/250] row 233eefc40f52085d4f6005f113561a01: success on attempt 1/1
# [batch_2 150/250] row d47c83db86be1d46ff99cbff54fc0db9: attempt 1/1 (deterministic)
# [batch_2 150/250] row d47c83db86be1d46ff99cbff54fc0db9: success on attempt 1/1
# [batch_2 151/250] row thesantatitan_deepseek-svg-dataset_0003106: attempt 1/1 (deterministic)
# [batch_2 151/250] row thesantatitan_deepseek-svg-dataset_0003106: success on attempt 1/1
# [batch_2 152/250] row a8a0ac74fb0e26c88d053271946e75f5: attempt 1/1 (deterministic)
# [batch_2 152/250] row a8a0ac74fb0e26c88d053271946e75f5: success on attempt 1/1
# [batch_2 153/250] row 6ac4b137-01f0-42d6-b8c0-95de2b9dd062: attempt 1/1 (deterministic)
# [batch_2 153/250] row 6ac4b137-01f0-42d6-b8c0-95de2b9dd062: attempt 1/1 failed: unclosed token: line 12, column 0
# [batch_2 154/250] row thesantatitan_deepseek-svg-dataset_0001432: attempt 1/1 (deterministic)
# [batch_2 154/250] row thesantatitan_deepseek-svg-dataset_0001432: attempt 1/1 failed: unclosed token: line 16, column 2
# [batch_2 155/250] row 72621a2124e5b0f27cab11a405fbd9d0: attempt 1/1 (deterministic)
# [batch_2 155/250] row 72621a2124e5b0f27cab11a405fbd9d0: success on attempt 1/1
# [batch_2 156/250] row 3d5d85ea2a76724290395124ef144432: attempt 1/1 (deterministic)
# [batch_2 156/250] row 3d5d85ea2a76724290395124ef144432: success on attempt 1/1
# [batch_2 157/250] row 08c13c16f4d8476b993b5784da3f12a3: attempt 1/1 (deterministic)
# [batch_2 157/250] row 08c13c16f4d8476b993b5784da3f12a3: success on attempt 1/1
# [batch_2 158/250] row 7b9efac1b032eb8136bc0f107f0fe6e6: attempt 1/1 (deterministic)
# [batch_2 158/250] row 7b9efac1b032eb8136bc0f107f0fe6e6: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_2 159/250] row a802656c9b712d3db0d6beb1cb1714be: attempt 1/1 (deterministic)
# [batch_2 159/250] row a802656c9b712d3db0d6beb1cb1714be: attempt 1/1 failed: unclosed token: line 19, column 4
# [batch_2 160/250] row 349f7e64432849df0db439b6249505c2: attempt 1/1 (deterministic)
# [batch_2 160/250] row 349f7e64432849df0db439b6249505c2: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_2 161/250] row e578c171a54f34c07c5b55bba5d61300: attempt 1/1 (deterministic)
# [batch_2 161/250] row e578c171a54f34c07c5b55bba5d61300: success on attempt 1/1
# [batch_2 162/250] row da6187528883b34f87a786adfc557953: attempt 1/1 (deterministic)
# [batch_2 162/250] row da6187528883b34f87a786adfc557953: success on attempt 1/1
# [batch_2 163/250] row b84924bd560d42becb4bde638d5a721f: attempt 1/1 (deterministic)
# [batch_2 163/250] row b84924bd560d42becb4bde638d5a721f: success on attempt 1/1
# [batch_2 164/250] row 2391d53e06ffc3fb8fd335429b75ce9c: attempt 1/1 (deterministic)
# [batch_2 164/250] row 2391d53e06ffc3fb8fd335429b75ce9c: success on attempt 1/1
# [batch_2 165/250] row 1fb2fc7afab9adb52a5f1fb0daefa0fe: attempt 1/1 (deterministic)
# [batch_2 165/250] row 1fb2fc7afab9adb52a5f1fb0daefa0fe: success on attempt 1/1
# [batch_2 166/250] row bd62059c6dddc7fc2566d415cdcf6b86: attempt 1/1 (deterministic)
# [batch_2 166/250] row bd62059c6dddc7fc2566d415cdcf6b86: success on attempt 1/1
# [batch_2 167/250] row 53c93380b8d336542d7d4d4fdd7e3df0: attempt 1/1 (deterministic)
# [batch_2 167/250] row 53c93380b8d336542d7d4d4fdd7e3df0: success on attempt 1/1
# [batch_2 168/250] row 06dac9a2b00ae93b160a9fd33ff275f1: attempt 1/1 (deterministic)
# [batch_2 168/250] row 06dac9a2b00ae93b160a9fd33ff275f1: success on attempt 1/1
# [batch_2 169/250] row 7dc444501e5eae3d56e2166fd6dbfdba: attempt 1/1 (deterministic)
# [batch_2 169/250] row 7dc444501e5eae3d56e2166fd6dbfdba: success on attempt 1/1
# [batch_2 170/250] row c9497e732d693769be0341de77468546: attempt 1/1 (deterministic)
# [batch_2 170/250] row c9497e732d693769be0341de77468546: attempt 1/1 failed: unclosed token: line 14, column 4
# [batch_2 171/250] row 066676c0-8181-4092-a6c0-29c7ce8342d5: attempt 1/1 (deterministic)
# [batch_2 171/250] row 066676c0-8181-4092-a6c0-29c7ce8342d5: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 172/250] row 08c4fe4b67eb5bde0560c776797a0b30: attempt 1/1 (deterministic)
# [batch_2 172/250] row 08c4fe4b67eb5bde0560c776797a0b30: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_2 173/250] row aad6f0ae0528efb062bf9b084cf8fbbe: attempt 1/1 (deterministic)
# [batch_2 173/250] row aad6f0ae0528efb062bf9b084cf8fbbe: success on attempt 1/1
# [batch_2 174/250] row bd1c691a8b93a5902b8e608009409b26: attempt 1/1 (deterministic)
# [batch_2 174/250] row bd1c691a8b93a5902b8e608009409b26: success on attempt 1/1
# [batch_2 175/250] row 68576ccc57bb97748fa1cbe13f37d971: attempt 1/1 (deterministic)
# [batch_2 175/250] row 68576ccc57bb97748fa1cbe13f37d971: success on attempt 1/1
# [batch_2 176/250] row d46706e4afd71b39bf6c7715fac7ce49: attempt 1/1 (deterministic)
# [batch_2 176/250] row d46706e4afd71b39bf6c7715fac7ce49: success on attempt 1/1
# [batch_2 177/250] row 3712aaefea588dcfcbe2c40a038c9024: attempt 1/1 (deterministic)
# [batch_2 177/250] row 3712aaefea588dcfcbe2c40a038c9024: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_2 178/250] row 4c16131d4cc415d991a52a9bcfe32b8d: attempt 1/1 (deterministic)
# [batch_2 178/250] row 4c16131d4cc415d991a52a9bcfe32b8d: success on attempt 1/1
# [batch_2 179/250] row c673cfef632658ba00e3ce635f562901: attempt 1/1 (deterministic)
# [batch_2 179/250] row c673cfef632658ba00e3ce635f562901: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_2 180/250] row 26994bd1171078b92a9957f977eed87c: attempt 1/1 (deterministic)
# [batch_2 180/250] row 26994bd1171078b92a9957f977eed87c: success on attempt 1/1
# [batch_2 181/250] row b964937ebec4f76d545638387655b38f: attempt 1/1 (deterministic)
# [batch_2 181/250] row b964937ebec4f76d545638387655b38f: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_2 182/250] row 3aeea789ed0e181f35968bafa8dded49: attempt 1/1 (deterministic)
# [batch_2 182/250] row 3aeea789ed0e181f35968bafa8dded49: success on attempt 1/1
# [batch_2 183/250] row c499d6062b8a598d6b5838d4792d7a41: attempt 1/1 (deterministic)
# [batch_2 183/250] row c499d6062b8a598d6b5838d4792d7a41: success on attempt 1/1
# [batch_2 184/250] row e7fa87cc7182de4add86460c905587df: attempt 1/1 (deterministic)
# [batch_2 184/250] row e7fa87cc7182de4add86460c905587df: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 185/250] row 8f4cfa5a-fb08-4eb1-aea3-e3601a18be4f: attempt 1/1 (deterministic)
# [batch_2 185/250] row 8f4cfa5a-fb08-4eb1-aea3-e3601a18be4f: success on attempt 1/1
# [batch_2 186/250] row 012864599f873514017c173770026982: attempt 1/1 (deterministic)
# [batch_2 186/250] row 012864599f873514017c173770026982: success on attempt 1/1
# [batch_2 187/250] row beed40817d966fca026c732b444c508e: attempt 1/1 (deterministic)
# [batch_2 187/250] row beed40817d966fca026c732b444c508e: success on attempt 1/1
# [batch_2 188/250] row 487f11a6f680d71ed8e1a90cf6e3e943: attempt 1/1 (deterministic)
# [batch_2 188/250] row 487f11a6f680d71ed8e1a90cf6e3e943: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 189/250] row thesantatitan_deepseek-svg-dataset_0004275: attempt 1/1 (deterministic)
# [batch_2 189/250] row thesantatitan_deepseek-svg-dataset_0004275: attempt 1/1 failed: unclosed token: line 16, column 2
# [batch_2 190/250] row 15816e0ecf760d38536ed9d1c1043ea8: attempt 1/1 (deterministic)
# [batch_2 190/250] row 15816e0ecf760d38536ed9d1c1043ea8: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 191/250] row 4155430a-4529-49e0-aff0-19bc632a770a: attempt 1/1 (deterministic)
# [batch_2 191/250] row 4155430a-4529-49e0-aff0-19bc632a770a: success on attempt 1/1
# [batch_2 192/250] row 25b3fc6e871febfd8a5aabf7dd75f3ea: attempt 1/1 (deterministic)
# [batch_2 192/250] row 25b3fc6e871febfd8a5aabf7dd75f3ea: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_2 193/250] row b3c9803cc62fa3a5074a40332ed1914b: attempt 1/1 (deterministic)
# [batch_2 193/250] row b3c9803cc62fa3a5074a40332ed1914b: success on attempt 1/1
# [batch_2 194/250] row 4b3c3ff3dcac0299c4c7c83307487357: attempt 1/1 (deterministic)
# [batch_2 194/250] row 4b3c3ff3dcac0299c4c7c83307487357: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_2 195/250] row 20986efd4f1d0ec5b9b56785d47d965e: attempt 1/1 (deterministic)
# [batch_2 195/250] row 20986efd4f1d0ec5b9b56785d47d965e: success on attempt 1/1
# [batch_2 196/250] row 2851c25b3ceb6e15363bd1e8e6b0b8e8: attempt 1/1 (deterministic)
# [batch_2 196/250] row 2851c25b3ceb6e15363bd1e8e6b0b8e8: attempt 1/1 failed: unclosed token: line 4, column 0
# [batch_2 197/250] row bf12a0c8-379b-4661-af84-94a26b15a80e: attempt 1/1 (deterministic)
# [batch_2 197/250] row bf12a0c8-379b-4661-af84-94a26b15a80e: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 198/250] row 93bac8b8e5cfb84cfd53f337293f9775: attempt 1/1 (deterministic)
# [batch_2 198/250] row 93bac8b8e5cfb84cfd53f337293f9775: success on attempt 1/1
# [batch_2 199/250] row ce54df39bd2cc3f034d0e9ad37b57e54: attempt 1/1 (deterministic)
# [batch_2 199/250] row ce54df39bd2cc3f034d0e9ad37b57e54: success on attempt 1/1
# [batch_2 200/250] row 363d477f8036ac66e42ead865d12c9e8: attempt 1/1 (deterministic)
# [batch_2 200/250] row 363d477f8036ac66e42ead865d12c9e8: success on attempt 1/1
# [batch_2 201/250] row afda3458e088c1f3d2bf6ade3d448fa6: attempt 1/1 (deterministic)
# [batch_2 201/250] row afda3458e088c1f3d2bf6ade3d448fa6: success on attempt 1/1
# [batch_2 202/250] row f79a5b0b-ca8a-492f-9edd-4c09fe80ad34: attempt 1/1 (deterministic)
# [batch_2 202/250] row f79a5b0b-ca8a-492f-9edd-4c09fe80ad34: success on attempt 1/1
# [batch_2 203/250] row eeb810ad1f6d55ae95bd61cb3cf9d54b: attempt 1/1 (deterministic)
# [batch_2 203/250] row eeb810ad1f6d55ae95bd61cb3cf9d54b: success on attempt 1/1
# [batch_2 204/250] row 9eff1981af2d3adfdfa60004557b43a4: attempt 1/1 (deterministic)
# [batch_2 204/250] row 9eff1981af2d3adfdfa60004557b43a4: success on attempt 1/1
# [batch_2 205/250] row 30d5bc926cf885da954cfe2ed9bca5e0: attempt 1/1 (deterministic)
# [batch_2 205/250] row 30d5bc926cf885da954cfe2ed9bca5e0: attempt 1/1 failed: unclosed token: line 16, column 4
# [batch_2 206/250] row 87fc9ad6d0953f556f3f0d36a9e6abee: attempt 1/1 (deterministic)
# [batch_2 206/250] row 87fc9ad6d0953f556f3f0d36a9e6abee: success on attempt 1/1
# [batch_2 207/250] row 068efa43794f885e51025d7fd682f50e: attempt 1/1 (deterministic)
# [batch_2 207/250] row 068efa43794f885e51025d7fd682f50e: success on attempt 1/1
# [batch_2 208/250] row fe163c205f88c88bd83c9eeefb5cf5f7: attempt 1/1 (deterministic)
# [batch_2 208/250] row fe163c205f88c88bd83c9eeefb5cf5f7: success on attempt 1/1
# [batch_2 209/250] row 592e346300a900eac1eb0fa0b32ae657: attempt 1/1 (deterministic)
# [batch_2 209/250] row 592e346300a900eac1eb0fa0b32ae657: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 210/250] row 1cb3f7c5409a7bc41be0c8192a60cb97: attempt 1/1 (deterministic)
# [batch_2 210/250] row 1cb3f7c5409a7bc41be0c8192a60cb97: success on attempt 1/1
# [batch_2 211/250] row afe06d3bbc251bbd6aaeb0ebedf1191c: attempt 1/1 (deterministic)
# [batch_2 211/250] row afe06d3bbc251bbd6aaeb0ebedf1191c: success on attempt 1/1
# [batch_2 212/250] row 992e35eb052c94802ca82064711a49c9: attempt 1/1 (deterministic)
# [batch_2 212/250] row 992e35eb052c94802ca82064711a49c9: success on attempt 1/1
# [batch_2 213/250] row 24b34f9251b33158b5fbb94a430cedaf: attempt 1/1 (deterministic)
# [batch_2 213/250] row 24b34f9251b33158b5fbb94a430cedaf: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_2 214/250] row f5195281cbde1f30eb5a15aa0fd70bbe: attempt 1/1 (deterministic)
# [batch_2 214/250] row f5195281cbde1f30eb5a15aa0fd70bbe: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_2 215/250] row af1e68518f76d8d893cd2eee9415c11d: attempt 1/1 (deterministic)
# [batch_2 215/250] row af1e68518f76d8d893cd2eee9415c11d: attempt 1/1 failed: unclosed token: line 18, column 0
# [batch_2 216/250] row 3966e08c3d5f49f093bcf2c55a03afa0: attempt 1/1 (deterministic)
# [batch_2 216/250] row 3966e08c3d5f49f093bcf2c55a03afa0: success on attempt 1/1
# [batch_2 217/250] row thesantatitan_deepseek-svg-dataset_0000625: attempt 1/1 (deterministic)
# [batch_2 217/250] row thesantatitan_deepseek-svg-dataset_0000625: success on attempt 1/1
# [batch_2 218/250] row 0c4c70a3672a69359fc35986cec3a40e: attempt 1/1 (deterministic)
# [batch_2 218/250] row 0c4c70a3672a69359fc35986cec3a40e: success on attempt 1/1
# [batch_2 219/250] row c34bc238145cb0dcdd1ec8101ec219e0: attempt 1/1 (deterministic)
# [batch_2 219/250] row c34bc238145cb0dcdd1ec8101ec219e0: success on attempt 1/1
# [batch_2 220/250] row a76155e15411f7f5fd94bc02a4ab6941: attempt 1/1 (deterministic)
# [batch_2 220/250] row a76155e15411f7f5fd94bc02a4ab6941: success on attempt 1/1
# [batch_2 221/250] row ac2b7fa7392fe4da83562436461a28ca: attempt 1/1 (deterministic)
# [batch_2 221/250] row ac2b7fa7392fe4da83562436461a28ca: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_2 222/250] row 65f76990299ca74cd6deef0395202bbb: attempt 1/1 (deterministic)
# [batch_2 222/250] row 65f76990299ca74cd6deef0395202bbb: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_2 223/250] row 5a414dc713e9d2967474bb9394789712: attempt 1/1 (deterministic)
# [batch_2 223/250] row 5a414dc713e9d2967474bb9394789712: success on attempt 1/1
# [batch_2 224/250] row f964d85da109fe4774a76a7b5acce9d5: attempt 1/1 (deterministic)
# [batch_2 224/250] row f964d85da109fe4774a76a7b5acce9d5: attempt 1/1 failed: unclosed token: line 7, column 0
# [batch_2 225/250] row 2559b460433538b805da78a4248053c4: attempt 1/1 (deterministic)
# [batch_2 225/250] row 2559b460433538b805da78a4248053c4: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 226/250] row 6171431e6fd4be7aec781fe6f86a7260: attempt 1/1 (deterministic)
# [batch_2 226/250] row 6171431e6fd4be7aec781fe6f86a7260: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_2 227/250] row dc9937b7f8ac24ae5cfeb6292e174339: attempt 1/1 (deterministic)
# [batch_2 227/250] row dc9937b7f8ac24ae5cfeb6292e174339: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 228/250] row 09ffc9113cc361c62d1093d82385ccc9: attempt 1/1 (deterministic)
# [batch_2 228/250] row 09ffc9113cc361c62d1093d82385ccc9: success on attempt 1/1
# [batch_2 229/250] row 7794bf395f0e23235313e6f6b64824b8: attempt 1/1 (deterministic)
# [batch_2 229/250] row 7794bf395f0e23235313e6f6b64824b8: attempt 1/1 failed: unclosed token: line 16, column 4
# [batch_2 230/250] row 66065b7a-be96-4ad5-8d3e-2510c38e9312: attempt 1/1 (deterministic)
# [batch_2 230/250] row 66065b7a-be96-4ad5-8d3e-2510c38e9312: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_2 231/250] row bb383be6-efd5-4266-858d-26dd6e01382e: attempt 1/1 (deterministic)
# [batch_2 231/250] row bb383be6-efd5-4266-858d-26dd6e01382e: success on attempt 1/1
# [batch_2 232/250] row 81aca13a-c934-4433-a8f9-847b9ab81581: attempt 1/1 (deterministic)
# [batch_2 232/250] row 81aca13a-c934-4433-a8f9-847b9ab81581: attempt 1/1 failed: unclosed token: line 12, column 0
# [batch_2 233/250] row 0bdead1c59587f304730dc559bd0077d: attempt 1/1 (deterministic)
# [batch_2 233/250] row 0bdead1c59587f304730dc559bd0077d: attempt 1/1 failed: unclosed token: line 11, column 4
# [batch_2 234/250] row cd1983cf12ee2015f55b6234a90ca5aa: attempt 1/1 (deterministic)
# [batch_2 234/250] row cd1983cf12ee2015f55b6234a90ca5aa: success on attempt 1/1
# [batch_2 235/250] row c03c6485-765b-4c86-9bfd-4428fb1ef0b5: attempt 1/1 (deterministic)
# [batch_2 235/250] row c03c6485-765b-4c86-9bfd-4428fb1ef0b5: attempt 1/1 failed: unclosed token: line 19, column 2
# [batch_2 236/250] row 00dc7f04-c2ce-441b-8ebf-431d6d23eaec: attempt 1/1 (deterministic)
# [batch_2 236/250] row 00dc7f04-c2ce-441b-8ebf-431d6d23eaec: success on attempt 1/1
# [batch_2 237/250] row 2707ad13f72707b60f69c3811701c1b5: attempt 1/1 (deterministic)
# [batch_2 237/250] row 2707ad13f72707b60f69c3811701c1b5: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 238/250] row fcbd3dd0f3205055864a080f786642fe: attempt 1/1 (deterministic)
# [batch_2 238/250] row fcbd3dd0f3205055864a080f786642fe: success on attempt 1/1
# [batch_2 239/250] row 1b345ad059582af46300c46bb39ebd70: attempt 1/1 (deterministic)
# [batch_2 239/250] row 1b345ad059582af46300c46bb39ebd70: success on attempt 1/1
# [batch_2 240/250] row 6d950c48fe42ed6b32b64f641d4d0f40: attempt 1/1 (deterministic)
# [batch_2 240/250] row 6d950c48fe42ed6b32b64f641d4d0f40: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_2 241/250] row 6a6ca488-0ca7-43e0-be5e-3a4bd9d0950c: attempt 1/1 (deterministic)
# [batch_2 241/250] row 6a6ca488-0ca7-43e0-be5e-3a4bd9d0950c: success on attempt 1/1
# [batch_2 242/250] row 57d5c6abde8998c16c29acd67057160a: attempt 1/1 (deterministic)
# [batch_2 242/250] row 57d5c6abde8998c16c29acd67057160a: success on attempt 1/1
# [batch_2 243/250] row f98e788a-cb5b-4f6d-a42f-88f10527d4f1: attempt 1/1 (deterministic)
# [batch_2 243/250] row f98e788a-cb5b-4f6d-a42f-88f10527d4f1: success on attempt 1/1
# [batch_2 244/250] row ab70b374f4f09f6f3702b0c6484597e5: attempt 1/1 (deterministic)
# [batch_2 244/250] row ab70b374f4f09f6f3702b0c6484597e5: attempt 1/1 failed: unclosed token: line 20, column 2
# [batch_2 245/250] row e4356d8c-b193-4988-8af7-46dbfa0b3906: attempt 1/1 (deterministic)
# [batch_2 245/250] row e4356d8c-b193-4988-8af7-46dbfa0b3906: success on attempt 1/1
# [batch_2 246/250] row 3aced3ceb1f4f809cc7362157856a47e: attempt 1/1 (deterministic)
# [batch_2 246/250] row 3aced3ceb1f4f809cc7362157856a47e: attempt 1/1 failed: unclosed token: line 4, column 0
# [batch_2 247/250] row 92ed8fec183f86a232b1a1bad759b94a: attempt 1/1 (deterministic)
# [batch_2 247/250] row 92ed8fec183f86a232b1a1bad759b94a: success on attempt 1/1
# [batch_2 248/250] row bf5739d50c3812db213e09c84aa7bece: attempt 1/1 (deterministic)
# [batch_2 248/250] row bf5739d50c3812db213e09c84aa7bece: success on attempt 1/1
# [batch_2 249/250] row c6a4b8f080508bd24a33f1473686429b: attempt 1/1 (deterministic)
# [batch_2 249/250] row c6a4b8f080508bd24a33f1473686429b: attempt 1/1 failed: unclosed token: line 7, column 0
# [batch_2 250/250] row 8972c992608f4a9abf73a5836aad48a7: attempt 1/1 (deterministic)
# [batch_2 250/250] row 8972c992608f4a9abf73a5836aad48a7: success on attempt 1/1
# Wrote batch artifacts to: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_2

# %% [markdown]
# ## Batch Summary
#
# Show the first-pass success/failure totals and inspect a few failed rows with their gate errors.
#
# - Reads: Batch result artifacts in memory
# - Writes: Nothing
# - Rerun-safe: Yes. Read-only display cell.

# %%
display(pipeline.summarize_batch_results(FIRST_PASS_RESULTS_DF))
FAILED_DF = FIRST_PASS_RESULTS_DF[~FIRST_PASS_RESULTS_DF["first_pass_success"]].copy()
if FAILED_DF.empty:
    print("No failed rows in this batch.")
else:
    display(FAILED_DF[["id", "row_index", "generation_mode", "gate_error"]].head(20))
# Out:
#                     metric       value
# 0                     rows  250.000000
# 1     first_pass_successes  142.000000
# 2      first_pass_failures  108.000000
# 3     mean_runtime_seconds   31.183713
# 4  mean_char_len_successes  381.126761
#                                       id  row_index generation_mode  \
# 0       34c190727cce6d1ea6d41e76ec560860        250        full_svg
# 3       eac44be984595232d314038a2de321ab        253        full_svg
# 7   a198f33e-3ec4-4932-8a5e-8266f5ef9ee1        257        full_svg
# 13  abaca1bd-1bb3-4dec-9316-76cd5bbcb07e        263        full_svg
# 14      973b240f0cb9d52940206c72b8acef67        264        full_svg
# 16      2ecac2a7259aa42b1f34ae1ca7a84304        266        full_svg
# 17  9a0c9dc7-ff3e-45df-9040-01ea6572ab3c        267        full_svg
# 18      8c32b0cc5f5d6cc5237154f5aefdad3a        268        full_svg
# 19      e9e06f483926aa9173f47efdff47bdfd        269        full_svg
# 21      ddeb75ae62bcf0b9d4020fed43425249        271        full_svg
# 22  33712ead-2ffa-41ac-8b3c-450418e64526        272        full_svg
# 23      f589c2b36017997b6cf8fec88a1b0210        273        full_svg
# 24      c321f45ec36cd318121742cf86b4bbe3        274        full_svg
# 26      c8ecb42b67d98b80728ae0800580c7f5        276        full_svg
# 27      6eca3b2c4fa89b8a75aae63e1e99d965        277        full_svg
# 30      14e2bada9947c9771638f4c8de86a362        280        full_svg
# 31      2e7630a66e4c461b4ba8832fb2c9eb05        281        full_svg
# 32      037dde66e5c63733fa3d155d56e83a2e        282        full_svg
# 33      ebdf859d921b2cfdcb73d16f47016fcb        283        full_svg
# 38      3c45ef17a1f899dcd6bc21f857abedb6        288        full_svg
#
#                                            gate_error
# 0   Failed after 1 attempts. attempt 1: unclosed t...
# 3   Failed after 1 attempts. attempt 1: unclosed t...
# 7   Failed after 1 attempts. attempt 1: unclosed t...
# 13  Failed after 1 attempts. attempt 1: unclosed t...
# 14  Failed after 1 attempts. attempt 1: unclosed t...
# 16  Failed after 1 attempts. attempt 1: unclosed t...
# 17  Failed after 1 attempts. attempt 1: unclosed t...
# 18  Failed after 1 attempts. attempt 1: unclosed t...
# 19  Failed after 1 attempts. attempt 1: unclosed t...
# 21  Failed after 1 attempts. attempt 1: unclosed t...
# 22  Failed after 1 attempts. attempt 1: unclosed t...
# 23  Failed after 1 attempts. attempt 1: unclosed t...
# 24  Failed after 1 attempts. attempt 1: unclosed t...
# 26  Failed after 1 attempts. attempt 1: unclosed t...
# 27  Failed after 1 attempts. attempt 1: unclosed t...
# 30  Failed after 1 attempts. attempt 1: unclosed t...
# 31  Failed after 1 attempts. attempt 1: unclosed t...
# 32  Failed after 1 attempts. attempt 1: unclosed t...
# 33  Failed after 1 attempts. attempt 1: unclosed t...
# 38  Failed after 1 attempts. attempt 1: unclosed t...
