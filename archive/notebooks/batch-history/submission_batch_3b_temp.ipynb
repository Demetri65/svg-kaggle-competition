# %% [markdown]
# # Temporary Split Batch 3B
#
# This temporary notebook handles the final smaller portion of batch 3 and writes only its split-specific partial outputs until all three coordinated splits are ready.

# %% [markdown]
# ## Drive And Repo Setup
#
# Mount Drive, clone the repo into the runtime, and copy the required CSV inputs into the checkout.
#
# - Reads: Google Drive, GitHub repo, runtime filesystem
# - Writes: `/content/svg-kaggle-comptetition`, Drive output root
# - Rerun-safe: Yes. It reclones the repo and recopies the inputs cleanly.

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path

from google.colab import drive

drive.mount("/content/drive")

GIT_REPO_URL = "https://github.com/Demetri65/svg-kaggle-competition-.git"
CHECKOUT_PATH = Path("/content/svg-kaggle-comptetition")
DRIVE_ROOT = Path("/content/drive/MyDrive")
OUTPUT_ROOT = DRIVE_ROOT / "svg-kaggle-comptetition" / "submission_outputs"

if CHECKOUT_PATH.exists():
    shutil.rmtree(CHECKOUT_PATH)
subprocess.check_call(["git", "clone", GIT_REPO_URL, str(CHECKOUT_PATH)])

for required_name in ["test.csv", "train.csv", "sample_submission.csv"]:
    destination = CHECKOUT_PATH / required_name
    if destination.exists():
        continue

    preferred_sources = [
        DRIVE_ROOT / "svg-kaggle-comptetition" / required_name,
        DRIVE_ROOT / "Colab Notebooks" / "svg-kaggle-comptetition" / required_name,
    ]
    copied = False
    for candidate in preferred_sources:
        if candidate.exists():
            shutil.copy2(candidate, destination)
            copied = True
            break
    if not copied:
        for candidate in DRIVE_ROOT.rglob(required_name):
            if candidate.is_file():
                shutil.copy2(candidate, destination)
                copied = True
                break
    if not copied:
        raise FileNotFoundError(
            f"Could not find {required_name} in Google Drive. Copy it into {CHECKOUT_PATH} manually and rerun this cell."
        )

os.environ["SVG_KAGGLE_REPO_ROOT"] = str(CHECKOUT_PATH)
sys.path.insert(0, str(CHECKOUT_PATH))
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

print(f"Repo checkout: {CHECKOUT_PATH}")
print(f"Drive output root: {OUTPUT_ROOT}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Repo checkout: /content/svg-kaggle-comptetition
# Drive output root: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs

# %% [markdown]
# ## Package Check
#
# Install any missing runtime packages required by the shared helper module and this notebook.
#
# - Reads: Current Python environment
# - Writes: Installed runtime packages
# - Rerun-safe: Yes. It only installs missing packages.

# %%
import importlib.util
import subprocess
import sys

REQUIRED_PACKAGES = {
    "pandas": "pandas",
    "numpy": "numpy",
    "torch": "torch",
    "transformers": "transformers",
    "peft": "peft",
    "accelerate": "accelerate",
    "cairosvg": "cairosvg",
    "skimage": "scikit-image",
    "PIL": "pillow",
}

missing_packages = [
    package_name
    for module_name, package_name in REQUIRED_PACKAGES.items()
    if importlib.util.find_spec(module_name) is None
]

if missing_packages:
    subprocess.check_call([sys.executable, "-m", "pip", "install", *missing_packages])
    print(f"Installed missing packages: {missing_packages}")
else:
    print("All required packages are already installed.")
# Out:
# All required packages are already installed.

# %% [markdown]
# ## Load Helpers, Recommendation, And Split Slice
#
# Import the shared helper module, load the analysis recommendation, prepare the coordinated split-run state, and select this notebook's exact row slice.
#
# - Reads: Repo checkout, helper module, analysis recommendation, competition CSV files
# - Writes: Split-run marker and cleared batch 3 artifacts only on first run of this split label
# - Rerun-safe: Yes. It reuses the existing split-run marker for the same run label.

# %%
import os
from pathlib import Path

import pandas as pd
from IPython.display import display

import submission_pipeline as pipeline

pipeline.set_global_seed(1337)
PATHS = pipeline.resolve_pipeline_paths(Path(os.environ["SVG_KAGGLE_REPO_ROOT"]), OUTPUT_ROOT)
CONFIG = pipeline.GenerationConfig(verbose_progress=True)
TEST_DF, SAMPLE_SUBMISSION_DF, TRAIN_DF = pipeline.load_competition_frames(PATHS)

print(f"Repo root: {PATHS.repo_root}")
print(f"Output root: {PATHS.output_root}")

BATCH_ID = 3
PART_NAME = "batch_3b"
ROW_START = 700
ROW_END = 750
EXPECTED_PARTS = ('batch_3_main', 'batch_3a', 'batch_3b')
CHECKPOINT_EVERY = 10
SPLIT_RUN_LABEL = "split_batch_3_temp_20260325_v2"

ANALYSIS_RECOMMENDATION = pipeline.load_analysis_recommendation(PATHS)
GENERATION_MODE = ANALYSIS_RECOMMENDATION.get("recommended_generation_mode", "body_only")
BATCH_DIR = pipeline.batch_output_dir(PATHS, BATCH_ID)
PARTIAL_DIR = pipeline.partial_batch_output_dir(PATHS, BATCH_ID)
SLICE_DF = pipeline.select_row_slice(TEST_DF, ROW_START, ROW_END)
INIT_STATUS = pipeline.prepare_split_batch_outputs(
    BATCH_DIR,
    EXPECTED_PARTS,
    run_label=SPLIT_RUN_LABEL,
)

print(f"Recommended generation mode: {GENERATION_MODE}")
print(f"Split run label: {SPLIT_RUN_LABEL}")
print(f"Slice rows: {ROW_START}:{ROW_END} ({len(SLICE_DF)} rows)")
if INIT_STATUS["did_reset"]:
    print("Initialized split batch 3 outputs and cleared stale batch_3 artifacts.")
else:
    print("Using existing split batch 3 partial state for this run label.")
display(SLICE_DF[["id", "prompt", "row_index"]].head())
# Out:
# Repo root: /content/svg-kaggle-comptetition
# Output root: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs
# Recommended generation mode: full_svg
# Split run label: split_batch_3_temp_20260325_v2
# Slice rows: 700:750 (50 rows)
# Using existing split batch 3 partial state for this run label.
#                                      id  \
# 0      aa9f193d583a18aab0b2792f8a98f1fe
# 1      323e864133b581e07a8c628d290bd4e7
# 2      b21a4952f41284c5698fc67c88e64868
# 3      64c0fdcd4bf1913d365cacdad36c2fe1
# 4  a062b36a-c983-41ea-9902-76638bc8be53
#
#                                               prompt  row_index
# 0            A simple line drawing of a cloud shape.        700
# 1  The image shows a blue icon consisting of thre...        701
# 2  The image features a single black spiral symbo...        702
# 3  A minimalist design featuring two overlapping ...        703
# 4     An illustration of a lemon outlined in yellow.        704

# %% [markdown]
# ## Resume From Partial Output
#
# Load this notebook's saved partial results, skip rows that already completed in this split, and show the remaining work.
#
# - Reads: `batch_3/partials/*_results.csv`
# - Writes: Nothing
# - Rerun-safe: Yes. It is how this notebook resumes after interruption.

# %%
PARTIAL_FRAMES, _ = pipeline.load_partial_batch_outputs(BATCH_DIR, [PART_NAME])
PARTIAL_RESULTS_DF = PARTIAL_FRAMES.get(
    PART_NAME,
    pipeline.normalize_results_df(pd.DataFrame(columns=pipeline.RESULT_COLUMNS)),
)
COMPLETED_IDS = set(PARTIAL_RESULTS_DF["id"].tolist())
PENDING_DF = SLICE_DF[~SLICE_DF["id"].isin(COMPLETED_IDS)].copy().reset_index(drop=True)

print(f"Existing completed rows for {PART_NAME}: {len(PARTIAL_RESULTS_DF)}")
print(f"Pending rows for {PART_NAME}: {len(PENDING_DF)}")
if not PENDING_DF.empty:
    display(PENDING_DF[["id", "row_index"]].head(10))
# Out:
# Existing completed rows for batch_3b: 0
# Pending rows for batch_3b: 50
#                                      id  row_index
# 0      aa9f193d583a18aab0b2792f8a98f1fe        700
# 1      323e864133b581e07a8c628d290bd4e7        701
# 2      b21a4952f41284c5698fc67c88e64868        702
# 3      64c0fdcd4bf1913d365cacdad36c2fe1        703
# 4  a062b36a-c983-41ea-9902-76638bc8be53        704
# 5      156591ee09bef9ff296a7fa6fa8354bb        705
# 6      ed06fe4128c3e2b58109abdb2ba0d381        706
# 7      ce3b6c429f39d502344ac6f7735f723e        707
# 8  36489f49-310a-4c51-9f7d-0eab2ac0b3fe        708
# 9      949609e244d614218b23f50c5509c614        709

# %% [markdown]
# ## Load Model
#
# Load the base model plus the LoRA adapter into the current Colab GPU runtime for first-pass generation.
#
# - Reads: Base model on Hugging Face, LoRA adapter from repo
# - Writes: In-memory model state only
# - Rerun-safe: No. It is safe to rerun, but it reloads the model and costs time.

# %%
RUNTIME = pipeline.load_lora_runtime(PATHS.adapter_dir)
print(f"Loaded runtime on: {RUNTIME.runtime_device}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# Loaded runtime on: cuda

# %% [markdown]
# ## Deterministic First Pass With Partial Checkpoints
#
# Run one deterministic generation attempt per pending row in this split and checkpoint the split-specific partial CSVs every 10 rows.
#
# - Reads: Selected split rows, model runtime, existing partial outputs
# - Writes: `batch_3/partials/*` files for this split only
# - Rerun-safe: Yes. It resumes from this split's saved partial results.

# %%
records = PARTIAL_RESULTS_DF.to_dict(orient="records")
total_pending = len(PENDING_DF)

if total_pending == 0:
    print(f"{PART_NAME} is already complete. Rewriting the current partial artifacts for consistency.")
else:
    for local_index, row in enumerate(PENDING_DF.to_dict(orient="records"), start=1):
        row_id = row["id"]
        prompt = row["prompt"]
        row_index = int(row["row_index"])
        started_at = pipeline.time.perf_counter()
        try:
            prepared = pipeline.infer_svg_candidate(
                prompt,
                RUNTIME,
                generation_mode=GENERATION_MODE,
                config=CONFIG,
                allow_sampled_repair=False,
                progress_label=f"{PART_NAME} {local_index}/{total_pending}",
                row_id=row_id,
            )
            runtime_seconds = pipeline.time.perf_counter() - started_at
            record = pipeline.build_success_record(
                row_id,
                prompt,
                prepared,
                batch_id=str(BATCH_ID),
                row_index=row_index,
                generation_mode=GENERATION_MODE,
                first_pass_success=True,
                runtime_seconds=runtime_seconds,
            )
        except pipeline.RowInferenceError as exc:
            runtime_seconds = pipeline.time.perf_counter() - started_at
            record = pipeline.build_failed_record(
                row_id,
                prompt,
                exc,
                batch_id=str(BATCH_ID),
                row_index=row_index,
                generation_mode=GENERATION_MODE,
                first_pass_success=False,
                runtime_seconds=runtime_seconds,
            )
        records.append(record)
        if local_index % CHECKPOINT_EVERY == 0 or local_index == total_pending:
            PARTIAL_RESULTS_DF = pipeline.normalize_results_df(pd.DataFrame(records))
            PARTIAL_RESULTS_DF = PARTIAL_RESULTS_DF.sort_values("row_index").drop_duplicates(subset=["id"], keep="last")
            pipeline.save_partial_batch_outputs(PARTIAL_RESULTS_DF, BATCH_DIR, PART_NAME)
            print(
                f"Checkpointed {PART_NAME}: {len(PARTIAL_RESULTS_DF)}/{len(SLICE_DF)} rows saved to {PARTIAL_DIR}"
            )
        pipeline.release_runtime_memory()

PARTIAL_RESULTS_DF = pipeline.normalize_results_df(pd.DataFrame(records))
PARTIAL_RESULTS_DF = PARTIAL_RESULTS_DF.sort_values("row_index").drop_duplicates(subset=["id"], keep="last")
pipeline.save_partial_batch_outputs(PARTIAL_RESULTS_DF, BATCH_DIR, PART_NAME)
print(f"Wrote partial batch artifacts to: {PARTIAL_DIR}")
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [batch_3b 1/50] row aa9f193d583a18aab0b2792f8a98f1fe: attempt 1/1 (deterministic)
# [batch_3b 1/50] row aa9f193d583a18aab0b2792f8a98f1fe: success on attempt 1/1
# [batch_3b 2/50] row 323e864133b581e07a8c628d290bd4e7: attempt 1/1 (deterministic)
# [batch_3b 2/50] row 323e864133b581e07a8c628d290bd4e7: success on attempt 1/1
# [batch_3b 3/50] row b21a4952f41284c5698fc67c88e64868: attempt 1/1 (deterministic)
# [batch_3b 3/50] row b21a4952f41284c5698fc67c88e64868: success on attempt 1/1
# [batch_3b 4/50] row 64c0fdcd4bf1913d365cacdad36c2fe1: attempt 1/1 (deterministic)
# [batch_3b 4/50] row 64c0fdcd4bf1913d365cacdad36c2fe1: success on attempt 1/1
# [batch_3b 5/50] row a062b36a-c983-41ea-9902-76638bc8be53: attempt 1/1 (deterministic)
# [batch_3b 5/50] row a062b36a-c983-41ea-9902-76638bc8be53: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_3b 6/50] row 156591ee09bef9ff296a7fa6fa8354bb: attempt 1/1 (deterministic)
# [batch_3b 6/50] row 156591ee09bef9ff296a7fa6fa8354bb: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3b 7/50] row ed06fe4128c3e2b58109abdb2ba0d381: attempt 1/1 (deterministic)
# [batch_3b 7/50] row ed06fe4128c3e2b58109abdb2ba0d381: attempt 1/1 failed: unclosed token: line 7, column 0
# [batch_3b 8/50] row ce3b6c429f39d502344ac6f7735f723e: attempt 1/1 (deterministic)
# [batch_3b 8/50] row ce3b6c429f39d502344ac6f7735f723e: attempt 1/1 failed: unclosed token: line 17, column 4
# [batch_3b 9/50] row 36489f49-310a-4c51-9f7d-0eab2ac0b3fe: attempt 1/1 (deterministic)
# [batch_3b 9/50] row 36489f49-310a-4c51-9f7d-0eab2ac0b3fe: success on attempt 1/1
# [batch_3b 10/50] row 949609e244d614218b23f50c5509c614: attempt 1/1 (deterministic)
# [batch_3b 10/50] row 949609e244d614218b23f50c5509c614: attempt 1/1 failed: unclosed token: line 13, column 2
# Checkpointed batch_3b: 10/50 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3b 11/50] row 85332760f9d829ead4a9d30ffc913d6a: attempt 1/1 (deterministic)
# [batch_3b 11/50] row 85332760f9d829ead4a9d30ffc913d6a: success on attempt 1/1
# [batch_3b 12/50] row dd968c952a9ed6b1e3af66e050aca87a: attempt 1/1 (deterministic)
# [batch_3b 12/50] row dd968c952a9ed6b1e3af66e050aca87a: attempt 1/1 failed: unclosed token: line 14, column 0
# [batch_3b 13/50] row e58231d097154095199ff717ddde87be: attempt 1/1 (deterministic)
# [batch_3b 13/50] row e58231d097154095199ff717ddde87be: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3b 14/50] row 8e5161fdce365e61dd324aa6f48d1de5: attempt 1/1 (deterministic)
# [batch_3b 14/50] row 8e5161fdce365e61dd324aa6f48d1de5: success on attempt 1/1
# [batch_3b 15/50] row ffdc11c523d214880eb61c0857311836: attempt 1/1 (deterministic)
# [batch_3b 15/50] row ffdc11c523d214880eb61c0857311836: attempt 1/1 failed: unclosed token: line 4, column 0
# [batch_3b 16/50] row aa1d1c5dd44400b0e1ad5a37e2a3b90c: attempt 1/1 (deterministic)
# [batch_3b 16/50] row aa1d1c5dd44400b0e1ad5a37e2a3b90c: attempt 1/1 failed: unclosed token: line 24, column 0
# [batch_3b 17/50] row c99a30ba9fd7fe64b935520102f66626: attempt 1/1 (deterministic)
# [batch_3b 17/50] row c99a30ba9fd7fe64b935520102f66626: attempt 1/1 failed: unclosed token: line 14, column 4
# [batch_3b 18/50] row 9171df5f-f639-4e1d-8617-9aad32be2aa5: attempt 1/1 (deterministic)
# [batch_3b 18/50] row 9171df5f-f639-4e1d-8617-9aad32be2aa5: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3b 19/50] row a130002a99cc3648a24d412c456afdca: attempt 1/1 (deterministic)
# [batch_3b 19/50] row a130002a99cc3648a24d412c456afdca: attempt 1/1 failed: unclosed token: line 4, column 0
# [batch_3b 20/50] row 62ca2f05e5976f9b8ebcd1f20bb36ee9: attempt 1/1 (deterministic)
# [batch_3b 20/50] row 62ca2f05e5976f9b8ebcd1f20bb36ee9: attempt 1/1 failed: unclosed token: line 8, column 0
# Checkpointed batch_3b: 20/50 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3b 21/50] row c200cf487f7ddd974f2127c14a34e1b9: attempt 1/1 (deterministic)
# [batch_3b 21/50] row c200cf487f7ddd974f2127c14a34e1b9: success on attempt 1/1
# [batch_3b 22/50] row 2b0cbea4570e361ff815e3f0fac0eabf: attempt 1/1 (deterministic)
# [batch_3b 22/50] row 2b0cbea4570e361ff815e3f0fac0eabf: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3b 23/50] row afe1611033a8ca58d13f71d60ea94f51: attempt 1/1 (deterministic)
# [batch_3b 23/50] row afe1611033a8ca58d13f71d60ea94f51: success on attempt 1/1
# [batch_3b 24/50] row cc76666c917bf608001d455150620f4d: attempt 1/1 (deterministic)
# [batch_3b 24/50] row cc76666c917bf608001d455150620f4d: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3b 25/50] row c40d10c549c1c80692ed3629d2cb9a27: attempt 1/1 (deterministic)
# [batch_3b 25/50] row c40d10c549c1c80692ed3629d2cb9a27: attempt 1/1 failed: unclosed token: line 22, column 2
# [batch_3b 26/50] row 28ef351b939259e4a6be864f5ca72123: attempt 1/1 (deterministic)
# [batch_3b 26/50] row 28ef351b939259e4a6be864f5ca72123: success on attempt 1/1
# [batch_3b 27/50] row dff7ef4393f1895cbb07b7d19d29ad23: attempt 1/1 (deterministic)
# [batch_3b 27/50] row dff7ef4393f1895cbb07b7d19d29ad23: success on attempt 1/1
# [batch_3b 28/50] row ebcc1d50efe24a33abcd202b06d14e8a: attempt 1/1 (deterministic)
# [batch_3b 28/50] row ebcc1d50efe24a33abcd202b06d14e8a: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3b 29/50] row 8feeaa885467f110de10a96773217f01: attempt 1/1 (deterministic)
# [batch_3b 29/50] row 8feeaa885467f110de10a96773217f01: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_3b 30/50] row f750e4869f90de864f0e6d29eae3b512: attempt 1/1 (deterministic)
# [batch_3b 30/50] row f750e4869f90de864f0e6d29eae3b512: success on attempt 1/1
# Checkpointed batch_3b: 30/50 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3b 31/50] row 6080026eb9cb1f3a9b1aadc079cf11c2: attempt 1/1 (deterministic)
# [batch_3b 31/50] row 6080026eb9cb1f3a9b1aadc079cf11c2: success on attempt 1/1
# [batch_3b 32/50] row d4d9c2dc33c69955435c18bcd8714270: attempt 1/1 (deterministic)
# [batch_3b 32/50] row d4d9c2dc33c69955435c18bcd8714270: success on attempt 1/1
# [batch_3b 33/50] row ee8222e02bb32ce069918af785689b44: attempt 1/1 (deterministic)
# [batch_3b 33/50] row ee8222e02bb32ce069918af785689b44: success on attempt 1/1
# [batch_3b 34/50] row ea4ce6666c1d1e7fb21039f2e08dc3d9: attempt 1/1 (deterministic)
# [batch_3b 34/50] row ea4ce6666c1d1e7fb21039f2e08dc3d9: success on attempt 1/1
# [batch_3b 35/50] row 4ab37b21a628826e513eba1b782f84ea: attempt 1/1 (deterministic)
# [batch_3b 35/50] row 4ab37b21a628826e513eba1b782f84ea: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3b 36/50] row 46535b644ad9b85b413dad8b13ae1edd: attempt 1/1 (deterministic)
# [batch_3b 36/50] row 46535b644ad9b85b413dad8b13ae1edd: success on attempt 1/1
# [batch_3b 37/50] row fde503da257b1af7293476a5590212d9: attempt 1/1 (deterministic)
# [batch_3b 37/50] row fde503da257b1af7293476a5590212d9: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3b 38/50] row 2ba4c37562d2e2bffb8a0e02a2efac75: attempt 1/1 (deterministic)
# [batch_3b 38/50] row 2ba4c37562d2e2bffb8a0e02a2efac75: success on attempt 1/1
# [batch_3b 39/50] row e32f4ccd3fdc9b9fed8eeb427b68306a: attempt 1/1 (deterministic)
# [batch_3b 39/50] row e32f4ccd3fdc9b9fed8eeb427b68306a: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_3b 40/50] row 41b38cf515cab74b8ccd839f826c2fa6: attempt 1/1 (deterministic)
# [batch_3b 40/50] row 41b38cf515cab74b8ccd839f826c2fa6: attempt 1/1 failed: unclosed token: line 7, column 0
# Checkpointed batch_3b: 40/50 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3b 41/50] row 0db43ecb-1c8f-4efb-bb0e-097d5e9d0d4d: attempt 1/1 (deterministic)
# [batch_3b 41/50] row 0db43ecb-1c8f-4efb-bb0e-097d5e9d0d4d: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_3b 42/50] row 2d829d14f389f6ac8a11d4a4542f3739: attempt 1/1 (deterministic)
# [batch_3b 42/50] row 2d829d14f389f6ac8a11d4a4542f3739: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_3b 43/50] row 386b7d92-a6fa-4005-abfc-50d67387cc7f: attempt 1/1 (deterministic)
# [batch_3b 43/50] row 386b7d92-a6fa-4005-abfc-50d67387cc7f: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3b 44/50] row 1370d580a7e7a91afcbbfed1cc0f800a: attempt 1/1 (deterministic)
# [batch_3b 44/50] row 1370d580a7e7a91afcbbfed1cc0f800a: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_3b 45/50] row 96f5b41df88bd3c1a0f1348567f3b6cb: attempt 1/1 (deterministic)
# [batch_3b 45/50] row 96f5b41df88bd3c1a0f1348567f3b6cb: attempt 1/1 failed: unclosed token: line 13, column 4
# [batch_3b 46/50] row 244cd227d650008ad779e4449c685ac3: attempt 1/1 (deterministic)
# [batch_3b 46/50] row 244cd227d650008ad779e4449c685ac3: attempt 1/1 failed: unclosed token: line 15, column 4
# [batch_3b 47/50] row 426aa538ac3f297b151503a0eae1889f: attempt 1/1 (deterministic)
# [batch_3b 47/50] row 426aa538ac3f297b151503a0eae1889f: success on attempt 1/1
# [batch_3b 48/50] row 9d3d65b9cef63049b3da71481aa360c3: attempt 1/1 (deterministic)
# [batch_3b 48/50] row 9d3d65b9cef63049b3da71481aa360c3: success on attempt 1/1
# [batch_3b 49/50] row 8be2785241ad8588627189631f7b45b2: attempt 1/1 (deterministic)
# [batch_3b 49/50] row 8be2785241ad8588627189631f7b45b2: attempt 1/1 failed: unclosed token: line 10, column 0
# [batch_3b 50/50] row 92edbc425cf8eb1429203b38912144e1: attempt 1/1 (deterministic)
# [batch_3b 50/50] row 92edbc425cf8eb1429203b38912144e1: attempt 1/1 failed: unclosed token: line 2, column 0
# Checkpointed batch_3b: 50/50 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# Wrote partial batch artifacts to: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials

# %% [markdown]
# ## Split Summary
#
# Show the current success and failure totals for this split of batch 3.
#
# - Reads: In-memory partial results
# - Writes: Nothing
# - Rerun-safe: Yes. Read-only display cell.

# %%
display(pipeline.summarize_batch_results(PARTIAL_RESULTS_DF))
FAILED_DF = PARTIAL_RESULTS_DF[~PARTIAL_RESULTS_DF["first_pass_success"]].copy()
if FAILED_DF.empty:
    print("No failed rows in this split.")
else:
    display(FAILED_DF[["id", "row_index", "generation_mode", "gate_error"]].head(20))

# %% [markdown]
# ## Finalize Canonical Batch 3 Outputs
#
# If all three split notebooks have finished, combine the partial outputs into the normal `batch_3/*.csv` files expected by the merge notebook. Otherwise print which split is still missing.
#
# - Reads: `batch_3/partials/*`
# - Writes: Canonical `batch_3/*.csv` only when all three splits are present
# - Rerun-safe: Yes. It rewrites the canonical batch 3 files if all splits are ready.

# %%
FINALIZE_STATUS = pipeline.finalize_split_batch_outputs(BATCH_DIR, expected_row_count=250)
if FINALIZE_STATUS["ready"]:
    print("Canonical batch_3 files are now finalized.")
    print(
        f"Rows: {FINALIZE_STATUS['rows']} | row range: {FINALIZE_STATUS['first_row_index']}:{FINALIZE_STATUS['last_row_index']}"
    )
else:
    print("Waiting for the other split notebooks before writing canonical batch_3 files.")
    print(f"Missing partials: {FINALIZE_STATUS['missing_parts']}")
    print(f"Currently saved rows across available partials: {FINALIZE_STATUS['rows']}")
display(pipeline.artifact_status_table(PATHS, batch_count=4))
