# %% [markdown]
# # Primary Split Batch 3
#
# This notebook handles the larger H100-backed portion of batch 3 and writes only its split-specific partial outputs until all three coordinated splits are ready.

# %% [markdown]
# ## Drive And Repo Setup
#
# Mount Drive, clone the repo into the runtime, and copy the required CSV inputs into the checkout.
#
# - Reads: Google Drive, GitHub repo, runtime filesystem
# - Writes: `/content/svg-kaggle-comptetition`, Drive output root
# - Rerun-safe: Yes. It reclones the repo and recopies the inputs cleanly.

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path

from google.colab import drive

drive.mount("/content/drive")

GIT_REPO_URL = "https://github.com/Demetri65/svg-kaggle-competition-.git"
CHECKOUT_PATH = Path("/content/svg-kaggle-comptetition")
DRIVE_ROOT = Path("/content/drive/MyDrive")
OUTPUT_ROOT = DRIVE_ROOT / "svg-kaggle-comptetition" / "submission_outputs"

if CHECKOUT_PATH.exists():
    shutil.rmtree(CHECKOUT_PATH)
subprocess.check_call(["git", "clone", GIT_REPO_URL, str(CHECKOUT_PATH)])

for required_name in ["test.csv", "train.csv", "sample_submission.csv"]:
    destination = CHECKOUT_PATH / required_name
    if destination.exists():
        continue

    preferred_sources = [
        DRIVE_ROOT / "svg-kaggle-comptetition" / required_name,
        DRIVE_ROOT / "Colab Notebooks" / "svg-kaggle-comptetition" / required_name,
    ]
    copied = False
    for candidate in preferred_sources:
        if candidate.exists():
            shutil.copy2(candidate, destination)
            copied = True
            break
    if not copied:
        for candidate in DRIVE_ROOT.rglob(required_name):
            if candidate.is_file():
                shutil.copy2(candidate, destination)
                copied = True
                break
    if not copied:
        raise FileNotFoundError(
            f"Could not find {required_name} in Google Drive. Copy it into {CHECKOUT_PATH} manually and rerun this cell."
        )

os.environ["SVG_KAGGLE_REPO_ROOT"] = str(CHECKOUT_PATH)
sys.path.insert(0, str(CHECKOUT_PATH))
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

print(f"Repo checkout: {CHECKOUT_PATH}")
print(f"Drive output root: {OUTPUT_ROOT}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Repo checkout: /content/svg-kaggle-comptetition
# Drive output root: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs

# %% [markdown]
# ## Package Check
#
# Install any missing runtime packages required by the shared helper module and this notebook.
#
# - Reads: Current Python environment
# - Writes: Installed runtime packages
# - Rerun-safe: Yes. It only installs missing packages.

# %%
import importlib.util
import subprocess
import sys

REQUIRED_PACKAGES = {
    "pandas": "pandas",
    "numpy": "numpy",
    "torch": "torch",
    "transformers": "transformers",
    "peft": "peft",
    "accelerate": "accelerate",
    "cairosvg": "cairosvg",
    "skimage": "scikit-image",
    "PIL": "pillow",
}

missing_packages = [
    package_name
    for module_name, package_name in REQUIRED_PACKAGES.items()
    if importlib.util.find_spec(module_name) is None
]

if missing_packages:
    subprocess.check_call([sys.executable, "-m", "pip", "install", *missing_packages])
    print(f"Installed missing packages: {missing_packages}")
else:
    print("All required packages are already installed.")
# Out:
# All required packages are already installed.

# %% [markdown]
# ## Load Helpers, Recommendation, And Split Slice
#
# Import the shared helper module, load the analysis recommendation, prepare the coordinated split-run state, and select this notebook's exact row slice.
#
# - Reads: Repo checkout, helper module, analysis recommendation, competition CSV files
# - Writes: Split-run marker and cleared batch 3 artifacts only on first run of this split label
# - Rerun-safe: Yes. It reuses the existing split-run marker for the same run label.

# %%
import os
from pathlib import Path

import pandas as pd
from IPython.display import display

import submission_pipeline as pipeline

pipeline.set_global_seed(1337)
PATHS = pipeline.resolve_pipeline_paths(Path(os.environ["SVG_KAGGLE_REPO_ROOT"]), OUTPUT_ROOT)
CONFIG = pipeline.GenerationConfig(verbose_progress=True)
TEST_DF, SAMPLE_SUBMISSION_DF, TRAIN_DF = pipeline.load_competition_frames(PATHS)

print(f"Repo root: {PATHS.repo_root}")
print(f"Output root: {PATHS.output_root}")

BATCH_ID = 3
PART_NAME = "batch_3_main"
ROW_START = 500
ROW_END = 650
EXPECTED_PARTS = ('batch_3_main', 'batch_3a', 'batch_3b')
CHECKPOINT_EVERY = 10
SPLIT_RUN_LABEL = "split_batch_3_temp_20260325_v2"

ANALYSIS_RECOMMENDATION = pipeline.load_analysis_recommendation(PATHS)
GENERATION_MODE = ANALYSIS_RECOMMENDATION.get("recommended_generation_mode", "body_only")
BATCH_DIR = pipeline.batch_output_dir(PATHS, BATCH_ID)
PARTIAL_DIR = pipeline.partial_batch_output_dir(PATHS, BATCH_ID)
SLICE_DF = pipeline.select_row_slice(TEST_DF, ROW_START, ROW_END)
INIT_STATUS = pipeline.prepare_split_batch_outputs(
    BATCH_DIR,
    EXPECTED_PARTS,
    run_label=SPLIT_RUN_LABEL,
)

print(f"Recommended generation mode: {GENERATION_MODE}")
print(f"Split run label: {SPLIT_RUN_LABEL}")
print(f"Slice rows: {ROW_START}:{ROW_END} ({len(SLICE_DF)} rows)")
if INIT_STATUS["did_reset"]:
    print("Initialized split batch 3 outputs and cleared stale batch_3 artifacts.")
else:
    print("Using existing split batch 3 partial state for this run label.")
display(SLICE_DF[["id", "prompt", "row_index"]].head())
# Out:
# Repo root: /content/svg-kaggle-comptetition
# Output root: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs
# Recommended generation mode: full_svg
# Split run label: split_batch_3_temp_20260325_v2
# Slice rows: 500:650 (150 rows)
# Using existing split batch 3 partial state for this run label.
#                                  id  \
# 0  f11f5c89bd20cd96350feee81112a947
# 1  28ebcd68a26c4a5c3627e0b387634a06
# 2  92bc76fd445cfb23162ecfb03f75c2a5
# 3  b8039c02aeb5b7800f5ab6147c25d8da
# 4  9c3614fc9c9de9db37b36b286e46921e
#
#                                               prompt  row_index
# 0  The image shows a dark gray numeral '7' center...        500
# 1  A black circular button with a white power sym...        501
# 2  A stylized icon featuring a curved line on a g...        502
# 3  The image features a single black shape with a...        503
# 4  The image contains a black arrow pointing down...        504

# %% [markdown]
# ## Resume From Partial Output
#
# Load this notebook's saved partial results, skip rows that already completed in this split, and show the remaining work.
#
# - Reads: `batch_3/partials/*_results.csv`
# - Writes: Nothing
# - Rerun-safe: Yes. It is how this notebook resumes after interruption.

# %%
PARTIAL_FRAMES, _ = pipeline.load_partial_batch_outputs(BATCH_DIR, [PART_NAME])
PARTIAL_RESULTS_DF = PARTIAL_FRAMES.get(
    PART_NAME,
    pipeline.normalize_results_df(pd.DataFrame(columns=pipeline.RESULT_COLUMNS)),
)
COMPLETED_IDS = set(PARTIAL_RESULTS_DF["id"].tolist())
PENDING_DF = SLICE_DF[~SLICE_DF["id"].isin(COMPLETED_IDS)].copy().reset_index(drop=True)

print(f"Existing completed rows for {PART_NAME}: {len(PARTIAL_RESULTS_DF)}")
print(f"Pending rows for {PART_NAME}: {len(PENDING_DF)}")
if not PENDING_DF.empty:
    display(PENDING_DF[["id", "row_index"]].head(10))
# Out:
# Existing completed rows for batch_3_main: 0
# Pending rows for batch_3_main: 150
#                                      id  row_index
# 0      f11f5c89bd20cd96350feee81112a947        500
# 1      28ebcd68a26c4a5c3627e0b387634a06        501
# 2      92bc76fd445cfb23162ecfb03f75c2a5        502
# 3      b8039c02aeb5b7800f5ab6147c25d8da        503
# 4      9c3614fc9c9de9db37b36b286e46921e        504
# 5      f3474be9579d8beda72d1541de40a444        505
# 6      a5d6d0951bccfe94265019f1b8c5ef39        506
# 7  9f0782e6-9bf0-4211-9aad-0c6cd8714ac5        507
# 8      14187d6297456d67ab32a78e4c8fcdf8        508
# 9      819ecc751368a711d824b10b1b727ea2        509

# %% [markdown]
# ## Load Model
#
# Load the base model plus the LoRA adapter into the current Colab GPU runtime for first-pass generation.
#
# - Reads: Base model on Hugging Face, LoRA adapter from repo
# - Writes: In-memory model state only
# - Rerun-safe: No. It is safe to rerun, but it reloads the model and costs time.

# %%
RUNTIME = pipeline.load_lora_runtime(PATHS.adapter_dir)
print(f"Loaded runtime on: {RUNTIME.runtime_device}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# Loaded runtime on: cuda

# %% [markdown]
# ## Deterministic First Pass With Partial Checkpoints
#
# Run one deterministic generation attempt per pending row in this split and checkpoint the split-specific partial CSVs every 10 rows.
#
# - Reads: Selected split rows, model runtime, existing partial outputs
# - Writes: `batch_3/partials/*` files for this split only
# - Rerun-safe: Yes. It resumes from this split's saved partial results.

# %%
records = PARTIAL_RESULTS_DF.to_dict(orient="records")
total_pending = len(PENDING_DF)

if total_pending == 0:
    print(f"{PART_NAME} is already complete. Rewriting the current partial artifacts for consistency.")
else:
    for local_index, row in enumerate(PENDING_DF.to_dict(orient="records"), start=1):
        row_id = row["id"]
        prompt = row["prompt"]
        row_index = int(row["row_index"])
        started_at = pipeline.time.perf_counter()
        try:
            prepared = pipeline.infer_svg_candidate(
                prompt,
                RUNTIME,
                generation_mode=GENERATION_MODE,
                config=CONFIG,
                allow_sampled_repair=False,
                progress_label=f"{PART_NAME} {local_index}/{total_pending}",
                row_id=row_id,
            )
            runtime_seconds = pipeline.time.perf_counter() - started_at
            record = pipeline.build_success_record(
                row_id,
                prompt,
                prepared,
                batch_id=str(BATCH_ID),
                row_index=row_index,
                generation_mode=GENERATION_MODE,
                first_pass_success=True,
                runtime_seconds=runtime_seconds,
            )
        except pipeline.RowInferenceError as exc:
            runtime_seconds = pipeline.time.perf_counter() - started_at
            record = pipeline.build_failed_record(
                row_id,
                prompt,
                exc,
                batch_id=str(BATCH_ID),
                row_index=row_index,
                generation_mode=GENERATION_MODE,
                first_pass_success=False,
                runtime_seconds=runtime_seconds,
            )
        records.append(record)
        if local_index % CHECKPOINT_EVERY == 0 or local_index == total_pending:
            PARTIAL_RESULTS_DF = pipeline.normalize_results_df(pd.DataFrame(records))
            PARTIAL_RESULTS_DF = PARTIAL_RESULTS_DF.sort_values("row_index").drop_duplicates(subset=["id"], keep="last")
            pipeline.save_partial_batch_outputs(PARTIAL_RESULTS_DF, BATCH_DIR, PART_NAME)
            print(
                f"Checkpointed {PART_NAME}: {len(PARTIAL_RESULTS_DF)}/{len(SLICE_DF)} rows saved to {PARTIAL_DIR}"
            )
        pipeline.release_runtime_memory()

PARTIAL_RESULTS_DF = pipeline.normalize_results_df(pd.DataFrame(records))
PARTIAL_RESULTS_DF = PARTIAL_RESULTS_DF.sort_values("row_index").drop_duplicates(subset=["id"], keep="last")
pipeline.save_partial_batch_outputs(PARTIAL_RESULTS_DF, BATCH_DIR, PART_NAME)
print(f"Wrote partial batch artifacts to: {PARTIAL_DIR}")
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [batch_3_main 1/150] row f11f5c89bd20cd96350feee81112a947: attempt 1/1 (deterministic)
# [batch_3_main 1/150] row f11f5c89bd20cd96350feee81112a947: success on attempt 1/1
# [batch_3_main 2/150] row 28ebcd68a26c4a5c3627e0b387634a06: attempt 1/1 (deterministic)
# [batch_3_main 2/150] row 28ebcd68a26c4a5c3627e0b387634a06: success on attempt 1/1
# [batch_3_main 3/150] row 92bc76fd445cfb23162ecfb03f75c2a5: attempt 1/1 (deterministic)
# [batch_3_main 3/150] row 92bc76fd445cfb23162ecfb03f75c2a5: success on attempt 1/1
# [batch_3_main 4/150] row b8039c02aeb5b7800f5ab6147c25d8da: attempt 1/1 (deterministic)
# [batch_3_main 4/150] row b8039c02aeb5b7800f5ab6147c25d8da: success on attempt 1/1
# [batch_3_main 5/150] row 9c3614fc9c9de9db37b36b286e46921e: attempt 1/1 (deterministic)
# [batch_3_main 5/150] row 9c3614fc9c9de9db37b36b286e46921e: attempt 1/1 failed: unclosed token: line 19, column 0
# [batch_3_main 6/150] row f3474be9579d8beda72d1541de40a444: attempt 1/1 (deterministic)
# [batch_3_main 6/150] row f3474be9579d8beda72d1541de40a444: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 7/150] row a5d6d0951bccfe94265019f1b8c5ef39: attempt 1/1 (deterministic)
# [batch_3_main 7/150] row a5d6d0951bccfe94265019f1b8c5ef39: attempt 1/1 failed: unclosed token: line 16, column 4
# [batch_3_main 8/150] row 9f0782e6-9bf0-4211-9aad-0c6cd8714ac5: attempt 1/1 (deterministic)
# [batch_3_main 8/150] row 9f0782e6-9bf0-4211-9aad-0c6cd8714ac5: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_3_main 9/150] row 14187d6297456d67ab32a78e4c8fcdf8: attempt 1/1 (deterministic)
# [batch_3_main 9/150] row 14187d6297456d67ab32a78e4c8fcdf8: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 10/150] row 819ecc751368a711d824b10b1b727ea2: attempt 1/1 (deterministic)
# [batch_3_main 10/150] row 819ecc751368a711d824b10b1b727ea2: attempt 1/1 failed: unclosed token: line 3, column 2
# Checkpointed batch_3_main: 10/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 11/150] row 6b6ad214135060900be917f659dccc26: attempt 1/1 (deterministic)
# [batch_3_main 11/150] row 6b6ad214135060900be917f659dccc26: attempt 1/1 failed: unclosed token: line 4, column 0
# [batch_3_main 12/150] row 4826a16f417e94a83afdbf7e22e5a0a9: attempt 1/1 (deterministic)
# [batch_3_main 12/150] row 4826a16f417e94a83afdbf7e22e5a0a9: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 13/150] row 23f7fa2f-ebc0-49d2-9aa3-fd1542efba96: attempt 1/1 (deterministic)
# [batch_3_main 13/150] row 23f7fa2f-ebc0-49d2-9aa3-fd1542efba96: success on attempt 1/1
# [batch_3_main 14/150] row 89e6603077a4021a00b49ba81da4f642: attempt 1/1 (deterministic)
# [batch_3_main 14/150] row 89e6603077a4021a00b49ba81da4f642: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 15/150] row 69be32f9806b461e9e8b0af54791b968: attempt 1/1 (deterministic)
# [batch_3_main 15/150] row 69be32f9806b461e9e8b0af54791b968: success on attempt 1/1
# [batch_3_main 16/150] row 45ec68713decbbbdc5d2da29f4a2e543: attempt 1/1 (deterministic)
# [batch_3_main 16/150] row 45ec68713decbbbdc5d2da29f4a2e543: success on attempt 1/1
# [batch_3_main 17/150] row a65ab6b493eaec46d6a2a2a68c1be344: attempt 1/1 (deterministic)
# [batch_3_main 17/150] row a65ab6b493eaec46d6a2a2a68c1be344: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_3_main 18/150] row e62aec99bb4aa8dd5bcf99ce23e8a3c7: attempt 1/1 (deterministic)
# [batch_3_main 18/150] row e62aec99bb4aa8dd5bcf99ce23e8a3c7: success on attempt 1/1
# [batch_3_main 19/150] row 8f4d1acdfe3ae945e0d8048ad87bf299: attempt 1/1 (deterministic)
# [batch_3_main 19/150] row 8f4d1acdfe3ae945e0d8048ad87bf299: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_3_main 20/150] row a4aaa1dea134b7ad933bc58f45a8abd7: attempt 1/1 (deterministic)
# [batch_3_main 20/150] row a4aaa1dea134b7ad933bc58f45a8abd7: success on attempt 1/1
# Checkpointed batch_3_main: 20/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 21/150] row 84cd7f9519a45bc7ae28c0fb77a6d54c: attempt 1/1 (deterministic)
# [batch_3_main 21/150] row 84cd7f9519a45bc7ae28c0fb77a6d54c: success on attempt 1/1
# [batch_3_main 22/150] row 5c7a342dd3688343a0e0962a2d7a74d0: attempt 1/1 (deterministic)
# [batch_3_main 22/150] row 5c7a342dd3688343a0e0962a2d7a74d0: attempt 1/1 failed: unclosed token: line 5, column 4
# [batch_3_main 23/150] row ef5081c497027006bd07735208bba911: attempt 1/1 (deterministic)
# [batch_3_main 23/150] row ef5081c497027006bd07735208bba911: success on attempt 1/1
# [batch_3_main 24/150] row 0989e2d303186dcb44ec3d718f0d1d04: attempt 1/1 (deterministic)
# [batch_3_main 24/150] row 0989e2d303186dcb44ec3d718f0d1d04: success on attempt 1/1
# [batch_3_main 25/150] row 245d2a9c92b73bbd58c9e4e97f91b72b: attempt 1/1 (deterministic)
# [batch_3_main 25/150] row 245d2a9c92b73bbd58c9e4e97f91b72b: success on attempt 1/1
# [batch_3_main 26/150] row d091e6693343180a934c1509fc164aaf: attempt 1/1 (deterministic)
# [batch_3_main 26/150] row d091e6693343180a934c1509fc164aaf: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 27/150] row 3ede34cac54e503b8f9805cc75fcd0d0: attempt 1/1 (deterministic)
# [batch_3_main 27/150] row 3ede34cac54e503b8f9805cc75fcd0d0: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 28/150] row thesantatitan_deepseek-svg-dataset_0002089: attempt 1/1 (deterministic)
# [batch_3_main 28/150] row thesantatitan_deepseek-svg-dataset_0002089: success on attempt 1/1
# [batch_3_main 29/150] row 7e2b0cf65f4bea635397c5c06288ac5d: attempt 1/1 (deterministic)
# [batch_3_main 29/150] row 7e2b0cf65f4bea635397c5c06288ac5d: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 30/150] row e7eab03a78edfdb3292458a0d110d5a7: attempt 1/1 (deterministic)
# [batch_3_main 30/150] row e7eab03a78edfdb3292458a0d110d5a7: attempt 1/1 failed: unclosed token: line 2, column 0
# Checkpointed batch_3_main: 30/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 31/150] row 419c943e98115a522ce8d0ceed72e058: attempt 1/1 (deterministic)
# [batch_3_main 31/150] row 419c943e98115a522ce8d0ceed72e058: success on attempt 1/1
# [batch_3_main 32/150] row 96d444b9e253870b0f9c681127a7a60c: attempt 1/1 (deterministic)
# [batch_3_main 32/150] row 96d444b9e253870b0f9c681127a7a60c: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_3_main 33/150] row 8c5f5dc69089a16823a430a679e0e1b6: attempt 1/1 (deterministic)
# [batch_3_main 33/150] row 8c5f5dc69089a16823a430a679e0e1b6: success on attempt 1/1
# [batch_3_main 34/150] row 82bbbfbc5d7e8dcce562cb2f8ee1289e: attempt 1/1 (deterministic)
# [batch_3_main 34/150] row 82bbbfbc5d7e8dcce562cb2f8ee1289e: success on attempt 1/1
# [batch_3_main 35/150] row f4d9e588ca3be28b2257c8bfea9d4f50: attempt 1/1 (deterministic)
# [batch_3_main 35/150] row f4d9e588ca3be28b2257c8bfea9d4f50: success on attempt 1/1
# [batch_3_main 36/150] row d949e65e28d18212f411b315efd37426: attempt 1/1 (deterministic)
# [batch_3_main 36/150] row d949e65e28d18212f411b315efd37426: attempt 1/1 failed: unclosed token: line 13, column 0
# [batch_3_main 37/150] row 78b1ba881f33cdc22e61cafd7a1b20a4: attempt 1/1 (deterministic)
# [batch_3_main 37/150] row 78b1ba881f33cdc22e61cafd7a1b20a4: success on attempt 1/1
# [batch_3_main 38/150] row 16233792e99370718b4d5da5b7c68332: attempt 1/1 (deterministic)
# [batch_3_main 38/150] row 16233792e99370718b4d5da5b7c68332: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_3_main 39/150] row ee182160475a006959dad8bb4d6d6fbd: attempt 1/1 (deterministic)
# [batch_3_main 39/150] row ee182160475a006959dad8bb4d6d6fbd: success on attempt 1/1
# [batch_3_main 40/150] row bf5e875f-ff60-41ae-83f4-fa434d44eac8: attempt 1/1 (deterministic)
# [batch_3_main 40/150] row bf5e875f-ff60-41ae-83f4-fa434d44eac8: attempt 1/1 failed: unclosed token: line 5, column 0
# Checkpointed batch_3_main: 40/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 41/150] row 22d7d3facdcbf22bb0dbf76407b98b4b: attempt 1/1 (deterministic)
# [batch_3_main 41/150] row 22d7d3facdcbf22bb0dbf76407b98b4b: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 42/150] row db82e3784a60c9c9f3db667cf53a7855: attempt 1/1 (deterministic)
# [batch_3_main 42/150] row db82e3784a60c9c9f3db667cf53a7855: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 43/150] row b81e1ec1740a7b11cd4821adf6dbe19b: attempt 1/1 (deterministic)
# [batch_3_main 43/150] row b81e1ec1740a7b11cd4821adf6dbe19b: success on attempt 1/1
# [batch_3_main 44/150] row cb8f6e2a3e24a2e03181ab6fd360e0c1: attempt 1/1 (deterministic)
# [batch_3_main 44/150] row cb8f6e2a3e24a2e03181ab6fd360e0c1: success on attempt 1/1
# [batch_3_main 45/150] row a1822f1e1e899bcaf1e5e3cecb02d7ca: attempt 1/1 (deterministic)
# [batch_3_main 45/150] row a1822f1e1e899bcaf1e5e3cecb02d7ca: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3_main 46/150] row 7f1a8304ece0d81fe025c385076708c3: attempt 1/1 (deterministic)
# [batch_3_main 46/150] row 7f1a8304ece0d81fe025c385076708c3: attempt 1/1 failed: unclosed token: line 7, column 0
# [batch_3_main 47/150] row 8abac35e-2595-4967-9767-75547161362f: attempt 1/1 (deterministic)
# [batch_3_main 47/150] row 8abac35e-2595-4967-9767-75547161362f: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 48/150] row 9b9d1f2e-4e3e-401d-ab83-e99ec38e9e10: attempt 1/1 (deterministic)
# [batch_3_main 48/150] row 9b9d1f2e-4e3e-401d-ab83-e99ec38e9e10: success on attempt 1/1
# [batch_3_main 49/150] row f2d07302e18ae7d9776178dffceb271f: attempt 1/1 (deterministic)
# [batch_3_main 49/150] row f2d07302e18ae7d9776178dffceb271f: success on attempt 1/1
# [batch_3_main 50/150] row db82a4a661507741ca0f6da7bdaee1c6: attempt 1/1 (deterministic)
# [batch_3_main 50/150] row db82a4a661507741ca0f6da7bdaee1c6: success on attempt 1/1
# Checkpointed batch_3_main: 50/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 51/150] row 0d31244c36f30e28fe93b814641bc343: attempt 1/1 (deterministic)
# [batch_3_main 51/150] row 0d31244c36f30e28fe93b814641bc343: attempt 1/1 failed: unclosed token: line 26, column 0
# [batch_3_main 52/150] row 32c32e232654d64a03ef21e65f62578f: attempt 1/1 (deterministic)
# [batch_3_main 52/150] row 32c32e232654d64a03ef21e65f62578f: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_3_main 53/150] row thesantatitan_deepseek-svg-dataset_0004060: attempt 1/1 (deterministic)
# [batch_3_main 53/150] row thesantatitan_deepseek-svg-dataset_0004060: success on attempt 1/1
# [batch_3_main 54/150] row thesantatitan_deepseek-svg-dataset_0000687: attempt 1/1 (deterministic)
# [batch_3_main 54/150] row thesantatitan_deepseek-svg-dataset_0000687: success on attempt 1/1
# [batch_3_main 55/150] row 76cd9ce8bd8c824e3ef75f4d114114d1: attempt 1/1 (deterministic)
# [batch_3_main 55/150] row 76cd9ce8bd8c824e3ef75f4d114114d1: success on attempt 1/1
# [batch_3_main 56/150] row dd6c00e847681e312f0bddc999e60693: attempt 1/1 (deterministic)
# [batch_3_main 56/150] row dd6c00e847681e312f0bddc999e60693: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3_main 57/150] row 02b8f76167c80dec8201c5cb4f15d3c3: attempt 1/1 (deterministic)
# [batch_3_main 57/150] row 02b8f76167c80dec8201c5cb4f15d3c3: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 58/150] row 5b2c72f60d01bb99ae45460a3539acd3: attempt 1/1 (deterministic)
# [batch_3_main 58/150] row 5b2c72f60d01bb99ae45460a3539acd3: success on attempt 1/1
# [batch_3_main 59/150] row 4d728b8028bde2a072dcf55f9830f137: attempt 1/1 (deterministic)
# [batch_3_main 59/150] row 4d728b8028bde2a072dcf55f9830f137: success on attempt 1/1
# [batch_3_main 60/150] row beec5bc1456e6f7d7521aa7c5dcaa469: attempt 1/1 (deterministic)
# [batch_3_main 60/150] row beec5bc1456e6f7d7521aa7c5dcaa469: attempt 1/1 failed: unclosed token: line 11, column 4
# Checkpointed batch_3_main: 60/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 61/150] row 9cd0140cd4b2d2a32bf11812e2f7e238: attempt 1/1 (deterministic)
# [batch_3_main 61/150] row 9cd0140cd4b2d2a32bf11812e2f7e238: success on attempt 1/1
# [batch_3_main 62/150] row c2b6cc5e1354c632e1f672d7eb30bc2e: attempt 1/1 (deterministic)
# [batch_3_main 62/150] row c2b6cc5e1354c632e1f672d7eb30bc2e: success on attempt 1/1
# [batch_3_main 63/150] row 3968b3d2665d692e689b25976462335b: attempt 1/1 (deterministic)
# [batch_3_main 63/150] row 3968b3d2665d692e689b25976462335b: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 64/150] row 12b37b7b73f422373d7548407bfcbe8f: attempt 1/1 (deterministic)
# [batch_3_main 64/150] row 12b37b7b73f422373d7548407bfcbe8f: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_3_main 65/150] row 09f2f0c8078e838e6d466dae721a98e7: attempt 1/1 (deterministic)
# [batch_3_main 65/150] row 09f2f0c8078e838e6d466dae721a98e7: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3_main 66/150] row 90e00776-4d3e-4b89-9398-9480fcde7a3e: attempt 1/1 (deterministic)
# [batch_3_main 66/150] row 90e00776-4d3e-4b89-9398-9480fcde7a3e: attempt 1/1 failed: unclosed token: line 18, column 4
# [batch_3_main 67/150] row 3dabbae64ac72c4159037593bfc10c52: attempt 1/1 (deterministic)
# [batch_3_main 67/150] row 3dabbae64ac72c4159037593bfc10c52: success on attempt 1/1
# [batch_3_main 68/150] row 36c10387fc114fd2117979d13f271868: attempt 1/1 (deterministic)
# [batch_3_main 68/150] row 36c10387fc114fd2117979d13f271868: success on attempt 1/1
# [batch_3_main 69/150] row b7eca035720fbc892f7694fb868ef297: attempt 1/1 (deterministic)
# [batch_3_main 69/150] row b7eca035720fbc892f7694fb868ef297: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 70/150] row 4f82c239dd7865d70480fa760082e950: attempt 1/1 (deterministic)
# [batch_3_main 70/150] row 4f82c239dd7865d70480fa760082e950: success on attempt 1/1
# Checkpointed batch_3_main: 70/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 71/150] row 5161f5f9cb93e860ab0a5f3433e87fdd: attempt 1/1 (deterministic)
# [batch_3_main 71/150] row 5161f5f9cb93e860ab0a5f3433e87fdd: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 72/150] row 2fca18de72c4a9c9cf0ded8580faacd9: attempt 1/1 (deterministic)
# [batch_3_main 72/150] row 2fca18de72c4a9c9cf0ded8580faacd9: success on attempt 1/1
# [batch_3_main 73/150] row 38f572d88d5ffd17a89013711afd22c9: attempt 1/1 (deterministic)
# [batch_3_main 73/150] row 38f572d88d5ffd17a89013711afd22c9: success on attempt 1/1
# [batch_3_main 74/150] row 42efbb57f659a5d2ba4a12960936f87f: attempt 1/1 (deterministic)
# [batch_3_main 74/150] row 42efbb57f659a5d2ba4a12960936f87f: success on attempt 1/1
# [batch_3_main 75/150] row 0b79739fa4bcb122783788213c782721: attempt 1/1 (deterministic)
# [batch_3_main 75/150] row 0b79739fa4bcb122783788213c782721: attempt 1/1 failed: unclosed token: line 8, column 2
# [batch_3_main 76/150] row 5f083a92f86834d90e63e720f8951d02: attempt 1/1 (deterministic)
# [batch_3_main 76/150] row 5f083a92f86834d90e63e720f8951d02: success on attempt 1/1
# [batch_3_main 77/150] row 190a66384392df4f5e812a5d0f2d4e96: attempt 1/1 (deterministic)
# [batch_3_main 77/150] row 190a66384392df4f5e812a5d0f2d4e96: success on attempt 1/1
# [batch_3_main 78/150] row c8c93c790f4af02010dc5ae4b7977186: attempt 1/1 (deterministic)
# [batch_3_main 78/150] row c8c93c790f4af02010dc5ae4b7977186: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3_main 79/150] row 8d678bec7789b4f45a5937fd3569e327: attempt 1/1 (deterministic)
# [batch_3_main 79/150] row 8d678bec7789b4f45a5937fd3569e327: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3_main 80/150] row c9515952342a43cf72b8a7727c194f03: attempt 1/1 (deterministic)
# [batch_3_main 80/150] row c9515952342a43cf72b8a7727c194f03: attempt 1/1 failed: unclosed token: line 6, column 0
# Checkpointed batch_3_main: 80/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 81/150] row a768d35479dada1dae71da76807f058f: attempt 1/1 (deterministic)
# [batch_3_main 81/150] row a768d35479dada1dae71da76807f058f: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 82/150] row 023d5f817a9967267a3dba34251f98df: attempt 1/1 (deterministic)
# [batch_3_main 82/150] row 023d5f817a9967267a3dba34251f98df: attempt 1/1 failed: unclosed token: line 3, column 0
# [batch_3_main 83/150] row de9aefbc28b32b7996b92dda6ad0d460: attempt 1/1 (deterministic)
# [batch_3_main 83/150] row de9aefbc28b32b7996b92dda6ad0d460: success on attempt 1/1
# [batch_3_main 84/150] row e9bb9c99188432d39681c16f3932baa8: attempt 1/1 (deterministic)
# [batch_3_main 84/150] row e9bb9c99188432d39681c16f3932baa8: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_3_main 85/150] row d51db1cba1c46a0de571af7d65e6ac18: attempt 1/1 (deterministic)
# [batch_3_main 85/150] row d51db1cba1c46a0de571af7d65e6ac18: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 86/150] row c973d2ca1c58f013c507decae31a0c26: attempt 1/1 (deterministic)
# [batch_3_main 86/150] row c973d2ca1c58f013c507decae31a0c26: success on attempt 1/1
# [batch_3_main 87/150] row 45486555-9f01-4a7e-8432-3734af76555c: attempt 1/1 (deterministic)
# [batch_3_main 87/150] row 45486555-9f01-4a7e-8432-3734af76555c: attempt 1/1 failed: unclosed token: line 33, column 0
# [batch_3_main 88/150] row 93319c64-c2b3-4b7a-a210-e95e9831f06f: attempt 1/1 (deterministic)
# [batch_3_main 88/150] row 93319c64-c2b3-4b7a-a210-e95e9831f06f: success on attempt 1/1
# [batch_3_main 89/150] row 1b36f0fd37021a1d271d1e655ab88e91: attempt 1/1 (deterministic)
# [batch_3_main 89/150] row 1b36f0fd37021a1d271d1e655ab88e91: success on attempt 1/1
# [batch_3_main 90/150] row e806d9f46ba842485ff904bfcd677b0e: attempt 1/1 (deterministic)
# [batch_3_main 90/150] row e806d9f46ba842485ff904bfcd677b0e: attempt 1/1 failed: unclosed token: line 6, column 0
# Checkpointed batch_3_main: 90/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 91/150] row b373d88e7addf0b42a6edb3236b0e013: attempt 1/1 (deterministic)
# [batch_3_main 91/150] row b373d88e7addf0b42a6edb3236b0e013: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 92/150] row thesantatitan_deepseek-svg-dataset_0002725: attempt 1/1 (deterministic)
# [batch_3_main 92/150] row thesantatitan_deepseek-svg-dataset_0002725: success on attempt 1/1
# [batch_3_main 93/150] row ad7370692ccf45080b0313e775fdc09b: attempt 1/1 (deterministic)
# [batch_3_main 93/150] row ad7370692ccf45080b0313e775fdc09b: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3_main 94/150] row ea45dd1338d4e9dbf629a33711d73ae4: attempt 1/1 (deterministic)
# [batch_3_main 94/150] row ea45dd1338d4e9dbf629a33711d73ae4: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 95/150] row 5a7b83c366f20f47b4fee61d4ed46672: attempt 1/1 (deterministic)
# [batch_3_main 95/150] row 5a7b83c366f20f47b4fee61d4ed46672: attempt 1/1 failed: no element found: line 19, column 74
# [batch_3_main 96/150] row 4a082d8ce70f07f2c8ec4343fb09607e: attempt 1/1 (deterministic)
# [batch_3_main 96/150] row 4a082d8ce70f07f2c8ec4343fb09607e: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3_main 97/150] row 2bc39245-d640-43d8-9530-b286f936c0ba: attempt 1/1 (deterministic)
# [batch_3_main 97/150] row 2bc39245-d640-43d8-9530-b286f936c0ba: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 98/150] row 56a3f65b116a470d99c361fc2adfd5b0: attempt 1/1 (deterministic)
# [batch_3_main 98/150] row 56a3f65b116a470d99c361fc2adfd5b0: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 99/150] row d0dd63edc498d8af5ad88feec3a3aa45: attempt 1/1 (deterministic)
# [batch_3_main 99/150] row d0dd63edc498d8af5ad88feec3a3aa45: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3_main 100/150] row 62bc19fa5c982a11799d408868ea7a34: attempt 1/1 (deterministic)
# [batch_3_main 100/150] row 62bc19fa5c982a11799d408868ea7a34: attempt 1/1 failed: unclosed token: line 7, column 0
# Checkpointed batch_3_main: 100/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 101/150] row 019dc4ad-a0fe-4399-ac43-08b3934069f1: attempt 1/1 (deterministic)
# [batch_3_main 101/150] row 019dc4ad-a0fe-4399-ac43-08b3934069f1: success on attempt 1/1
# [batch_3_main 102/150] row 252a142060baed151fbdfe5c6e3b0dfb: attempt 1/1 (deterministic)
# [batch_3_main 102/150] row 252a142060baed151fbdfe5c6e3b0dfb: success on attempt 1/1
# [batch_3_main 103/150] row 0dc5c2d18af6c533f3bb0b897c4b0b92: attempt 1/1 (deterministic)
# [batch_3_main 103/150] row 0dc5c2d18af6c533f3bb0b897c4b0b92: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3_main 104/150] row 8c08a58c7f37e1a9dbefae50a6cc9f88: attempt 1/1 (deterministic)
# [batch_3_main 104/150] row 8c08a58c7f37e1a9dbefae50a6cc9f88: attempt 1/1 failed: unclosed token: line 20, column 4
# [batch_3_main 105/150] row 01f9378aa823a0f5ac3ea1b849437c06: attempt 1/1 (deterministic)
# [batch_3_main 105/150] row 01f9378aa823a0f5ac3ea1b849437c06: success on attempt 1/1
# [batch_3_main 106/150] row 1dc699e6e000b9c92aeae85d6eb4be64: attempt 1/1 (deterministic)
# [batch_3_main 106/150] row 1dc699e6e000b9c92aeae85d6eb4be64: attempt 1/1 failed: unclosed token: line 9, column 0
# [batch_3_main 107/150] row 8f8a6b6a8f41bcf6e6d82b9963c602f2: attempt 1/1 (deterministic)
# [batch_3_main 107/150] row 8f8a6b6a8f41bcf6e6d82b9963c602f2: success on attempt 1/1
# [batch_3_main 108/150] row 52807a64aeff6b3ee944dea2c504a8ae: attempt 1/1 (deterministic)
# [batch_3_main 108/150] row 52807a64aeff6b3ee944dea2c504a8ae: success on attempt 1/1
# [batch_3_main 109/150] row ebb8b5e83943b0f9350eb5ab7005cbb7: attempt 1/1 (deterministic)
# [batch_3_main 109/150] row ebb8b5e83943b0f9350eb5ab7005cbb7: attempt 1/1 failed: unclosed token: line 3, column 2
# [batch_3_main 110/150] row 687dcd7afc538b8d02cb79732e11f704: attempt 1/1 (deterministic)
# [batch_3_main 110/150] row 687dcd7afc538b8d02cb79732e11f704: success on attempt 1/1
# Checkpointed batch_3_main: 110/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 111/150] row 80626a7fb98cd3cda8c4c0166a414151: attempt 1/1 (deterministic)
# [batch_3_main 111/150] row 80626a7fb98cd3cda8c4c0166a414151: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 112/150] row thesantatitan_deepseek-svg-dataset_0003439: attempt 1/1 (deterministic)
# [batch_3_main 112/150] row thesantatitan_deepseek-svg-dataset_0003439: success on attempt 1/1
# [batch_3_main 113/150] row 41d36fbc527fc6d0970316cdf3b932b1: attempt 1/1 (deterministic)
# [batch_3_main 113/150] row 41d36fbc527fc6d0970316cdf3b932b1: success on attempt 1/1
# [batch_3_main 114/150] row df6bd5343885ca965f03d4161ca708ca: attempt 1/1 (deterministic)
# [batch_3_main 114/150] row df6bd5343885ca965f03d4161ca708ca: attempt 1/1 failed: unclosed token: line 8, column 0
# [batch_3_main 115/150] row 48c87959-d450-4a1b-bfd2-9b98e92ead19: attempt 1/1 (deterministic)
# [batch_3_main 115/150] row 48c87959-d450-4a1b-bfd2-9b98e92ead19: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 116/150] row a1fd86df-eeda-4f7b-b38e-3600927245b9: attempt 1/1 (deterministic)
# [batch_3_main 116/150] row a1fd86df-eeda-4f7b-b38e-3600927245b9: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 117/150] row 35af79d442bd937fbe614fd6aaaaa12c: attempt 1/1 (deterministic)
# [batch_3_main 117/150] row 35af79d442bd937fbe614fd6aaaaa12c: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3_main 118/150] row 39698809c3776f5cf8b4addb39a847b3: attempt 1/1 (deterministic)
# [batch_3_main 118/150] row 39698809c3776f5cf8b4addb39a847b3: success on attempt 1/1
# [batch_3_main 119/150] row ac257ce0ad3fc16513c55487a6e0eec8: attempt 1/1 (deterministic)
# [batch_3_main 119/150] row ac257ce0ad3fc16513c55487a6e0eec8: success on attempt 1/1
# [batch_3_main 120/150] row 034434f25044347627650b37c6ded315: attempt 1/1 (deterministic)
# [batch_3_main 120/150] row 034434f25044347627650b37c6ded315: success on attempt 1/1
# Checkpointed batch_3_main: 120/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 121/150] row 8cc54422f6df100049df0fa8b3297e7c: attempt 1/1 (deterministic)
# [batch_3_main 121/150] row 8cc54422f6df100049df0fa8b3297e7c: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_3_main 122/150] row eca474d62ec9c844fb98d910e5b4bddb: attempt 1/1 (deterministic)
# [batch_3_main 122/150] row eca474d62ec9c844fb98d910e5b4bddb: success on attempt 1/1
# [batch_3_main 123/150] row 4bdabc5bd786e2ab60383e19c1089f76: attempt 1/1 (deterministic)
# [batch_3_main 123/150] row 4bdabc5bd786e2ab60383e19c1089f76: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_3_main 124/150] row 71ee158a22a6097284b46695521992a7: attempt 1/1 (deterministic)
# [batch_3_main 124/150] row 71ee158a22a6097284b46695521992a7: success on attempt 1/1
# [batch_3_main 125/150] row 9fa4222ec7965d5d3df86cd6b7967041: attempt 1/1 (deterministic)
# [batch_3_main 125/150] row 9fa4222ec7965d5d3df86cd6b7967041: attempt 1/1 failed: unclosed token: line 11, column 4
# [batch_3_main 126/150] row thesantatitan_deepseek-svg-dataset_0001094: attempt 1/1 (deterministic)
# [batch_3_main 126/150] row thesantatitan_deepseek-svg-dataset_0001094: attempt 1/1 failed: unclosed token: line 22, column 2
# [batch_3_main 127/150] row 3332a2eeb90d4b8ace89ce52e857c0f1: attempt 1/1 (deterministic)
# [batch_3_main 127/150] row 3332a2eeb90d4b8ace89ce52e857c0f1: success on attempt 1/1
# [batch_3_main 128/150] row thesantatitan_deepseek-svg-dataset_0003906: attempt 1/1 (deterministic)
# [batch_3_main 128/150] row thesantatitan_deepseek-svg-dataset_0003906: success on attempt 1/1
# [batch_3_main 129/150] row 90a05b017060160c10ff6d99d5899d03: attempt 1/1 (deterministic)
# [batch_3_main 129/150] row 90a05b017060160c10ff6d99d5899d03: attempt 1/1 failed: unclosed token: line 9, column 4
# [batch_3_main 130/150] row 81f0ef2e89e860a114af2d8a4d133baa: attempt 1/1 (deterministic)
# [batch_3_main 130/150] row 81f0ef2e89e860a114af2d8a4d133baa: success on attempt 1/1
# Checkpointed batch_3_main: 130/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 131/150] row c3ce8e79074302a57f484a046a013c36: attempt 1/1 (deterministic)
# [batch_3_main 131/150] row c3ce8e79074302a57f484a046a013c36: attempt 1/1 failed: unclosed token: line 6, column 0
# [batch_3_main 132/150] row 5042ffa79825e6f2e6cee4a274ba4f5b: attempt 1/1 (deterministic)
# [batch_3_main 132/150] row 5042ffa79825e6f2e6cee4a274ba4f5b: success on attempt 1/1
# [batch_3_main 133/150] row 9505dcfe12be5fffcbb4ba231515c977: attempt 1/1 (deterministic)
# [batch_3_main 133/150] row 9505dcfe12be5fffcbb4ba231515c977: attempt 1/1 failed: unclosed token: line 11, column 0
# [batch_3_main 134/150] row 74f6eac8-62ee-4eb8-8011-46240d04e009: attempt 1/1 (deterministic)
# [batch_3_main 134/150] row 74f6eac8-62ee-4eb8-8011-46240d04e009: attempt 1/1 failed: unclosed token: line 5, column 0
# [batch_3_main 135/150] row 53327e66189097b0ff9f7e70945735dc: attempt 1/1 (deterministic)
# [batch_3_main 135/150] row 53327e66189097b0ff9f7e70945735dc: success on attempt 1/1
# [batch_3_main 136/150] row b360fa0926a8b1957b1f26088fe97853: attempt 1/1 (deterministic)
# [batch_3_main 136/150] row b360fa0926a8b1957b1f26088fe97853: success on attempt 1/1
# [batch_3_main 137/150] row 6ad7c2e050bff53dcea032cf7583bf0a: attempt 1/1 (deterministic)
# [batch_3_main 137/150] row 6ad7c2e050bff53dcea032cf7583bf0a: attempt 1/1 failed: unclosed token: line 20, column 0
# [batch_3_main 138/150] row 6bc65b1d3307d18e1f92706020aa894b: attempt 1/1 (deterministic)
# [batch_3_main 138/150] row 6bc65b1d3307d18e1f92706020aa894b: success on attempt 1/1
# [batch_3_main 139/150] row c3db0c52ced2e11be751309c2556006d: attempt 1/1 (deterministic)
# [batch_3_main 139/150] row c3db0c52ced2e11be751309c2556006d: success on attempt 1/1
# [batch_3_main 140/150] row 2a1c12b0d51a179892d195533f7f596c: attempt 1/1 (deterministic)
# [batch_3_main 140/150] row 2a1c12b0d51a179892d195533f7f596c: attempt 1/1 failed: unclosed token: line 8, column 4
# Checkpointed batch_3_main: 140/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# [batch_3_main 141/150] row 90abc2f690f333e847fe3eb62fdef1a2: attempt 1/1 (deterministic)
# [batch_3_main 141/150] row 90abc2f690f333e847fe3eb62fdef1a2: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 142/150] row thesantatitan_deepseek-svg-dataset_0003980: attempt 1/1 (deterministic)
# [batch_3_main 142/150] row thesantatitan_deepseek-svg-dataset_0003980: success on attempt 1/1
# [batch_3_main 143/150] row c9b6722769932bb1efc2f6bc12ed7d65: attempt 1/1 (deterministic)
# [batch_3_main 143/150] row c9b6722769932bb1efc2f6bc12ed7d65: attempt 1/1 failed: unclosed token: line 10, column 2
# [batch_3_main 144/150] row b38e1c566cfcb22ad3f533f433cd0733: attempt 1/1 (deterministic)
# [batch_3_main 144/150] row b38e1c566cfcb22ad3f533f433cd0733: success on attempt 1/1
# [batch_3_main 145/150] row b8029140c5fbb9821be9425c7fd82df5: attempt 1/1 (deterministic)
# [batch_3_main 145/150] row b8029140c5fbb9821be9425c7fd82df5: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 146/150] row 5d7ea50b7cbde896eda454af884fd39c: attempt 1/1 (deterministic)
# [batch_3_main 146/150] row 5d7ea50b7cbde896eda454af884fd39c: success on attempt 1/1
# [batch_3_main 147/150] row 5dcad18dd9f772a1ad8cd21e85dc0d22: attempt 1/1 (deterministic)
# [batch_3_main 147/150] row 5dcad18dd9f772a1ad8cd21e85dc0d22: attempt 1/1 failed: unclosed token: line 10, column 0
# [batch_3_main 148/150] row 45cc90ae5276bda487c4d20efc9f681c: attempt 1/1 (deterministic)
# [batch_3_main 148/150] row 45cc90ae5276bda487c4d20efc9f681c: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 149/150] row fdd6dae79b074bc46f43126e1bd6c938: attempt 1/1 (deterministic)
# [batch_3_main 149/150] row fdd6dae79b074bc46f43126e1bd6c938: attempt 1/1 failed: unclosed token: line 2, column 0
# [batch_3_main 150/150] row 1caebe7cd161b7e3bf1035a31da0b4ef: attempt 1/1 (deterministic)
# [batch_3_main 150/150] row 1caebe7cd161b7e3bf1035a31da0b4ef: success on attempt 1/1
# Checkpointed batch_3_main: 150/150 rows saved to /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials
# Wrote partial batch artifacts to: /content/drive/MyDrive/svg-kaggle-comptetition/submission_outputs/batches/batch_3/partials

# %% [markdown]
# ## Split Summary
#
# Show the current success and failure totals for this split of batch 3.
#
# - Reads: In-memory partial results
# - Writes: Nothing
# - Rerun-safe: Yes. Read-only display cell.

# %%
display(pipeline.summarize_batch_results(PARTIAL_RESULTS_DF))
FAILED_DF = PARTIAL_RESULTS_DF[~PARTIAL_RESULTS_DF["first_pass_success"]].copy()
if FAILED_DF.empty:
    print("No failed rows in this split.")
else:
    display(FAILED_DF[["id", "row_index", "generation_mode", "gate_error"]].head(20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_18476/2251180902.py in <cell line: 0>()
# ----> 1 display(pipeline.summarize_batch_results(PARTIAL_RESULTS_DF))
#       2 FAILED_DF = PARTIAL_RESULTS_DF[~PARTIAL_RESULTS_DF["first_pass_success"]].copy()
#       3 if FAILED_DF.empty:
#       4     print("No failed rows in this split.")
#       5 else:
#
# NameError: name 'PARTIAL_RESULTS_DF' is not defined

# %% [markdown]
# ## Finalize Canonical Batch 3 Outputs
#
# If all three split notebooks have finished, combine the partial outputs into the normal `batch_3/*.csv` files expected by the merge notebook. Otherwise print which split is still missing.
#
# - Reads: `batch_3/partials/*`
# - Writes: Canonical `batch_3/*.csv` only when all three splits are present
# - Rerun-safe: Yes. It rewrites the canonical batch 3 files if all splits are ready.

# %%
FINALIZE_STATUS = pipeline.finalize_split_batch_outputs(BATCH_DIR, expected_row_count=250)
if FINALIZE_STATUS["ready"]:
    print("Canonical batch_3 files are now finalized.")
    print(
        f"Rows: {FINALIZE_STATUS['rows']} | row range: {FINALIZE_STATUS['first_row_index']}:{FINALIZE_STATUS['last_row_index']}"
    )
else:
    print("Waiting for the other split notebooks before writing canonical batch_3 files.")
    print(f"Missing partials: {FINALIZE_STATUS['missing_parts']}")
    print(f"Currently saved rows across available partials: {FINALIZE_STATUS['rows']}")
display(pipeline.artifact_status_table(PATHS, batch_count=4))
